# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from textblob import TextBlob
from sklearn.feature_extraction.text import TfidfVectorizer
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
from collections import Counter
from itertools import chain
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import seaborn as sns
from wordcloud import WordCloud

# %%
file_path = "C:/Users/AKSHAYA/OneDrive/Documents/AmazonReviews/cleaned.csv"  # Update with actual file path

df = pd.read_csv(file_path)

# %%
df.head
# Out:
# <bound method NDFrame.head of          Unnamed: 0  rating  \
# 0                 0     5.0
# 1                 1     5.0
# 2                 2     2.0
# 3                 3     1.0
# 4                 4     5.0
# ...             ...     ...
# 2500934     2500934     5.0
# 2500935     2500935     1.0
# 2500936     2500936     3.0
# 2500937     2500937     5.0
# 2500938     2500938     1.0
#
#                                                      title  \
# 0                                            Pretty locket
# 1                                                        A
# 2                                                Two Stars
# 3                                          Won’t buy again
# 4                                     I LOVE these glasses
# ...                                                    ...
# 2500934  ... allowed them to be used to add military ri...
# 2500935                           Didn’t come with all ten
# 2500936                            Not checked for quality
# 2500937                                            Awesome
# 2500938                                  Empty plastic bag
#
#                                                       text images        asin  \
# 0        i think this locket is really pretty. the insi...     []  B00LOPVX74
# 1                                                    great     []  B07B4JXK8D
# 2        one of the stones fell out within the first 2 ...     []  B007ZSEQ4Q
# 3        crappy socks. money wasted. bought to wear wit...     []  B07F2BTFS9
# 4        i love these glasses!  they fit perfectly over...     []  B00PKRFU4O
# ...                                                    ...    ...         ...
# 2500934  the tie tacks were the size that allowed them ...     []  B00YGFMQC0
# 2500935          says ten tie clips but o only received 7.     []  B00YGFMQC0
# 2500936  when i received them 2-3 of them did not open ...     []  B00YGFMQC0
# 2500937                                     great product.     []  B00YGFMQC0
# 2500938  i got an empty bag in my package of 10 that i ...     []  B00YGFMQC0
#
#         parent_asin                       user_id                timestamp  \
# 0        B00LOPVX74  AGBFYI2DDIKXC5Y4FARTYDTQBMFQ  2020-01-09 00:06:34.489
# 1        B07B4JXK8D  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ  2020-12-20 01:04:06.701
# 2        B007ZSEQ4Q  AHITBJSS7KYUBVZPX7M2WJCOIVKQ  2015-05-23 01:33:48.000
# 3        B07F2BTFS9  AFVNEEPDEIH5SPUN5BWC6NKL3WNQ  2018-12-31 20:57:27.095
# 4        B00XESJTDE  AHSPLDNW5OOUK2PLH7GXLACFBZNQ  2015-08-13 14:29:26.000
# ...             ...                           ...                      ...
# 2500934  B00YGFMQC0  AFXSFD3FTZ2CLN3TYV4B63CQM5BQ  2016-06-24 20:12:38.000
# 2500935  B00YGFMQC0  AEH7WP5HGM6FGLSSC6GSTYUXBHGQ  2018-05-08 17:05:05.585
# 2500936  B00YGFMQC0  AEL2TSSBVLIPWQ7YVMK364DUYURQ  2016-12-17 22:28:31.000
# 2500937  B00YGFMQC0  AGZ6IIYSPCW4YXWH6VFEOI7MTBZA  2017-04-15 17:34:26.000
# 2500938  B00YGFMQC0  AGN3P7MZ3WYZQTPOCSIWNTHD5RDQ  2017-03-15 00:25:02.000
#
#          helpful_vote  verified_purchase  \
# 0                   3               True
# 1                   0               True
# 2                   3               True
# 3                   2               True
# 4                   0               True
# ...               ...                ...
# 2500934             0               True
# 2500935             0               True
# 2500936             0               True
# 2500937             1               True
# 2500938             1               True
#
#                                                     tokens  \
# 0        ['think', 'locket', 'really', 'pretty', '.', '...
# 1                                                ['great']
# 2        ['stone', 'fell', '2', 'week', 'wearing', '.',...
# 3        ['crappy', 'sock', '.', 'money', 'wasted', '.'...
# 4        ['love', 'glass', '!', 'fit', 'perfectly', 're...
# ...                                                    ...
# 2500934  ['tie', 'tack', 'size', 'allowed', 'used', 'ad...
# 2500935       ['say', 'tie', 'clip', 'received', '7', '.']
# 2500936  ['received', '2-3', 'open', 'properly', '.', '...
# 2500937                          ['great', 'product', '.']
# 2500938  ['got', 'bag', 'package', '10', 'purchased', '...
#
#                                               cleaned_text  review_length
# 0        think locket really pretty . inside solid silv...             36
# 1                                                    great              1
# 2        stone fell 2 week wearing . stone smaller expe...             10
# 3        crappy sock . money wasted . bought wear tieks...             14
# 4        love glass ! fit perfectly regular , rectangul...             29
# ...                                                    ...            ...
# 2500934  tie tack size allowed used add military ribbon...             16
# 2500935                          say tie clip received 7 .              6
# 2500936     received 2-3 open properly . look break easily              8
# 2500937                                    great product .              3
# 2500938            got bag package 10 purchased . thanks !              8
#
# [2500939 rows x 14 columns]>

# %%
# Count reviews per reviewer
review_counts = df['user_id'].value_counts()

# Map reviewerID to 'Frequent' or 'Infrequent'
df['reviewer_type'] = df['user_id'].map(lambda x: 'Frequent' if review_counts[x] >= 10 else 'Infrequent')

# %%
def get_fashion_category(title):
    if not isinstance(title, str):
        return 'Unknown'

    title = title.lower()

    categories = {
        'Tops & Tees': ['t-shirt', 'tee', 'top', 'tank', 'blouse', 'shirt'],
        'Bottoms': ['jeans', 'pants', 'trousers', 'leggings', 'shorts', 'skirt'],
        'Dresses': ['dress', 'gown', 'frock', 'kurti'],
        'Outerwear': ['jacket', 'coat', 'hoodie', 'sweater', 'blazer', 'shrug'],
        'Ethnic Wear': ['saree', 'salwar', 'lehenga', 'kurta', 'kurti', 'dupatta'],
        'Footwear': ['shoes', 'sneakers', 'heels', 'sandals', 'flats', 'slippers', 'boots'],
        'Lingerie & Sleepwear': ['bra', 'panty', 'lingerie', 'nightwear', 'sleepwear', 'camisole', 'nightdress'],
        'Accessories': ['belt', 'cap', 'hat', 'sunglasses', 'scarf', 'watch', 'bag', 'handbag', 'wallet','locket','glasses'],
        'Activewear': ['sports bra', 'gym', 'trackpant', 'activewear', 'joggers'],
        'Kidswear': ['kids', 'child', 'baby', 'infant'],
        'Menswear': ['men', "men's", 'gent'],
        'Womenswear': ['women', "women's", 'lady', 'ladies']
    }

    for category, keywords in categories.items():
        if any(keyword in title for keyword in keywords):
            return category
    return 'Unknown'
if 'title' in df.columns:
    df['fashion_category'] = df['title'].apply(get_fashion_category)
else:
    df['fashion_category'] = 'Unknown'

# %%
# Generalize Rating
rating_hierarchy = {
    1: 'Low',
    2: 'Low',
    3: 'Medium',
    4: 'High',
    5: 'High'
}
df['rating_generalized'] = df['rating'].map(rating_hierarchy)

# Add Sentiment based on rating
def map_sentiment(rating):
    if rating >= 4:
        return 'Positive'
    elif rating == 3:
        return 'Neutral'
    else:
        return 'Negative'

df['sentiment'] = df['rating'].apply(map_sentiment)

# Generalize Review Length
def categorize_length(length):
    if length < 50:
        return 'Short'
    elif 50 <= length <= 100:
        return 'Medium'
    else:
        return 'Long'

df['review_length_category'] = df['cleaned_text'].apply(
    lambda x: categorize_length(len(str(x).split()))
)

# Generalize Helpful Votes
def generalize_helpful(votes):
    if votes == 0:
        return 'None'
    elif 1 <= votes <= 5:
        return 'Less Helpful'
    else:
        return 'More Helpful'

df['helpful_vote_category'] = df['helpful_vote'].apply(generalize_helpful)

# Generalize Verified Purchase
df['verified_status'] = df['verified_purchase'].map({True: 'Verified', False: 'Not Verified'})



# Final selection of generalized attributes
generalized_df = df[[
    'rating_generalized',
    'sentiment',
    'review_length_category',
    'helpful_vote_category',
    'verified_status',
    'reviewer_type',
    'fashion_category'
]]

# Display top rows
print(generalized_df.head())
# Out:
#   rating_generalized sentiment review_length_category helpful_vote_category  \
# 0               High  Positive                  Short          Less Helpful
# 1               High  Positive                  Short                  None
# 2                Low  Negative                  Short          Less Helpful
# 3                Low  Negative                  Short          Less Helpful
# 4               High  Positive                  Short                  None
#
#   verified_status reviewer_type fashion_category
# 0        Verified    Infrequent      Accessories
# 1        Verified    Infrequent          Unknown
# 2        Verified    Infrequent          Unknown
# 3        Verified    Infrequent          Unknown
# 4        Verified    Infrequent      Accessories

# %%
summary = df.groupby(
    ["reviewer_type", "fashion_category", "rating_generalized", "sentiment", 
     "review_length_category", "helpful_vote_category", "verified_status"]
).agg(
    review_count=("rating", "count"),
    avg_rating=("rating", "mean"),
    avg_helpful_vote=("helpful_vote", "mean")
).reset_index()

# %%
summary
# Out:
#      reviewer_type fashion_category rating_generalized sentiment  \
# 0         Frequent      Accessories               High  Positive
# 1         Frequent      Accessories               High  Positive
# 2         Frequent      Accessories               High  Positive
# 3         Frequent      Accessories               High  Positive
# 4         Frequent      Accessories               High  Positive
# ...            ...              ...                ...       ...
# 1003    Infrequent       Womenswear             Medium   Neutral
# 1004    Infrequent       Womenswear             Medium   Neutral
# 1005    Infrequent       Womenswear             Medium   Neutral
# 1006    Infrequent       Womenswear             Medium   Neutral
# 1007    Infrequent       Womenswear             Medium   Neutral
#
#      review_length_category helpful_vote_category verified_status  \
# 0                      Long          Less Helpful    Not Verified
# 1                      Long          Less Helpful        Verified
# 2                      Long          More Helpful    Not Verified
# 3                      Long          More Helpful        Verified
# 4                      Long                  None    Not Verified
# ...                     ...                   ...             ...
# 1003                 Medium                  None        Verified
# 1004                  Short          Less Helpful        Verified
# 1005                  Short          More Helpful        Verified
# 1006                  Short                  None    Not Verified
# 1007                  Short                  None        Verified
#
#       review_count  avg_rating  avg_helpful_vote
# 0               61    4.606557          1.770492
# 1               10    4.700000          2.500000
# 2               11    4.909091         24.818182
# 3                6    4.333333         15.500000
# 4               77    4.584416          0.000000
# ...            ...         ...               ...
# 1003             7    3.000000          0.000000
# 1004            30    3.000000          1.433333
# 1005             6    3.000000         11.500000
# 1006            11    3.000000          0.000000
# 1007            88    3.000000          0.000000
#
# [1008 rows x 10 columns]

# %%
# Convert the summary dataframe into a transaction-style format
summary_trans = summary.apply(lambda row: [
    f"Reviewer_Type={row['reviewer_type']}",
    f"Fashion_Category={row['fashion_category']}",  # Added fashion_category
    f"Rating={row['rating_generalized']}",
    f"Sentiment={row['sentiment']}",
    f"Review_Length={row['review_length_category']}",
    f"Helpfulness={row['helpful_vote_category']}",
    f"Verified={row['verified_status']}"
], axis=1)

# Convert the list of transactions to the right format for rule mining
summary_trans = summary_trans.tolist()

# Example: Print the first 5 transactions
print("Sample Transactions (first 5):", summary_trans[:5])
# Out:
# Sample Transactions (first 5): [['Reviewer_Type=Frequent', 'Fashion_Category=Accessories', 'Rating=High', 'Sentiment=Positive', 'Review_Length=Long', 'Helpfulness=Less Helpful', 'Verified=Not Verified'], ['Reviewer_Type=Frequent', 'Fashion_Category=Accessories', 'Rating=High', 'Sentiment=Positive', 'Review_Length=Long', 'Helpfulness=Less Helpful', 'Verified=Verified'], ['Reviewer_Type=Frequent', 'Fashion_Category=Accessories', 'Rating=High', 'Sentiment=Positive', 'Review_Length=Long', 'Helpfulness=More Helpful', 'Verified=Not Verified'], ['Reviewer_Type=Frequent', 'Fashion_Category=Accessories', 'Rating=High', 'Sentiment=Positive', 'Review_Length=Long', 'Helpfulness=More Helpful', 'Verified=Verified'], ['Reviewer_Type=Frequent', 'Fashion_Category=Accessories', 'Rating=High', 'Sentiment=Positive', 'Review_Length=Long', 'Helpfulness=None', 'Verified=Not Verified']]

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# Create a TransactionEncoder object to convert the transaction data
te = TransactionEncoder()
te_ary = te.fit(summary_trans).transform(summary_trans)
df_trans = pd.DataFrame(te_ary, columns=te.columns_)

# Apply apriori algorithm with a lower support threshold (e.g., 0.1)
frequent_itemsets = apriori(df_trans, min_support=0.1, use_colnames=True)

# Generate association rules based on confidence with a minimum threshold of 0.6
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

# === Step 2: Filter Rules Where Antecedent Contains 'Reviewer_Type=Frequent' or 'Reviewer_Type=Infrequent' ===
reviewer_type_rules = rules[rules['antecedents'].apply(
    lambda x: any('Reviewer_Type=Frequent' in str(i) or 'Reviewer_Type=Infrequent' in str(i) for i in x))
]

# Sort the rules by lift in descending order
reviewer_type_rules = reviewer_type_rules.sort_values(by='lift', ascending=False)

# === Step 3: Display Rules ===
print("\n📋 Reviewer Type-Based Discrimination Rules:\n")
if not reviewer_type_rules.empty:
    for _, row in reviewer_type_rules.iterrows():
        antecedent = ' AND '.join(list(row['antecedents']))
        consequent = ' AND '.join(list(row['consequents']))
        print(f"👉 IF {antecedent} THEN {consequent}")
        print(f"   - Support: {round(row['support'], 3)}")
        print(f"   - Confidence: {round(row['confidence'], 3)}")
        print(f"   - Lift: {round(row['lift'], 3)}\n")
else:
    print("No rules generated.")

# === Step 4: Summary Table ===
summary_df = reviewer_type_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].copy()
summary_df['antecedents'] = summary_df['antecedents'].apply(lambda x: ' AND '.join(x))
summary_df['consequents'] = summary_df['consequents'].apply(lambda x: ' AND '.join(x))

# Save the summary to a CSV file
summary_df.to_csv('reviewer_type_discrimination_rules_summary.csv', index=False)

# Print the summary of the rules
print("\n📄 Summary of Reviewer Type Discrimination Rules:\n")
print(summary_df.head(10))
# Out:
# 📋 Reviewer Type-Based Discrimination Rules:
#
# 👉 IF Reviewer_Type=Infrequent AND Rating=Medium THEN Sentiment=Neutral
#    - Support: 0.186
#    - Confidence: 1.0
#    - Lift: 3.371
#
# 👉 IF Reviewer_Type=Frequent AND Rating=Medium THEN Sentiment=Neutral
#    - Support: 0.111
#    - Confidence: 1.0
#    - Lift: 3.371
#
# 👉 IF Verified=Verified AND Reviewer_Type=Infrequent AND Rating=Medium THEN Sentiment=Neutral
#    - Support: 0.103
#    - Confidence: 1.0
#    - Lift: 3.371
#
# 👉 IF Reviewer_Type=Infrequent AND Sentiment=Neutral THEN Rating=Medium
#    - Support: 0.186
#    - Confidence: 1.0
#    - Lift: 3.371
#
# 👉 IF Reviewer_Type=Frequent AND Sentiment=Neutral THEN Rating=Medium
#    - Support: 0.111
#    - Confidence: 1.0
#    - Lift: 3.371
#
# 👉 IF Reviewer_Type=Infrequent AND Sentiment=Neutral AND Verified=Verified THEN Rating=Medium
#    - Support: 0.103
#    - Confidence: 1.0
#    - Lift: 3.371
#
# 👉 IF Reviewer_Type=Infrequent AND Rating=Low THEN Sentiment=Negative
#    - Support: 0.195
#    - Confidence: 1.0
#    - Lift: 3.294
#
# 👉 IF Reviewer_Type=Infrequent AND Sentiment=Negative THEN Rating=Low
#    - Support: 0.195
#    - Confidence: 1.0
#    - Lift: 3.294
#
# 👉 IF Reviewer_Type=Frequent AND Sentiment=Negative THEN Rating=Low
#    - Support: 0.108
#    - Confidence: 1.0
#    - Lift: 3.294
#
# 👉 IF Rating=Low AND Reviewer_Type=Frequent THEN Sentiment=Negative
#    - Support: 0.108
#    - Confidence: 1.0
#    - Lift: 3.294
#
# 👉 IF Reviewer_Type=Infrequent AND Rating=Low AND Verified=Verified THEN Sentiment=Negative
#    - Support: 0.102
#    - Confidence: 1.0
#    - Lift: 3.294
#
# 👉 IF Reviewer_Type=Infrequent AND Sentiment=Negative AND Verified=Verified THEN Rating=Low
#    - Support: 0.102
#    - Confidence: 1.0
#    - Lift: 3.294
#
# 👉 IF Reviewer_Type=Frequent AND Rating=High THEN Sentiment=Positive
#    - Support: 0.183
#    - Confidence: 1.0
#    - Lift: 2.501
#
# 👉 IF Reviewer_Type=Infrequent AND Rating=High THEN Sentiment=Positive
#    - Support: 0.217
#    - Confidence: 1.0
#    - Lift: 2.501
#
# 👉 IF Reviewer_Type=Infrequent AND Sentiment=Positive AND Verified=Not Verified THEN Rating=High
#    - Support: 0.105
#    - Confidence: 1.0
#    - Lift: 2.501
#
# 👉 IF Reviewer_Type=Infrequent AND Verified=Not Verified AND Rating=High THEN Sentiment=Positive
#    - Support: 0.105
#    - Confidence: 1.0
#    - Lift: 2.501
#
# 👉 IF Reviewer_Type=Infrequent AND Sentiment=Positive AND Verified=Verified THEN Rating=High
#    - Support: 0.112
#    - Confidence: 1.0
#    - Lift: 2.501
#
# 👉 IF Reviewer_Type=Infrequent AND Rating=High AND Verified=Verified THEN Sentiment=Positive
#    - Support: 0.112
#    - Confidence: 1.0
#    - Lift: 2.501
#
# 👉 IF Reviewer_Type=Infrequent AND Sentiment=Positive THEN Rating=High
#    - Support: 0.217
#    - Confidence: 1.0
#    - Lift: 2.501
#
# 👉 IF Sentiment=Positive AND Reviewer_Type=Frequent THEN Rating=High
#    - Support: 0.183
#    - Confidence: 1.0
#    - Lift: 2.501
#
#
# 📄 Summary of Reviewer Type Discrimination Rules:
#
#                                           antecedents         consequents  \
# 65         Reviewer_Type=Infrequent AND Rating=Medium   Sentiment=Neutral
# 63           Reviewer_Type=Frequent AND Rating=Medium   Sentiment=Neutral
# 87  Verified=Verified AND Reviewer_Type=Infrequent...   Sentiment=Neutral
# 67     Reviewer_Type=Infrequent AND Sentiment=Neutral       Rating=Medium
# 64       Reviewer_Type=Frequent AND Sentiment=Neutral       Rating=Medium
# 89  Reviewer_Type=Infrequent AND Sentiment=Neutral...       Rating=Medium
# 49            Reviewer_Type=Infrequent AND Rating=Low  Sentiment=Negative
# 50    Reviewer_Type=Infrequent AND Sentiment=Negative          Rating=Low
# 48      Reviewer_Type=Frequent AND Sentiment=Negative          Rating=Low
# 47              Rating=Low AND Reviewer_Type=Frequent  Sentiment=Negative
#
#      support  confidence      lift
# 65  0.185516         1.0  3.371237
# 63  0.111111         1.0  3.371237
# 87  0.103175         1.0  3.371237
# 67  0.185516         1.0  3.371237
# 64  0.111111         1.0  3.371237
# 89  0.103175         1.0  3.371237
# 49  0.195437         1.0  3.294118
# 50  0.195437         1.0  3.294118
# 48  0.108135         1.0  3.294118
# 47  0.108135         1.0  3.294118

# %%
# Apply apriori with a lower support threshold (e.g., 0.05)
frequent_itemsets = apriori(df_trans, min_support=0.05, use_colnames=True)

# Generate association rules based on confidence with a minimum threshold of 0.2
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)

# === Step 1: Filter for 'Reviewer_Type=Frequent' in antecedents ===
frequent_reviewer_rules = rules[rules['antecedents'].apply(
    lambda x: 'Reviewer_Type=Frequent' in str(x) and len(x) == 1)]  # Strict filter for 'Reviewer_Type=Frequent' alone

# === Step 2: Filter for 'Reviewer_Type=Infrequent' in antecedents ===
infrequent_reviewer_rules = rules[rules['antecedents'].apply(
    lambda x: 'Reviewer_Type=Infrequent' in str(x) and len(x) == 1)]  # Strict filter for 'Reviewer_Type=Infrequent' alone

# === Step 3: Sort the rules by lift in descending order ===
frequent_reviewer_rules = frequent_reviewer_rules.sort_values(by='lift', ascending=False)
infrequent_reviewer_rules = infrequent_reviewer_rules.sort_values(by='lift', ascending=False)

# === Step 4: Display Rules for Frequent Reviewer Type ===
print("\n📋 Reviewer Type-Based Discrimination Rules (Strictly 'Reviewer_Type=Frequent'):\n")
if not frequent_reviewer_rules.empty:
    for _, row in frequent_reviewer_rules.iterrows():
        antecedent = ' AND '.join(list(row['antecedents']))
        consequent = ' AND '.join(list(row['consequents']))
        print(f"👉 IF {antecedent} THEN {consequent}")
        print(f"   - Support: {round(row['support'], 3)}")
        print(f"   - Confidence: {round(row['confidence'], 3)}")
        print(f"   - Lift: {round(row['lift'], 3)}\n")
else:
    print("No rules generated for 'Reviewer_Type=Frequent'.")

# === Step 5: Display Rules for Infrequent Reviewer Type ===
print("\n📋 Reviewer Type-Based Discrimination Rules (Strictly 'Reviewer_Type=Infrequent'):\n")
if not infrequent_reviewer_rules.empty:
    for _, row in infrequent_reviewer_rules.iterrows():
        antecedent = ' AND '.join(list(row['antecedents']))
        consequent = ' AND '.join(list(row['consequents']))
        print(f"👉 IF {antecedent} THEN {consequent}")
        print(f"   - Support: {round(row['support'], 3)}")
        print(f"   - Confidence: {round(row['confidence'], 3)}")
        print(f"   - Lift: {round(row['lift'], 3)}\n")
else:
    print("No rules generated for 'Reviewer_Type=Infrequent'.")

# === Step 6: Summary Tables ===
# Create summary tables for each filter
frequent_summary_df = frequent_reviewer_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].copy()
frequent_summary_df['antecedents'] = frequent_summary_df['antecedents'].apply(lambda x: ' AND '.join(x))
frequent_summary_df['consequents'] = frequent_summary_df['consequents'].apply(lambda x: ' AND '.join(x))

infrequent_summary_df = infrequent_reviewer_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].copy()
infrequent_summary_df['antecedents'] = infrequent_summary_df['antecedents'].apply(lambda x: ' AND '.join(x))
infrequent_summary_df['consequents'] = infrequent_summary_df['consequents'].apply(lambda x: ' AND '.join(x))

# Save the summaries to separate CSV files
frequent_summary_df.to_csv('reviewer_type_frequent_discrimination_rules_summary.csv', index=False)
infrequent_summary_df.to_csv('reviewer_type_infrequent_discrimination_rules_summary.csv', index=False)

# Print the summary of the rules
print("\n📄 Summary of Reviewer Type Discrimination Rules :\n")
print(frequent_summary_df.head(10))

print("\n📄 Summary of Reviewer Type Discrimination Rules :\n")
print(infrequent_summary_df.head(10))
# Out:
# 📋 Reviewer Type-Based Discrimination Rules (Strictly 'Reviewer_Type=Frequent'):
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Positive AND Verified=Not Verified AND Rating=High
#    - Support: 0.095
#    - Confidence: 0.237
#    - Lift: 1.183
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Positive AND Verified=Not Verified
#    - Support: 0.095
#    - Confidence: 0.237
#    - Lift: 1.183
#
# 👉 IF Reviewer_Type=Frequent THEN Verified=Not Verified AND Rating=High
#    - Support: 0.095
#    - Confidence: 0.237
#    - Lift: 1.183
#
# 👉 IF Reviewer_Type=Frequent THEN Verified=Not Verified AND Helpfulness=None
#    - Support: 0.092
#    - Confidence: 0.23
#    - Lift: 1.169
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Positive
#    - Support: 0.183
#    - Confidence: 0.454
#    - Lift: 1.136
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High
#    - Support: 0.183
#    - Confidence: 0.454
#    - Lift: 1.136
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Positive AND Rating=High
#    - Support: 0.183
#    - Confidence: 0.454
#    - Lift: 1.136
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Positive AND Rating=High AND Verified=Verified
#    - Support: 0.087
#    - Confidence: 0.217
#    - Lift: 1.09
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.087
#    - Confidence: 0.217
#    - Lift: 1.09
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High AND Verified=Verified
#    - Support: 0.087
#    - Confidence: 0.217
#    - Lift: 1.09
#
# 👉 IF Reviewer_Type=Frequent THEN Helpfulness=Less Helpful
#    - Support: 0.156
#    - Confidence: 0.388
#    - Lift: 1.074
#
# 👉 IF Reviewer_Type=Frequent THEN Helpfulness=None
#    - Support: 0.16
#    - Confidence: 0.398
#    - Lift: 1.069
#
# 👉 IF Reviewer_Type=Frequent THEN Review_Length=Short AND Verified=Verified
#    - Support: 0.083
#    - Confidence: 0.207
#    - Lift: 1.056
#
# 👉 IF Reviewer_Type=Frequent THEN Verified=Not Verified
#    - Support: 0.206
#    - Confidence: 0.514
#    - Lift: 1.054
#
# 👉 IF Reviewer_Type=Frequent THEN Review_Length=Short
#    - Support: 0.155
#    - Confidence: 0.385
#    - Lift: 1.044
#
# 👉 IF Reviewer_Type=Frequent THEN Review_Length=Medium
#    - Support: 0.141
#    - Confidence: 0.351
#    - Lift: 1.03
#
# 👉 IF Reviewer_Type=Frequent THEN Verified=Verified
#    - Support: 0.195
#    - Confidence: 0.486
#    - Lift: 0.948
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Neutral
#    - Support: 0.111
#    - Confidence: 0.277
#    - Lift: 0.932
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.111
#    - Confidence: 0.277
#    - Lift: 0.932
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=Medium
#    - Support: 0.111
#    - Confidence: 0.277
#    - Lift: 0.932
#
# 👉 IF Reviewer_Type=Frequent THEN Review_Length=Long
#    - Support: 0.106
#    - Confidence: 0.264
#    - Lift: 0.909
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Negative
#    - Support: 0.108
#    - Confidence: 0.269
#    - Lift: 0.887
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.108
#    - Confidence: 0.269
#    - Lift: 0.887
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=Low
#    - Support: 0.108
#    - Confidence: 0.269
#    - Lift: 0.887
#
# 👉 IF Reviewer_Type=Frequent THEN Helpfulness=More Helpful
#    - Support: 0.086
#    - Confidence: 0.215
#    - Lift: 0.805
#
#
# 📋 Reviewer Type-Based Discrimination Rules (Strictly 'Reviewer_Type=Infrequent'):
#
# 👉 IF Reviewer_Type=Infrequent THEN Helpfulness=More Helpful
#    - Support: 0.181
#    - Confidence: 0.302
#    - Lift: 1.131
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.195
#    - Confidence: 0.327
#    - Lift: 1.076
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=Low
#    - Support: 0.195
#    - Confidence: 0.327
#    - Lift: 1.076
#
# 👉 IF Reviewer_Type=Infrequent THEN Sentiment=Negative
#    - Support: 0.195
#    - Confidence: 0.327
#    - Lift: 1.076
#
# 👉 IF Reviewer_Type=Infrequent THEN Review_Length=Long
#    - Support: 0.185
#    - Confidence: 0.308
#    - Lift: 1.061
#
# 👉 IF Reviewer_Type=Infrequent THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.186
#    - Confidence: 0.31
#    - Lift: 1.045
#
# 👉 IF Reviewer_Type=Infrequent THEN Sentiment=Neutral
#    - Support: 0.186
#    - Confidence: 0.31
#    - Lift: 1.045
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=Medium
#    - Support: 0.186
#    - Confidence: 0.31
#    - Lift: 1.045
#
# 👉 IF Reviewer_Type=Infrequent THEN Verified=Verified
#    - Support: 0.317
#    - Confidence: 0.531
#    - Lift: 1.035
#
# 👉 IF Reviewer_Type=Infrequent THEN Review_Length=Medium
#    - Support: 0.199
#    - Confidence: 0.333
#    - Lift: 0.98
#
# 👉 IF Reviewer_Type=Infrequent THEN Review_Length=Short
#    - Support: 0.214
#    - Confidence: 0.358
#    - Lift: 0.971
#
# 👉 IF Reviewer_Type=Infrequent THEN Verified=Not Verified
#    - Support: 0.281
#    - Confidence: 0.469
#    - Lift: 0.963
#
# 👉 IF Reviewer_Type=Infrequent THEN Helpfulness=None
#    - Support: 0.212
#    - Confidence: 0.355
#    - Lift: 0.954
#
# 👉 IF Reviewer_Type=Infrequent THEN Helpfulness=Less Helpful
#    - Support: 0.205
#    - Confidence: 0.343
#    - Lift: 0.951
#
# 👉 IF Reviewer_Type=Infrequent THEN Sentiment=Positive
#    - Support: 0.217
#    - Confidence: 0.363
#    - Lift: 0.908
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=High
#    - Support: 0.217
#    - Confidence: 0.363
#    - Lift: 0.908
#
# 👉 IF Reviewer_Type=Infrequent THEN Sentiment=Positive AND Rating=High
#    - Support: 0.217
#    - Confidence: 0.363
#    - Lift: 0.908
#
#
# 📄 Summary of Reviewer Type Discrimination Rules :
#
#                  antecedents  \
# 1389  Reviewer_Type=Frequent
# 983   Reviewer_Type=Frequent
# 644   Reviewer_Type=Frequent
# 529   Reviewer_Type=Frequent
# 184   Reviewer_Type=Frequent
# 95    Reviewer_Type=Frequent
# 639   Reviewer_Type=Frequent
# 1402  Reviewer_Type=Frequent
# 988   Reviewer_Type=Frequent
# 649   Reviewer_Type=Frequent
#
#                                             consequents   support  confidence  \
# 1389  Sentiment=Positive AND Verified=Not Verified A...  0.095238    0.237037
# 983        Sentiment=Positive AND Verified=Not Verified  0.095238    0.237037
# 644               Verified=Not Verified AND Rating=High  0.095238    0.237037
# 529          Verified=Not Verified AND Helpfulness=None  0.092262    0.229630
# 184                                  Sentiment=Positive  0.182540    0.454321
# 95                                          Rating=High  0.182540    0.454321
# 639                  Sentiment=Positive AND Rating=High  0.182540    0.454321
# 1402  Sentiment=Positive AND Rating=High AND Verifie...  0.087302    0.217284
# 988            Sentiment=Positive AND Verified=Verified  0.087302    0.217284
# 649                   Rating=High AND Verified=Verified  0.087302    0.217284
#
#           lift
# 1389  1.182838
# 983   1.182838
# 644   1.182838
# 529   1.169024
# 184   1.136366
# 95    1.136366
# 639   1.136366
# 1402  1.089663
# 988   1.089663
# 649   1.089663
#
# 📄 Summary of Reviewer Type Discrimination Rules :
#
#                   antecedents                          consequents   support  \
# 52   Reviewer_Type=Infrequent             Helpfulness=More Helpful  0.180556
# 734  Reviewer_Type=Infrequent    Rating=Low AND Sentiment=Negative  0.195437
# 113  Reviewer_Type=Infrequent                           Rating=Low  0.195437
# 189  Reviewer_Type=Infrequent                   Sentiment=Negative  0.195437
# 139  Reviewer_Type=Infrequent                   Review_Length=Long  0.184524
# 812  Reviewer_Type=Infrequent  Sentiment=Neutral AND Rating=Medium  0.185516
# 191  Reviewer_Type=Infrequent                    Sentiment=Neutral  0.185516
# 129  Reviewer_Type=Infrequent                        Rating=Medium  0.185516
# 197  Reviewer_Type=Infrequent                    Verified=Verified  0.317460
# 153  Reviewer_Type=Infrequent                 Review_Length=Medium  0.199405
#
#      confidence      lift
# 52     0.301824  1.130999
# 734    0.326700  1.076188
# 113    0.326700  1.076188
# 189    0.326700  1.076188
# 139    0.308458  1.061179
# 812    0.310116  1.045475
# 191    0.310116  1.045475
# 129    0.310116  1.045475
# 197    0.530680  1.034672
# 153    0.333333  0.979592

# %%
from mlxtend.frequent_patterns import apriori, association_rules
import pandas as pd
import os

# Re-run Apriori with lower thresholds to capture more rules
frequent_itemsets = apriori(df_trans, min_support=0.01, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)

# Create output directory
os.makedirs("fashion_category_rules", exist_ok=True)

# Define fashion categories
fashion_categories = [
    'Accessories', 'Tops & Tees', 'Bottoms', 'Dresses', 'Outerwear', 'Ethnic Wear',
    'Footwear', 'Lingerie & Sleepwear', 'Activewear', 'Kidswear', 'Menswear', 'Womenswear'
]

print("\n🎯 Generating Discrimination Rules Based on Fashion_Category \n")

for category in fashion_categories:
    cat_tag = f"Fashion_Category={category}"
    
    # Strict filter: only that category alone in antecedent
    cat_rules = rules[rules['antecedents'].apply(
        lambda x: cat_tag in str(x) and len(x) == 1
    )].sort_values(by='lift', ascending=False)

    print(f"\n📂 Rules for '{cat_tag}':")
    if not cat_rules.empty:
        for _, row in cat_rules.iterrows():
            antecedent = ' AND '.join(list(row['antecedents']))
            consequent = ' AND '.join(list(row['consequents']))
            print(f"👉 IF {antecedent} THEN {consequent}")
            print(f"   - Support: {round(row['support'], 3)}")
            print(f"   - Confidence: {round(row['confidence'], 3)}")
            print(f"   - Lift: {round(row['lift'], 3)}\n")
        
        # Save summary to CSV
        summary_df = cat_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].copy()
        summary_df['antecedents'] = summary_df['antecedents'].apply(lambda x: ' AND '.join(x))
        summary_df['consequents'] = summary_df['consequents'].apply(lambda x: ' AND '.join(x))
        summary_df.to_csv(f"fashion_category_rules/{category}_category_rules_summary.csv", index=False)
    else:
        print(f"❌ No rules generated for category '{category}'.")
# Out:
# 🎯 Generating Discrimination Rules Based on Fashion_Category
#
#
# 📂 Rules for 'Fashion_Category=Accessories':
# 👉 IF Fashion_Category=Accessories THEN Reviewer_Type=Frequent AND Verified=Verified
#    - Support: 0.023
#    - Confidence: 0.235
#    - Lift: 1.201
#
# 👉 IF Fashion_Category=Accessories THEN Reviewer_Type=Frequent
#    - Support: 0.045
#    - Confidence: 0.459
#    - Lift: 1.143
#
# 👉 IF Fashion_Category=Accessories THEN Sentiment=Negative
#    - Support: 0.033
#    - Confidence: 0.337
#    - Lift: 1.109
#
# 👉 IF Fashion_Category=Accessories THEN Rating=Low
#    - Support: 0.033
#    - Confidence: 0.337
#    - Lift: 1.109
#
# 👉 IF Fashion_Category=Accessories THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.033
#    - Confidence: 0.337
#    - Lift: 1.109
#
# 👉 IF Fashion_Category=Accessories THEN Review_Length=Long
#    - Support: 0.031
#    - Confidence: 0.316
#    - Lift: 1.088
#
# 👉 IF Fashion_Category=Accessories THEN Verified=Not Verified AND Reviewer_Type=Frequent
#    - Support: 0.022
#    - Confidence: 0.224
#    - Lift: 1.088
#
# 👉 IF Fashion_Category=Accessories THEN Helpfulness=More Helpful
#    - Support: 0.028
#    - Confidence: 0.286
#    - Lift: 1.071
#
# 👉 IF Fashion_Category=Accessories THEN Helpfulness=Less Helpful
#    - Support: 0.036
#    - Confidence: 0.367
#    - Lift: 1.017
#
# 👉 IF Fashion_Category=Accessories THEN Verified=Not Verified
#    - Support: 0.048
#    - Confidence: 0.49
#    - Lift: 1.006
#
# 👉 IF Fashion_Category=Accessories THEN Sentiment=Neutral
#    - Support: 0.029
#    - Confidence: 0.296
#    - Lift: 0.998
#
# 👉 IF Fashion_Category=Accessories THEN Rating=Medium
#    - Support: 0.029
#    - Confidence: 0.296
#    - Lift: 0.998
#
# 👉 IF Fashion_Category=Accessories THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.029
#    - Confidence: 0.296
#    - Lift: 0.998
#
# 👉 IF Fashion_Category=Accessories THEN Verified=Verified
#    - Support: 0.05
#    - Confidence: 0.51
#    - Lift: 0.995
#
# 👉 IF Fashion_Category=Accessories THEN Review_Length=Medium
#    - Support: 0.033
#    - Confidence: 0.337
#    - Lift: 0.99
#
# 👉 IF Fashion_Category=Accessories THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.026
#    - Confidence: 0.265
#    - Lift: 0.945
#
# 👉 IF Fashion_Category=Accessories THEN Review_Length=Short
#    - Support: 0.034
#    - Confidence: 0.347
#    - Lift: 0.94
#
# 👉 IF Fashion_Category=Accessories THEN Helpfulness=None
#    - Support: 0.034
#    - Confidence: 0.347
#    - Lift: 0.933
#
# 👉 IF Fashion_Category=Accessories THEN Sentiment=Positive
#    - Support: 0.036
#    - Confidence: 0.367
#    - Lift: 0.919
#
# 👉 IF Fashion_Category=Accessories THEN Sentiment=Positive AND Rating=High
#    - Support: 0.036
#    - Confidence: 0.367
#    - Lift: 0.919
#
# 👉 IF Fashion_Category=Accessories THEN Rating=High
#    - Support: 0.036
#    - Confidence: 0.367
#    - Lift: 0.919
#
# 👉 IF Fashion_Category=Accessories THEN Reviewer_Type=Infrequent
#    - Support: 0.053
#    - Confidence: 0.541
#    - Lift: 0.904
#
# 👉 IF Fashion_Category=Accessories THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.027
#    - Confidence: 0.276
#    - Lift: 0.868
#
#
# 📂 Rules for 'Fashion_Category=Tops & Tees':
# 👉 IF Fashion_Category=Tops & Tees THEN Reviewer_Type=Frequent AND Verified=Verified
#    - Support: 0.022
#    - Confidence: 0.227
#    - Lift: 1.161
#
# 👉 IF Fashion_Category=Tops & Tees THEN Reviewer_Type=Frequent
#    - Support: 0.044
#    - Confidence: 0.454
#    - Lift: 1.129
#
# 👉 IF Fashion_Category=Tops & Tees THEN Review_Length=Long
#    - Support: 0.031
#    - Confidence: 0.32
#    - Lift: 1.099
#
# 👉 IF Fashion_Category=Tops & Tees THEN Verified=Not Verified AND Reviewer_Type=Frequent
#    - Support: 0.022
#    - Confidence: 0.227
#    - Lift: 1.099
#
# 👉 IF Fashion_Category=Tops & Tees THEN Sentiment=Negative
#    - Support: 0.031
#    - Confidence: 0.32
#    - Lift: 1.053
#
# 👉 IF Fashion_Category=Tops & Tees THEN Rating=Low
#    - Support: 0.031
#    - Confidence: 0.32
#    - Lift: 1.053
#
# 👉 IF Fashion_Category=Tops & Tees THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.031
#    - Confidence: 0.32
#    - Lift: 1.053
#
# 👉 IF Fashion_Category=Tops & Tees THEN Helpfulness=More Helpful
#    - Support: 0.027
#    - Confidence: 0.278
#    - Lift: 1.043
#
# 👉 IF Fashion_Category=Tops & Tees THEN Rating=Medium
#    - Support: 0.03
#    - Confidence: 0.309
#    - Lift: 1.043
#
# 👉 IF Fashion_Category=Tops & Tees THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.03
#    - Confidence: 0.309
#    - Lift: 1.043
#
# 👉 IF Fashion_Category=Tops & Tees THEN Sentiment=Neutral
#    - Support: 0.03
#    - Confidence: 0.309
#    - Lift: 1.043
#
# 👉 IF Fashion_Category=Tops & Tees THEN Helpfulness=Less Helpful
#    - Support: 0.036
#    - Confidence: 0.371
#    - Lift: 1.028
#
# 👉 IF Fashion_Category=Tops & Tees THEN Verified=Not Verified
#    - Support: 0.048
#    - Confidence: 0.495
#    - Lift: 1.016
#
# 👉 IF Fashion_Category=Tops & Tees THEN Verified=Verified
#    - Support: 0.049
#    - Confidence: 0.505
#    - Lift: 0.985
#
# 👉 IF Fashion_Category=Tops & Tees THEN Review_Length=Medium
#    - Support: 0.032
#    - Confidence: 0.33
#    - Lift: 0.969
#
# 👉 IF Fashion_Category=Tops & Tees THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.026
#    - Confidence: 0.268
#    - Lift: 0.955
#
# 👉 IF Fashion_Category=Tops & Tees THEN Review_Length=Short
#    - Support: 0.034
#    - Confidence: 0.351
#    - Lift: 0.95
#
# 👉 IF Fashion_Category=Tops & Tees THEN Helpfulness=None
#    - Support: 0.034
#    - Confidence: 0.351
#    - Lift: 0.942
#
# 👉 IF Fashion_Category=Tops & Tees THEN Sentiment=Positive
#    - Support: 0.036
#    - Confidence: 0.371
#    - Lift: 0.928
#
# 👉 IF Fashion_Category=Tops & Tees THEN Sentiment=Positive AND Rating=High
#    - Support: 0.036
#    - Confidence: 0.371
#    - Lift: 0.928
#
# 👉 IF Fashion_Category=Tops & Tees THEN Rating=High
#    - Support: 0.036
#    - Confidence: 0.371
#    - Lift: 0.928
#
# 👉 IF Fashion_Category=Tops & Tees THEN Reviewer_Type=Infrequent
#    - Support: 0.053
#    - Confidence: 0.546
#    - Lift: 0.913
#
# 👉 IF Fashion_Category=Tops & Tees THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.027
#    - Confidence: 0.278
#    - Lift: 0.877
#
#
# 📂 Rules for 'Fashion_Category=Bottoms':
# 👉 IF Fashion_Category=Bottoms THEN Reviewer_Type=Frequent AND Verified=Verified
#    - Support: 0.02
#    - Confidence: 0.222
#    - Lift: 1.137
#
# 👉 IF Fashion_Category=Bottoms THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.028
#    - Confidence: 0.311
#    - Lift: 1.049
#
# 👉 IF Fashion_Category=Bottoms THEN Sentiment=Neutral
#    - Support: 0.028
#    - Confidence: 0.311
#    - Lift: 1.049
#
# 👉 IF Fashion_Category=Bottoms THEN Rating=Medium
#    - Support: 0.028
#    - Confidence: 0.311
#    - Lift: 1.049
#
# 👉 IF Fashion_Category=Bottoms THEN Helpfulness=More Helpful
#    - Support: 0.025
#    - Confidence: 0.278
#    - Lift: 1.041
#
# 👉 IF Fashion_Category=Bottoms THEN Review_Length=Long
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 1.032
#
# 👉 IF Fashion_Category=Bottoms THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.026
#    - Confidence: 0.289
#    - Lift: 1.029
#
# 👉 IF Fashion_Category=Bottoms THEN Reviewer_Type=Frequent
#    - Support: 0.037
#    - Confidence: 0.411
#    - Lift: 1.023
#
# 👉 IF Fashion_Category=Bottoms THEN Verified=Verified
#    - Support: 0.047
#    - Confidence: 0.522
#    - Lift: 1.018
#
# 👉 IF Fashion_Category=Bottoms THEN Review_Length=Medium
#    - Support: 0.031
#    - Confidence: 0.344
#    - Lift: 1.012
#
# 👉 IF Fashion_Category=Bottoms THEN Rating=High
#    - Support: 0.036
#    - Confidence: 0.4
#    - Lift: 1.0
#
# 👉 IF Fashion_Category=Bottoms THEN Sentiment=Positive
#    - Support: 0.036
#    - Confidence: 0.4
#    - Lift: 1.0
#
# 👉 IF Fashion_Category=Bottoms THEN Sentiment=Positive AND Rating=High
#    - Support: 0.036
#    - Confidence: 0.4
#    - Lift: 1.0
#
# 👉 IF Fashion_Category=Bottoms THEN Helpfulness=None
#    - Support: 0.033
#    - Confidence: 0.367
#    - Lift: 0.986
#
# 👉 IF Fashion_Category=Bottoms THEN Helpfulness=Less Helpful
#    - Support: 0.032
#    - Confidence: 0.356
#    - Lift: 0.985
#
# 👉 IF Fashion_Category=Bottoms THEN Reviewer_Type=Infrequent
#    - Support: 0.053
#    - Confidence: 0.589
#    - Lift: 0.984
#
# 👉 IF Fashion_Category=Bottoms THEN Verified=Not Verified
#    - Support: 0.043
#    - Confidence: 0.478
#    - Lift: 0.981
#
# 👉 IF Fashion_Category=Bottoms THEN Review_Length=Short
#    - Support: 0.032
#    - Confidence: 0.356
#    - Lift: 0.963
#
# 👉 IF Fashion_Category=Bottoms THEN Sentiment=Negative
#    - Support: 0.026
#    - Confidence: 0.289
#    - Lift: 0.952
#
# 👉 IF Fashion_Category=Bottoms THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.026
#    - Confidence: 0.289
#    - Lift: 0.952
#
# 👉 IF Fashion_Category=Bottoms THEN Rating=Low
#    - Support: 0.026
#    - Confidence: 0.289
#    - Lift: 0.952
#
# 👉 IF Fashion_Category=Bottoms THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 0.945
#
#
# 📂 Rules for 'Fashion_Category=Dresses':
# 👉 IF Fashion_Category=Dresses THEN Reviewer_Type=Frequent AND Verified=Verified
#    - Support: 0.023
#    - Confidence: 0.235
#    - Lift: 1.201
#
# 👉 IF Fashion_Category=Dresses THEN Reviewer_Type=Frequent
#    - Support: 0.046
#    - Confidence: 0.469
#    - Lift: 1.168
#
# 👉 IF Fashion_Category=Dresses THEN Verified=Not Verified AND Reviewer_Type=Frequent
#    - Support: 0.023
#    - Confidence: 0.235
#    - Lift: 1.137
#
# 👉 IF Fashion_Category=Dresses THEN Review_Length=Long
#    - Support: 0.032
#    - Confidence: 0.327
#    - Lift: 1.123
#
# 👉 IF Fashion_Category=Dresses THEN Sentiment=Negative
#    - Support: 0.032
#    - Confidence: 0.327
#    - Lift: 1.076
#
# 👉 IF Fashion_Category=Dresses THEN Rating=Low
#    - Support: 0.032
#    - Confidence: 0.327
#    - Lift: 1.076
#
# 👉 IF Fashion_Category=Dresses THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.032
#    - Confidence: 0.327
#    - Lift: 1.076
#
# 👉 IF Fashion_Category=Dresses THEN Helpfulness=More Helpful
#    - Support: 0.028
#    - Confidence: 0.286
#    - Lift: 1.071
#
# 👉 IF Fashion_Category=Dresses THEN Rating=Medium
#    - Support: 0.03
#    - Confidence: 0.306
#    - Lift: 1.032
#
# 👉 IF Fashion_Category=Dresses THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.03
#    - Confidence: 0.306
#    - Lift: 1.032
#
# 👉 IF Fashion_Category=Dresses THEN Sentiment=Neutral
#    - Support: 0.03
#    - Confidence: 0.306
#    - Lift: 1.032
#
# 👉 IF Fashion_Category=Dresses THEN Helpfulness=Less Helpful
#    - Support: 0.036
#    - Confidence: 0.367
#    - Lift: 1.017
#
# 👉 IF Fashion_Category=Dresses THEN Verified=Not Verified
#    - Support: 0.048
#    - Confidence: 0.49
#    - Lift: 1.006
#
# 👉 IF Fashion_Category=Dresses THEN Verified=Verified
#    - Support: 0.05
#    - Confidence: 0.51
#    - Lift: 0.995
#
# 👉 IF Fashion_Category=Dresses THEN Review_Length=Medium
#    - Support: 0.032
#    - Confidence: 0.327
#    - Lift: 0.96
#
# 👉 IF Fashion_Category=Dresses THEN Review_Length=Short
#    - Support: 0.034
#    - Confidence: 0.347
#    - Lift: 0.94
#
# 👉 IF Fashion_Category=Dresses THEN Helpfulness=None
#    - Support: 0.034
#    - Confidence: 0.347
#    - Lift: 0.933
#
# 👉 IF Fashion_Category=Dresses THEN Sentiment=Positive
#    - Support: 0.036
#    - Confidence: 0.367
#    - Lift: 0.919
#
# 👉 IF Fashion_Category=Dresses THEN Sentiment=Positive AND Rating=High
#    - Support: 0.036
#    - Confidence: 0.367
#    - Lift: 0.919
#
# 👉 IF Fashion_Category=Dresses THEN Rating=High
#    - Support: 0.036
#    - Confidence: 0.367
#    - Lift: 0.919
#
# 👉 IF Fashion_Category=Dresses THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.025
#    - Confidence: 0.255
#    - Lift: 0.909
#
# 👉 IF Fashion_Category=Dresses THEN Reviewer_Type=Infrequent
#    - Support: 0.052
#    - Confidence: 0.531
#    - Lift: 0.887
#
# 👉 IF Fashion_Category=Dresses THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.027
#    - Confidence: 0.276
#    - Lift: 0.868
#
#
# 📂 Rules for 'Fashion_Category=Outerwear':
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Review_Length=Long
#    - Support: 0.017
#    - Confidence: 0.21
#    - Lift: 1.137
#
# 👉 IF Fashion_Category=Outerwear THEN Verified=Not Verified AND Helpfulness=None
#    - Support: 0.018
#    - Confidence: 0.222
#    - Lift: 1.131
#
# 👉 IF Fashion_Category=Outerwear THEN Helpfulness=None
#    - Support: 0.034
#    - Confidence: 0.42
#    - Lift: 1.128
#
# 👉 IF Fashion_Category=Outerwear THEN Review_Length=Long
#    - Support: 0.026
#    - Confidence: 0.321
#    - Lift: 1.104
#
# 👉 IF Fashion_Category=Outerwear THEN Rating=Medium
#    - Support: 0.026
#    - Confidence: 0.321
#    - Lift: 1.082
#
# 👉 IF Fashion_Category=Outerwear THEN Rating=Medium AND Sentiment=Neutral
#    - Support: 0.026
#    - Confidence: 0.321
#    - Lift: 1.082
#
# 👉 IF Fashion_Category=Outerwear THEN Sentiment=Neutral
#    - Support: 0.026
#    - Confidence: 0.321
#    - Lift: 1.082
#
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.027
#    - Confidence: 0.333
#    - Lift: 1.05
#
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.018
#    - Confidence: 0.222
#    - Lift: 1.047
#
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Sentiment=Positive AND Rating=High
#    - Support: 0.018
#    - Confidence: 0.222
#    - Lift: 1.023
#
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Sentiment=Positive
#    - Support: 0.018
#    - Confidence: 0.222
#    - Lift: 1.023
#
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.018
#    - Confidence: 0.222
#    - Lift: 1.023
#
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.017
#    - Confidence: 0.21
#    - Lift: 1.022
#
# 👉 IF Fashion_Category=Outerwear THEN Verified=Not Verified AND Reviewer_Type=Frequent
#    - Support: 0.017
#    - Confidence: 0.21
#    - Lift: 1.017
#
# 👉 IF Fashion_Category=Outerwear THEN Review_Length=Medium
#    - Support: 0.028
#    - Confidence: 0.346
#    - Lift: 1.016
#
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent
#    - Support: 0.049
#    - Confidence: 0.605
#    - Lift: 1.011
#
# 👉 IF Fashion_Category=Outerwear THEN Verified=Verified
#    - Support: 0.042
#    - Confidence: 0.519
#    - Lift: 1.011
#
# 👉 IF Fashion_Category=Outerwear THEN Helpfulness=Less Helpful
#    - Support: 0.029
#    - Confidence: 0.358
#    - Lift: 0.991
#
# 👉 IF Fashion_Category=Outerwear THEN Verified=Not Verified
#    - Support: 0.039
#    - Confidence: 0.481
#    - Lift: 0.988
#
# 👉 IF Fashion_Category=Outerwear THEN Sentiment=Positive
#    - Support: 0.032
#    - Confidence: 0.395
#    - Lift: 0.988
#
# 👉 IF Fashion_Category=Outerwear THEN Sentiment=Positive AND Rating=High
#    - Support: 0.032
#    - Confidence: 0.395
#    - Lift: 0.988
#
# 👉 IF Fashion_Category=Outerwear THEN Rating=High
#    - Support: 0.032
#    - Confidence: 0.395
#    - Lift: 0.988
#
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Frequent
#    - Support: 0.032
#    - Confidence: 0.395
#    - Lift: 0.983
#
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Review_Length=Short
#    - Support: 0.017
#    - Confidence: 0.21
#    - Lift: 0.979
#
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.022
#    - Confidence: 0.272
#    - Lift: 0.967
#
# 👉 IF Fashion_Category=Outerwear THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.023
#    - Confidence: 0.284
#    - Lift: 0.935
#
# 👉 IF Fashion_Category=Outerwear THEN Sentiment=Negative
#    - Support: 0.023
#    - Confidence: 0.284
#    - Lift: 0.935
#
# 👉 IF Fashion_Category=Outerwear THEN Rating=Low
#    - Support: 0.023
#    - Confidence: 0.284
#    - Lift: 0.935
#
# 👉 IF Fashion_Category=Outerwear THEN Review_Length=Short
#    - Support: 0.027
#    - Confidence: 0.333
#    - Lift: 0.903
#
# 👉 IF Fashion_Category=Outerwear THEN Helpfulness=More Helpful
#    - Support: 0.018
#    - Confidence: 0.222
#    - Lift: 0.833
#
#
# 📂 Rules for 'Fashion_Category=Ethnic Wear':
# 👉 IF Fashion_Category=Ethnic Wear THEN Reviewer_Type=Infrequent
#    - Support: 0.012
#    - Confidence: 0.923
#    - Lift: 1.543
#
#
# 📂 Rules for 'Fashion_Category=Footwear':
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Review_Length=Long
#    - Support: 0.017
#    - Confidence: 0.23
#    - Lift: 1.245
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Rating=Low AND Sentiment=Negative
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.245
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Sentiment=Negative
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.245
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Rating=Low
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.245
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Review_Length=Medium
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.22
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.025
#    - Confidence: 0.338
#    - Lift: 1.203
#
# 👉 IF Fashion_Category=Footwear THEN Helpfulness=More Helpful AND Reviewer_Type=Infrequent
#    - Support: 0.016
#    - Confidence: 0.216
#    - Lift: 1.198
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.184
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent
#    - Support: 0.052
#    - Confidence: 0.703
#    - Lift: 1.175
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Sentiment=Neutral AND Rating=Medium
#    - Support: 0.016
#    - Confidence: 0.216
#    - Lift: 1.165
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Sentiment=Neutral
#    - Support: 0.016
#    - Confidence: 0.216
#    - Lift: 1.165
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Rating=Medium
#    - Support: 0.016
#    - Confidence: 0.216
#    - Lift: 1.165
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.027
#    - Confidence: 0.365
#    - Lift: 1.149
#
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Positive AND Verified=Not Verified AND Rating=High
#    - Support: 0.017
#    - Confidence: 0.23
#    - Lift: 1.146
#
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Positive AND Verified=Not Verified
#    - Support: 0.017
#    - Confidence: 0.23
#    - Lift: 1.146
#
# 👉 IF Fashion_Category=Footwear THEN Verified=Not Verified AND Rating=High
#    - Support: 0.017
#    - Confidence: 0.23
#    - Lift: 1.146
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.146
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.12
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Sentiment=Positive
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.12
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Sentiment=Positive AND Rating=High
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.12
#
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Positive AND Rating=High
#    - Support: 0.033
#    - Confidence: 0.446
#    - Lift: 1.115
#
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Positive
#    - Support: 0.033
#    - Confidence: 0.446
#    - Lift: 1.115
#
# 👉 IF Fashion_Category=Footwear THEN Rating=High
#    - Support: 0.033
#    - Confidence: 0.446
#    - Lift: 1.115
#
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Positive AND Reviewer_Type=Frequent AND Rating=High
#    - Support: 0.015
#    - Confidence: 0.203
#    - Lift: 1.11
#
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Positive AND Reviewer_Type=Frequent
#    - Support: 0.015
#    - Confidence: 0.203
#    - Lift: 1.11
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Frequent AND Rating=High
#    - Support: 0.015
#    - Confidence: 0.203
#    - Lift: 1.11
#
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.016
#    - Confidence: 0.216
#    - Lift: 1.084
#
# 👉 IF Fashion_Category=Footwear THEN Rating=High AND Verified=Verified
#    - Support: 0.016
#    - Confidence: 0.216
#    - Lift: 1.084
#
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Positive AND Rating=High AND Verified=Verified
#    - Support: 0.016
#    - Confidence: 0.216
#    - Lift: 1.084
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Review_Length=Short
#    - Support: 0.017
#    - Confidence: 0.23
#    - Lift: 1.072
#
# 👉 IF Fashion_Category=Footwear THEN Helpfulness=None
#    - Support: 0.029
#    - Confidence: 0.392
#    - Lift: 1.053
#
# 👉 IF Fashion_Category=Footwear THEN Review_Length=Medium
#    - Support: 0.026
#    - Confidence: 0.351
#    - Lift: 1.033
#
# 👉 IF Fashion_Category=Footwear THEN Review_Length=Short AND Verified=Verified
#    - Support: 0.015
#    - Confidence: 0.203
#    - Lift: 1.032
#
# 👉 IF Fashion_Category=Footwear THEN Verified=Not Verified AND Helpfulness=None
#    - Support: 0.015
#    - Confidence: 0.203
#    - Lift: 1.032
#
# 👉 IF Fashion_Category=Footwear THEN Review_Length=Short
#    - Support: 0.028
#    - Confidence: 0.378
#    - Lift: 1.025
#
# 👉 IF Fashion_Category=Footwear THEN Helpfulness=More Helpful
#    - Support: 0.02
#    - Confidence: 0.27
#    - Lift: 1.013
#
# 👉 IF Fashion_Category=Footwear THEN Verified=Verified
#    - Support: 0.038
#    - Confidence: 0.514
#    - Lift: 1.001
#
# 👉 IF Fashion_Category=Footwear THEN Verified=Not Verified
#    - Support: 0.036
#    - Confidence: 0.486
#    - Lift: 0.999
#
# 👉 IF Fashion_Category=Footwear THEN Helpfulness=Less Helpful
#    - Support: 0.025
#    - Confidence: 0.338
#    - Lift: 0.936
#
# 👉 IF Fashion_Category=Footwear THEN Rating=Low
#    - Support: 0.021
#    - Confidence: 0.284
#    - Lift: 0.935
#
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Negative
#    - Support: 0.021
#    - Confidence: 0.284
#    - Lift: 0.935
#
# 👉 IF Fashion_Category=Footwear THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.021
#    - Confidence: 0.284
#    - Lift: 0.935
#
# 👉 IF Fashion_Category=Footwear THEN Review_Length=Long
#    - Support: 0.02
#    - Confidence: 0.27
#    - Lift: 0.93
#
# 👉 IF Fashion_Category=Footwear THEN Rating=Medium
#    - Support: 0.02
#    - Confidence: 0.27
#    - Lift: 0.911
#
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.02
#    - Confidence: 0.27
#    - Lift: 0.911
#
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Neutral
#    - Support: 0.02
#    - Confidence: 0.27
#    - Lift: 0.911
#
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Frequent
#    - Support: 0.022
#    - Confidence: 0.297
#    - Lift: 0.74
#
#
# 📂 Rules for 'Fashion_Category=Lingerie & Sleepwear':
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Verified=Not Verified AND Reviewer_Type=Frequent
#    - Support: 0.021
#    - Confidence: 0.233
#    - Lift: 1.131
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Reviewer_Type=Frequent
#    - Support: 0.038
#    - Confidence: 0.422
#    - Lift: 1.051
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Verified=Not Verified
#    - Support: 0.046
#    - Confidence: 0.511
#    - Lift: 1.049
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Helpfulness=More Helpful
#    - Support: 0.025
#    - Confidence: 0.278
#    - Lift: 1.041
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Review_Length=Long
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 1.032
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Review_Length=Short
#    - Support: 0.034
#    - Confidence: 0.378
#    - Lift: 1.024
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Helpfulness=Less Helpful
#    - Support: 0.033
#    - Confidence: 0.367
#    - Lift: 1.015
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Rating=Medium
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 1.011
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 1.011
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Sentiment=Neutral
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 1.011
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Sentiment=Positive AND Rating=High
#    - Support: 0.036
#    - Confidence: 0.4
#    - Lift: 1.0
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Rating=High
#    - Support: 0.036
#    - Confidence: 0.4
#    - Lift: 1.0
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Sentiment=Positive
#    - Support: 0.036
#    - Confidence: 0.4
#    - Lift: 1.0
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.025
#    - Confidence: 0.278
#    - Lift: 0.989
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 0.988
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Sentiment=Negative
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 0.988
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Rating=Low
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 0.988
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Reviewer_Type=Infrequent
#    - Support: 0.052
#    - Confidence: 0.578
#    - Lift: 0.966
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Helpfulness=None
#    - Support: 0.032
#    - Confidence: 0.356
#    - Lift: 0.956
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Verified=Verified
#    - Support: 0.044
#    - Confidence: 0.489
#    - Lift: 0.953
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Review_Length=Medium
#    - Support: 0.029
#    - Confidence: 0.322
#    - Lift: 0.947
#
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 0.945
#
#
# 📂 Rules for 'Fashion_Category=Activewear':
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent AND Sentiment=Positive AND Rating=High
#    - Support: 0.017
#    - Confidence: 0.395
#    - Lift: 1.82
#
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent AND Sentiment=Positive
#    - Support: 0.017
#    - Confidence: 0.395
#    - Lift: 1.82
#
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.017
#    - Confidence: 0.395
#    - Lift: 1.82
#
# 👉 IF Fashion_Category=Activewear THEN Sentiment=Positive AND Verified=Not Verified AND Rating=High
#    - Support: 0.014
#    - Confidence: 0.326
#    - Lift: 1.625
#
# 👉 IF Fashion_Category=Activewear THEN Sentiment=Positive AND Verified=Not Verified
#    - Support: 0.014
#    - Confidence: 0.326
#    - Lift: 1.625
#
# 👉 IF Fashion_Category=Activewear THEN Verified=Not Verified AND Rating=High
#    - Support: 0.014
#    - Confidence: 0.326
#    - Lift: 1.625
#
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent AND Review_Length=Short
#    - Support: 0.014
#    - Confidence: 0.326
#    - Lift: 1.519
#
# 👉 IF Fashion_Category=Activewear THEN Sentiment=Positive AND Rating=High
#    - Support: 0.025
#    - Confidence: 0.581
#    - Lift: 1.454
#
# 👉 IF Fashion_Category=Activewear THEN Rating=High
#    - Support: 0.025
#    - Confidence: 0.581
#    - Lift: 1.454
#
# 👉 IF Fashion_Category=Activewear THEN Sentiment=Positive
#    - Support: 0.025
#    - Confidence: 0.581
#    - Lift: 1.454
#
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.013
#    - Confidence: 0.302
#    - Lift: 1.424
#
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.019
#    - Confidence: 0.442
#    - Lift: 1.392
#
# 👉 IF Fashion_Category=Activewear THEN Review_Length=Short AND Verified=Verified
#    - Support: 0.011
#    - Confidence: 0.256
#    - Lift: 1.302
#
# 👉 IF Fashion_Category=Activewear THEN Rating=High AND Verified=Verified
#    - Support: 0.011
#    - Confidence: 0.256
#    - Lift: 1.283
#
# 👉 IF Fashion_Category=Activewear THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.011
#    - Confidence: 0.256
#    - Lift: 1.283
#
# 👉 IF Fashion_Category=Activewear THEN Sentiment=Positive AND Rating=High AND Verified=Verified
#    - Support: 0.011
#    - Confidence: 0.256
#    - Lift: 1.283
#
# 👉 IF Fashion_Category=Activewear THEN Review_Length=Short
#    - Support: 0.02
#    - Confidence: 0.465
#    - Lift: 1.26
#
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.011
#    - Confidence: 0.256
#    - Lift: 1.246
#
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent
#    - Support: 0.032
#    - Confidence: 0.744
#    - Lift: 1.244
#
# 👉 IF Fashion_Category=Activewear THEN Helpfulness=None
#    - Support: 0.018
#    - Confidence: 0.419
#    - Lift: 1.125
#
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.013
#    - Confidence: 0.302
#    - Lift: 1.077
#
# 👉 IF Fashion_Category=Activewear THEN Helpfulness=Less Helpful
#    - Support: 0.016
#    - Confidence: 0.372
#    - Lift: 1.03
#
# 👉 IF Fashion_Category=Activewear THEN Verified=Not Verified
#    - Support: 0.021
#    - Confidence: 0.488
#    - Lift: 1.003
#
# 👉 IF Fashion_Category=Activewear THEN Verified=Verified
#    - Support: 0.022
#    - Confidence: 0.512
#    - Lift: 0.998
#
# 👉 IF Fashion_Category=Activewear THEN Review_Length=Medium
#    - Support: 0.013
#    - Confidence: 0.302
#    - Lift: 0.888
#
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Frequent
#    - Support: 0.011
#    - Confidence: 0.256
#    - Lift: 0.637
#
#
# 📂 Rules for 'Fashion_Category=Kidswear':
# 👉 IF Fashion_Category=Kidswear THEN Verified=Not Verified AND Helpfulness=Less Helpful
#    - Support: 0.016
#    - Confidence: 0.222
#    - Lift: 1.251
#
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.018
#    - Confidence: 0.25
#    - Lift: 1.217
#
# 👉 IF Fashion_Category=Kidswear THEN Helpfulness=Less Helpful
#    - Support: 0.03
#    - Confidence: 0.417
#    - Lift: 1.154
#
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Sentiment=Negative
#    - Support: 0.016
#    - Confidence: 0.222
#    - Lift: 1.137
#
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Rating=Low
#    - Support: 0.016
#    - Confidence: 0.222
#    - Lift: 1.137
#
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Rating=Low AND Sentiment=Negative
#    - Support: 0.016
#    - Confidence: 0.222
#    - Lift: 1.137
#
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Review_Length=Medium
#    - Support: 0.016
#    - Confidence: 0.222
#    - Lift: 1.114
#
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Review_Length=Short
#    - Support: 0.017
#    - Confidence: 0.236
#    - Lift: 1.102
#
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.025
#    - Confidence: 0.347
#    - Lift: 1.094
#
# 👉 IF Fashion_Category=Kidswear THEN Review_Length=Short
#    - Support: 0.029
#    - Confidence: 0.403
#    - Lift: 1.091
#
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Sentiment=Positive
#    - Support: 0.017
#    - Confidence: 0.236
#    - Lift: 1.087
#
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.017
#    - Confidence: 0.236
#    - Lift: 1.087
#
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Sentiment=Positive AND Rating=High
#    - Support: 0.017
#    - Confidence: 0.236
#    - Lift: 1.087
#
# 👉 IF Fashion_Category=Kidswear THEN Verified=Not Verified AND Reviewer_Type=Frequent
#    - Support: 0.016
#    - Confidence: 0.222
#    - Lift: 1.077
#
# 👉 IF Fashion_Category=Kidswear THEN Review_Length=Medium
#    - Support: 0.026
#    - Confidence: 0.361
#    - Lift: 1.061
#
# 👉 IF Fashion_Category=Kidswear THEN Review_Length=Short AND Verified=Verified
#    - Support: 0.015
#    - Confidence: 0.208
#    - Lift: 1.061
#
# 👉 IF Fashion_Category=Kidswear THEN Verified=Not Verified AND Helpfulness=None
#    - Support: 0.015
#    - Confidence: 0.208
#    - Lift: 1.061
#
# 👉 IF Fashion_Category=Kidswear THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.023
#    - Confidence: 0.319
#    - Lift: 1.052
#
# 👉 IF Fashion_Category=Kidswear THEN Rating=Low
#    - Support: 0.023
#    - Confidence: 0.319
#    - Lift: 1.052
#
# 👉 IF Fashion_Category=Kidswear THEN Sentiment=Negative
#    - Support: 0.023
#    - Confidence: 0.319
#    - Lift: 1.052
#
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent
#    - Support: 0.045
#    - Confidence: 0.625
#    - Lift: 1.045
#
# 👉 IF Fashion_Category=Kidswear THEN Sentiment=Positive AND Verified=Not Verified
#    - Support: 0.015
#    - Confidence: 0.208
#    - Lift: 1.04
#
# 👉 IF Fashion_Category=Kidswear THEN Sentiment=Positive AND Verified=Not Verified AND Rating=High
#    - Support: 0.015
#    - Confidence: 0.208
#    - Lift: 1.04
#
# 👉 IF Fashion_Category=Kidswear THEN Verified=Not Verified AND Rating=High
#    - Support: 0.015
#    - Confidence: 0.208
#    - Lift: 1.04
#
# 👉 IF Fashion_Category=Kidswear THEN Verified=Not Verified
#    - Support: 0.036
#    - Confidence: 0.5
#    - Lift: 1.026
#
# 👉 IF Fashion_Category=Kidswear THEN Helpfulness=None
#    - Support: 0.027
#    - Confidence: 0.375
#    - Lift: 1.008
#
# 👉 IF Fashion_Category=Kidswear THEN Rating=High
#    - Support: 0.029
#    - Confidence: 0.403
#    - Lift: 1.007
#
# 👉 IF Fashion_Category=Kidswear THEN Sentiment=Positive AND Rating=High
#    - Support: 0.029
#    - Confidence: 0.403
#    - Lift: 1.007
#
# 👉 IF Fashion_Category=Kidswear THEN Sentiment=Positive
#    - Support: 0.029
#    - Confidence: 0.403
#    - Lift: 1.007
#
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.02
#    - Confidence: 0.278
#    - Lift: 0.989
#
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.015
#    - Confidence: 0.208
#    - Lift: 0.981
#
# 👉 IF Fashion_Category=Kidswear THEN Verified=Verified
#    - Support: 0.036
#    - Confidence: 0.5
#    - Lift: 0.975
#
# 👉 IF Fashion_Category=Kidswear THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.02
#    - Confidence: 0.278
#    - Lift: 0.936
#
# 👉 IF Fashion_Category=Kidswear THEN Rating=Medium
#    - Support: 0.02
#    - Confidence: 0.278
#    - Lift: 0.936
#
# 👉 IF Fashion_Category=Kidswear THEN Sentiment=Neutral
#    - Support: 0.02
#    - Confidence: 0.278
#    - Lift: 0.936
#
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Frequent
#    - Support: 0.027
#    - Confidence: 0.375
#    - Lift: 0.933
#
# 👉 IF Fashion_Category=Kidswear THEN Review_Length=Long
#    - Support: 0.017
#    - Confidence: 0.236
#    - Lift: 0.812
#
# 👉 IF Fashion_Category=Kidswear THEN Helpfulness=More Helpful
#    - Support: 0.015
#    - Confidence: 0.208
#    - Lift: 0.781
#
#
# 📂 Rules for 'Fashion_Category=Menswear':
# 👉 IF Fashion_Category=Menswear THEN Helpfulness=More Helpful AND Reviewer_Type=Infrequent
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.12
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Review_Length=Long
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.096
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Sentiment=Neutral AND Rating=Medium
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.09
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Rating=Medium
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.09
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Sentiment=Neutral
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.09
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.027
#    - Confidence: 0.303
#    - Lift: 1.081
#
# 👉 IF Fashion_Category=Menswear THEN Verified=Not Verified
#    - Support: 0.045
#    - Confidence: 0.506
#    - Lift: 1.038
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Sentiment=Negative
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.035
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Rating=Low
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.035
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Rating=Low AND Sentiment=Negative
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.035
#
# 👉 IF Fashion_Category=Menswear THEN Verified=Not Verified AND Helpfulness=None
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.03
#
# 👉 IF Fashion_Category=Menswear THEN Helpfulness=None
#    - Support: 0.034
#    - Confidence: 0.382
#    - Lift: 1.027
#
# 👉 IF Fashion_Category=Menswear THEN Review_Length=Medium
#    - Support: 0.031
#    - Confidence: 0.348
#    - Lift: 1.024
#
# 👉 IF Fashion_Category=Menswear THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.027
#    - Confidence: 0.303
#    - Lift: 1.023
#
# 👉 IF Fashion_Category=Menswear THEN Rating=Medium
#    - Support: 0.027
#    - Confidence: 0.303
#    - Lift: 1.023
#
# 👉 IF Fashion_Category=Menswear THEN Sentiment=Neutral
#    - Support: 0.027
#    - Confidence: 0.303
#    - Lift: 1.023
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent
#    - Support: 0.054
#    - Confidence: 0.607
#    - Lift: 1.014
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Review_Length=Medium
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.014
#
# 👉 IF Fashion_Category=Menswear THEN Helpfulness=More Helpful
#    - Support: 0.024
#    - Confidence: 0.27
#    - Lift: 1.01
#
# 👉 IF Fashion_Category=Menswear THEN Sentiment=Positive AND Verified=Not Verified AND Rating=High
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.009
#
# 👉 IF Fashion_Category=Menswear THEN Sentiment=Positive AND Verified=Not Verified
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.009
#
# 👉 IF Fashion_Category=Menswear THEN Verified=Not Verified AND Rating=High
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.009
#
# 👉 IF Fashion_Category=Menswear THEN Review_Length=Short
#    - Support: 0.033
#    - Confidence: 0.371
#    - Lift: 1.005
#
# 👉 IF Fashion_Category=Menswear THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.027
#    - Confidence: 0.303
#    - Lift: 0.999
#
# 👉 IF Fashion_Category=Menswear THEN Rating=Low
#    - Support: 0.027
#    - Confidence: 0.303
#    - Lift: 0.999
#
# 👉 IF Fashion_Category=Menswear THEN Sentiment=Negative
#    - Support: 0.027
#    - Confidence: 0.303
#    - Lift: 0.999
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 0.985
#
# 👉 IF Fashion_Category=Menswear THEN Rating=High
#    - Support: 0.035
#    - Confidence: 0.393
#    - Lift: 0.984
#
# 👉 IF Fashion_Category=Menswear THEN Sentiment=Positive AND Rating=High
#    - Support: 0.035
#    - Confidence: 0.393
#    - Lift: 0.984
#
# 👉 IF Fashion_Category=Menswear THEN Sentiment=Positive
#    - Support: 0.035
#    - Confidence: 0.393
#    - Lift: 0.984
#
# 👉 IF Fashion_Category=Menswear THEN Verified=Not Verified AND Reviewer_Type=Frequent
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 0.98
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Frequent
#    - Support: 0.035
#    - Confidence: 0.393
#    - Lift: 0.979
#
# 👉 IF Fashion_Category=Menswear THEN Review_Length=Long
#    - Support: 0.025
#    - Confidence: 0.281
#    - Lift: 0.966
#
# 👉 IF Fashion_Category=Menswear THEN Helpfulness=Less Helpful
#    - Support: 0.031
#    - Confidence: 0.348
#    - Lift: 0.965
#
# 👉 IF Fashion_Category=Menswear THEN Verified=Verified
#    - Support: 0.044
#    - Confidence: 0.494
#    - Lift: 0.964
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.027
#    - Confidence: 0.303
#    - Lift: 0.956
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 0.953
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Review_Length=Short
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 0.944
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Sentiment=Positive
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 0.931
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Sentiment=Positive AND Rating=High
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 0.931
#
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 0.931
#
#
# 📂 Rules for 'Fashion_Category=Womenswear':
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Review_Length=Medium
#    - Support: 0.016
#    - Confidence: 0.291
#    - Lift: 1.459
#
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.017
#    - Confidence: 0.309
#    - Lift: 1.456
#
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Sentiment=Positive AND Rating=High
#    - Support: 0.017
#    - Confidence: 0.309
#    - Lift: 1.423
#
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Sentiment=Positive
#    - Support: 0.017
#    - Confidence: 0.309
#    - Lift: 1.423
#
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.017
#    - Confidence: 0.309
#    - Lift: 1.423
#
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Review_Length=Short
#    - Support: 0.016
#    - Confidence: 0.291
#    - Lift: 1.358
#
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.015
#    - Confidence: 0.273
#    - Lift: 1.328
#
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.023
#    - Confidence: 0.418
#    - Lift: 1.317
#
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent
#    - Support: 0.042
#    - Confidence: 0.764
#    - Lift: 1.277
#
# 👉 IF Fashion_Category=Womenswear THEN Rating=High AND Verified=Verified
#    - Support: 0.014
#    - Confidence: 0.255
#    - Lift: 1.277
#
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.014
#    - Confidence: 0.255
#    - Lift: 1.277
#
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Positive AND Rating=High AND Verified=Verified
#    - Support: 0.014
#    - Confidence: 0.255
#    - Lift: 1.277
#
# 👉 IF Fashion_Category=Womenswear THEN Review_Length=Medium AND Verified=Verified
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.236
#
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.019
#    - Confidence: 0.345
#    - Lift: 1.23
#
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Rating=Low AND Sentiment=Negative
#    - Support: 0.013
#    - Confidence: 0.236
#    - Lift: 1.209
#
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Rating=Low
#    - Support: 0.013
#    - Confidence: 0.236
#    - Lift: 1.209
#
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Sentiment=Negative
#    - Support: 0.013
#    - Confidence: 0.236
#    - Lift: 1.209
#
# 👉 IF Fashion_Category=Womenswear THEN Review_Length=Short AND Verified=Verified
#    - Support: 0.013
#    - Confidence: 0.236
#    - Lift: 1.203
#
# 👉 IF Fashion_Category=Womenswear THEN Helpfulness=Less Helpful AND Verified=Verified
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.189
#
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Positive
#    - Support: 0.026
#    - Confidence: 0.473
#    - Lift: 1.182
#
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Positive AND Rating=High
#    - Support: 0.026
#    - Confidence: 0.473
#    - Lift: 1.182
#
# 👉 IF Fashion_Category=Womenswear THEN Rating=High
#    - Support: 0.026
#    - Confidence: 0.473
#    - Lift: 1.182
#
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Sentiment=Neutral AND Rating=Medium
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.176
#
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Rating=Medium
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.176
#
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Sentiment=Neutral
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.176
#
# 👉 IF Fashion_Category=Womenswear THEN Review_Length=Medium
#    - Support: 0.022
#    - Confidence: 0.4
#    - Lift: 1.176
#
# 👉 IF Fashion_Category=Womenswear THEN Verified=Not Verified AND Helpfulness=None
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.111
#
# 👉 IF Fashion_Category=Womenswear THEN Verified=Verified
#    - Support: 0.031
#    - Confidence: 0.564
#    - Lift: 1.099
#
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Positive AND Verified=Not Verified AND Rating=High
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.089
#
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Positive AND Verified=Not Verified
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.089
#
# 👉 IF Fashion_Category=Womenswear THEN Verified=Not Verified AND Rating=High
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.089
#
# 👉 IF Fashion_Category=Womenswear THEN Review_Length=Short
#    - Support: 0.022
#    - Confidence: 0.4
#    - Lift: 1.084
#
# 👉 IF Fashion_Category=Womenswear THEN Helpfulness=None
#    - Support: 0.022
#    - Confidence: 0.4
#    - Lift: 1.075
#
# 👉 IF Fashion_Category=Womenswear THEN Helpfulness=Less Helpful
#    - Support: 0.021
#    - Confidence: 0.382
#    - Lift: 1.057
#
# 👉 IF Fashion_Category=Womenswear THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.015
#    - Confidence: 0.273
#    - Lift: 0.898
#
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Negative
#    - Support: 0.015
#    - Confidence: 0.273
#    - Lift: 0.898
#
# 👉 IF Fashion_Category=Womenswear THEN Rating=Low
#    - Support: 0.015
#    - Confidence: 0.273
#    - Lift: 0.898
#
# 👉 IF Fashion_Category=Womenswear THEN Verified=Not Verified
#    - Support: 0.024
#    - Confidence: 0.436
#    - Lift: 0.896
#
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.014
#    - Confidence: 0.255
#    - Lift: 0.858
#
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Neutral
#    - Support: 0.014
#    - Confidence: 0.255
#    - Lift: 0.858
#
# 👉 IF Fashion_Category=Womenswear THEN Rating=Medium
#    - Support: 0.014
#    - Confidence: 0.255
#    - Lift: 0.858
#
# 👉 IF Fashion_Category=Womenswear THEN Helpfulness=More Helpful
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 0.818
#
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Frequent
#    - Support: 0.013
#    - Confidence: 0.236
#    - Lift: 0.588

# %%
from mlxtend.frequent_patterns import apriori, association_rules
import pandas as pd
import os

# Run Apriori (adjust thresholds as needed)
frequent_itemsets = apriori(df_trans, min_support=0.01, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)

# Create output directory
os.makedirs("verified_status_rules", exist_ok=True)

# Define verified status values (fix column names)
verified_statuses = ['Verified=Verified', 'Verified=Not Verified']

print("\n🔍 Generating Discrimination Rules Based on Verified_Status\n")

for status_tag in verified_statuses:
    print(f"\n📁 Rules for '{status_tag}':")
    
    # Only include rules where that status is the only antecedent
    status_rules = rules[rules['antecedents'].apply(
        lambda x: status_tag in x and len(x) == 1
    )].sort_values(by='lift', ascending=False)
    
    if not status_rules.empty:
        for _, row in status_rules.iterrows():
            antecedent = ' AND '.join(list(row['antecedents']))
            consequent = ' AND '.join(list(row['consequents']))
            print(f"👉 IF {antecedent} THEN {consequent}")
            print(f"   - Support: {round(row['support'], 3)}")
            print(f"   - Confidence: {round(row['confidence'], 3)}")
            print(f"   - Lift: {round(row['lift'], 3)}\n")

        # Save to CSV
        summary_df = status_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].copy()
        summary_df['antecedents'] = summary_df['antecedents'].apply(lambda x: ' AND '.join(x))
        summary_df['consequents'] = summary_df['consequents'].apply(lambda x: ' AND '.join(x))
        filename = status_tag.replace("=", "_") + "_rules_summary.csv"
        summary_df.to_csv(f"verified_status_rules/{filename}", index=False)
    else:
        print(f"❌ No rules generated for status '{status_tag}'.")
# Out:
# 🔍 Generating Discrimination Rules Based on Verified_Status
#
#
# 📁 Rules for 'Verified=Verified':
# 👉 IF Verified=Verified THEN Helpfulness=More Helpful
#    - Support: 0.154
#    - Confidence: 0.3
#    - Lift: 1.123
#
# 👉 IF Verified=Verified THEN Helpfulness=More Helpful AND Reviewer_Type=Infrequent
#    - Support: 0.103
#    - Confidence: 0.201
#    - Lift: 1.114
#
# 👉 IF Verified=Verified THEN Reviewer_Type=Infrequent AND Sentiment=Neutral AND Rating=Medium
#    - Support: 0.103
#    - Confidence: 0.201
#    - Lift: 1.084
#
# 👉 IF Verified=Verified THEN Reviewer_Type=Infrequent AND Sentiment=Neutral
#    - Support: 0.103
#    - Confidence: 0.201
#    - Lift: 1.084
#
# 👉 IF Verified=Verified THEN Reviewer_Type=Infrequent AND Rating=Medium
#    - Support: 0.103
#    - Confidence: 0.201
#    - Lift: 1.084
#
# 👉 IF Verified=Verified THEN Reviewer_Type=Infrequent AND Review_Length=Medium
#    - Support: 0.107
#    - Confidence: 0.209
#    - Lift: 1.048
#
# 👉 IF Verified=Verified THEN Review_Length=Short
#    - Support: 0.196
#    - Confidence: 0.383
#    - Lift: 1.038
#
# 👉 IF Verified=Verified THEN Reviewer_Type=Infrequent
#    - Support: 0.317
#    - Confidence: 0.619
#    - Lift: 1.035
#
# 👉 IF Verified=Verified THEN Rating=Medium
#    - Support: 0.157
#    - Confidence: 0.306
#    - Lift: 1.03
#
# 👉 IF Verified=Verified THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.157
#    - Confidence: 0.306
#    - Lift: 1.03
#
# 👉 IF Verified=Verified THEN Sentiment=Neutral
#    - Support: 0.157
#    - Confidence: 0.306
#    - Lift: 1.03
#
# 👉 IF Verified=Verified THEN Reviewer_Type=Infrequent AND Review_Length=Short
#    - Support: 0.113
#    - Confidence: 0.221
#    - Lift: 1.029
#
# 👉 IF Verified=Verified THEN Review_Length=Medium
#    - Support: 0.177
#    - Confidence: 0.344
#    - Lift: 1.012
#
# 👉 IF Verified=Verified THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.106
#    - Confidence: 0.207
#    - Lift: 1.008
#
# 👉 IF Verified=Verified THEN Sentiment=Negative
#    - Support: 0.157
#    - Confidence: 0.306
#    - Lift: 1.007
#
# 👉 IF Verified=Verified THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.157
#    - Confidence: 0.306
#    - Lift: 1.007
#
# 👉 IF Verified=Verified THEN Rating=Low
#    - Support: 0.157
#    - Confidence: 0.306
#    - Lift: 1.007
#
# 👉 IF Verified=Verified THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.112
#    - Confidence: 0.219
#    - Lift: 1.006
#
# 👉 IF Verified=Verified THEN Reviewer_Type=Infrequent AND Sentiment=Positive
#    - Support: 0.112
#    - Confidence: 0.219
#    - Lift: 1.006
#
# 👉 IF Verified=Verified THEN Reviewer_Type=Infrequent AND Sentiment=Positive AND Rating=High
#    - Support: 0.112
#    - Confidence: 0.219
#    - Lift: 1.006
#
# 👉 IF Verified=Verified THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.108
#    - Confidence: 0.211
#    - Lift: 0.993
#
# 👉 IF Verified=Verified THEN Helpfulness=Less Helpful
#    - Support: 0.184
#    - Confidence: 0.358
#    - Lift: 0.991
#
# 👉 IF Verified=Verified THEN Sentiment=Positive
#    - Support: 0.199
#    - Confidence: 0.389
#    - Lift: 0.972
#
# 👉 IF Verified=Verified THEN Sentiment=Positive AND Rating=High
#    - Support: 0.199
#    - Confidence: 0.389
#    - Lift: 0.972
#
# 👉 IF Verified=Verified THEN Rating=High
#    - Support: 0.199
#    - Confidence: 0.389
#    - Lift: 0.972
#
# 👉 IF Verified=Verified THEN Reviewer_Type=Frequent
#    - Support: 0.195
#    - Confidence: 0.381
#    - Lift: 0.948
#
# 👉 IF Verified=Verified THEN Review_Length=Long
#    - Support: 0.14
#    - Confidence: 0.273
#    - Lift: 0.938
#
# 👉 IF Verified=Verified THEN Helpfulness=None
#    - Support: 0.176
#    - Confidence: 0.342
#    - Lift: 0.92
#
#
# 📁 Rules for 'Verified=Not Verified':
# 👉 IF Verified=Not Verified THEN Helpfulness=None
#    - Support: 0.196
#    - Confidence: 0.403
#    - Lift: 1.084
#
# 👉 IF Verified=Not Verified THEN Review_Length=Long
#    - Support: 0.151
#    - Confidence: 0.31
#    - Lift: 1.065
#
# 👉 IF Verified=Not Verified THEN Reviewer_Type=Frequent
#    - Support: 0.206
#    - Confidence: 0.424
#    - Lift: 1.054
#
# 👉 IF Verified=Not Verified THEN Sentiment=Positive
#    - Support: 0.2
#    - Confidence: 0.411
#    - Lift: 1.029
#
# 👉 IF Verified=Not Verified THEN Rating=High
#    - Support: 0.2
#    - Confidence: 0.411
#    - Lift: 1.029
#
# 👉 IF Verified=Not Verified THEN Sentiment=Positive AND Rating=High
#    - Support: 0.2
#    - Confidence: 0.411
#    - Lift: 1.029
#
# 👉 IF Verified=Not Verified THEN Helpfulness=Less Helpful
#    - Support: 0.178
#    - Confidence: 0.365
#    - Lift: 1.01
#
# 👉 IF Verified=Not Verified THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.104
#    - Confidence: 0.214
#    - Lift: 1.007
#
# 👉 IF Verified=Not Verified THEN Reviewer_Type=Infrequent AND Sentiment=Positive
#    - Support: 0.105
#    - Confidence: 0.216
#    - Lift: 0.994
#
# 👉 IF Verified=Not Verified THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.105
#    - Confidence: 0.216
#    - Lift: 0.994
#
# 👉 IF Verified=Not Verified THEN Reviewer_Type=Infrequent AND Sentiment=Positive AND Rating=High
#    - Support: 0.105
#    - Confidence: 0.216
#    - Lift: 0.994
#
# 👉 IF Verified=Not Verified THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.147
#    - Confidence: 0.301
#    - Lift: 0.993
#
# 👉 IF Verified=Not Verified THEN Rating=Low
#    - Support: 0.147
#    - Confidence: 0.301
#    - Lift: 0.993
#
# 👉 IF Verified=Not Verified THEN Sentiment=Negative
#    - Support: 0.147
#    - Confidence: 0.301
#    - Lift: 0.993
#
# 👉 IF Verified=Not Verified THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.099
#    - Confidence: 0.204
#    - Lift: 0.992
#
# 👉 IF Verified=Not Verified THEN Review_Length=Medium
#    - Support: 0.164
#    - Confidence: 0.336
#    - Lift: 0.988
#
# 👉 IF Verified=Not Verified THEN Reviewer_Type=Infrequent AND Review_Length=Short
#    - Support: 0.101
#    - Confidence: 0.208
#    - Lift: 0.969
#
# 👉 IF Verified=Not Verified THEN Sentiment=Neutral
#    - Support: 0.14
#    - Confidence: 0.287
#    - Lift: 0.968
#
# 👉 IF Verified=Not Verified THEN Rating=Medium
#    - Support: 0.14
#    - Confidence: 0.287
#    - Lift: 0.968
#
# 👉 IF Verified=Not Verified THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.14
#    - Confidence: 0.287
#    - Lift: 0.968
#
# 👉 IF Verified=Not Verified THEN Reviewer_Type=Infrequent
#    - Support: 0.281
#    - Confidence: 0.576
#    - Lift: 0.963
#
# 👉 IF Verified=Not Verified THEN Review_Length=Short
#    - Support: 0.173
#    - Confidence: 0.354
#    - Lift: 0.96
#
# 👉 IF Verified=Not Verified THEN Helpfulness=More Helpful
#    - Support: 0.113
#    - Confidence: 0.232
#    - Lift: 0.87

# %%
df_trans
# Out:
#       Fashion_Category=Accessories  Fashion_Category=Activewear  \
# 0                             True                        False
# 1                             True                        False
# 2                             True                        False
# 3                             True                        False
# 4                             True                        False
# ...                            ...                          ...
# 1003                         False                        False
# 1004                         False                        False
# 1005                         False                        False
# 1006                         False                        False
# 1007                         False                        False
#
#       Fashion_Category=Bottoms  Fashion_Category=Dresses  \
# 0                        False                     False
# 1                        False                     False
# 2                        False                     False
# 3                        False                     False
# 4                        False                     False
# ...                        ...                       ...
# 1003                     False                     False
# 1004                     False                     False
# 1005                     False                     False
# 1006                     False                     False
# 1007                     False                     False
#
#       Fashion_Category=Ethnic Wear  Fashion_Category=Footwear  \
# 0                            False                      False
# 1                            False                      False
# 2                            False                      False
# 3                            False                      False
# 4                            False                      False
# ...                            ...                        ...
# 1003                         False                      False
# 1004                         False                      False
# 1005                         False                      False
# 1006                         False                      False
# 1007                         False                      False
#
#       Fashion_Category=Kidswear  Fashion_Category=Lingerie & Sleepwear  \
# 0                         False                                  False
# 1                         False                                  False
# 2                         False                                  False
# 3                         False                                  False
# 4                         False                                  False
# ...                         ...                                    ...
# 1003                      False                                  False
# 1004                      False                                  False
# 1005                      False                                  False
# 1006                      False                                  False
# 1007                      False                                  False
#
#       Fashion_Category=Menswear  Fashion_Category=Outerwear  ...  \
# 0                         False                       False  ...
# 1                         False                       False  ...
# 2                         False                       False  ...
# 3                         False                       False  ...
# 4                         False                       False  ...
# ...                         ...                         ...  ...
# 1003                      False                       False  ...
# 1004                      False                       False  ...
# 1005                      False                       False  ...
# 1006                      False                       False  ...
# 1007                      False                       False  ...
#
#       Review_Length=Long  Review_Length=Medium  Review_Length=Short  \
# 0                   True                 False                False
# 1                   True                 False                False
# 2                   True                 False                False
# 3                   True                 False                False
# 4                   True                 False                False
# ...                  ...                   ...                  ...
# 1003               False                  True                False
# 1004               False                 False                 True
# 1005               False                 False                 True
# 1006               False                 False                 True
# 1007               False                 False                 True
#
#       Reviewer_Type=Frequent  Reviewer_Type=Infrequent  Sentiment=Negative  \
# 0                       True                     False               False
# 1                       True                     False               False
# 2                       True                     False               False
# 3                       True                     False               False
# 4                       True                     False               False
# ...                      ...                       ...                 ...
# 1003                   False                      True               False
# 1004                   False                      True               False
# 1005                   False                      True               False
# 1006                   False                      True               False
# 1007                   False                      True               False
#
#       Sentiment=Neutral  Sentiment=Positive  Verified=Not Verified  \
# 0                 False                True                   True
# 1                 False                True                  False
# 2                 False                True                   True
# 3                 False                True                  False
# 4                 False                True                   True
# ...                 ...                 ...                    ...
# 1003               True               False                  False
# 1004               True               False                  False
# 1005               True               False                  False
# 1006               True               False                   True
# 1007               True               False                  False
#
#       Verified=Verified
# 0                 False
# 1                  True
# 2                 False
# 3                  True
# 4                 False
# ...                 ...
# 1003               True
# 1004               True
# 1005               True
# 1006              False
# 1007               True
#
# [1008 rows x 29 columns]

# %%
from mlxtend.frequent_patterns import apriori, association_rules
import pandas as pd
import os

# Run Apriori (adjust thresholds as needed)
frequent_itemsets = apriori(df_trans, min_support=0.01, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)

# Create output directory
os.makedirs("review_length_rules", exist_ok=True)

# Define review length categories
review_lengths = ['Review_Length=Short', 'Review_Length=Long']

print("\n📝 Generating Discrimination Rules Based on Review_Length\n")

for length_tag in review_lengths:
    print(f"\n📁 Rules for '{length_tag}':")
    
    # Filter rules where the only antecedent is review length
    length_rules = rules[rules['antecedents'].apply(
        lambda x: length_tag in x and len(x) == 1
    )].sort_values(by='lift', ascending=False)
    
    if not length_rules.empty:
        for _, row in length_rules.iterrows():
            antecedent = ' AND '.join(list(row['antecedents']))
            consequent = ' AND '.join(list(row['consequents']))
            print(f"👉 IF {antecedent} THEN {consequent}")
            print(f"   - Support: {round(row['support'], 3)}")
            print(f"   - Confidence: {round(row['confidence'], 3)}")
            print(f"   - Lift: {round(row['lift'], 3)}\n")

        # Save to CSV
        summary_df = length_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].copy()
        summary_df['antecedents'] = summary_df['antecedents'].apply(lambda x: ' AND '.join(x))
        summary_df['consequents'] = summary_df['consequents'].apply(lambda x: ' AND '.join(x))
        filename = length_tag.replace("=", "_") + "_rules_summary.csv"
        summary_df.to_csv(f"review_length_rules/{filename}", index=False)
    else:
        print(f"❌ No rules generated for review length '{length_tag}'.")
# Out:
# 📝 Generating Discrimination Rules Based on Review_Length
#
#
# 📁 Rules for 'Review_Length=Short':
# 👉 IF Review_Length=Short THEN Reviewer_Type=Frequent AND Verified=Verified
#    - Support: 0.083
#    - Confidence: 0.226
#    - Lift: 1.155
#
# 👉 IF Review_Length=Short THEN Reviewer_Type=Frequent
#    - Support: 0.155
#    - Confidence: 0.419
#    - Lift: 1.044
#
# 👉 IF Review_Length=Short THEN Verified=Verified
#    - Support: 0.196
#    - Confidence: 0.532
#    - Lift: 1.038
#
# 👉 IF Review_Length=Short THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.116
#    - Confidence: 0.315
#    - Lift: 1.036
#
# 👉 IF Review_Length=Short THEN Rating=Low
#    - Support: 0.116
#    - Confidence: 0.315
#    - Lift: 1.036
#
# 👉 IF Review_Length=Short THEN Sentiment=Negative
#    - Support: 0.116
#    - Confidence: 0.315
#    - Lift: 1.036
#
# 👉 IF Review_Length=Short THEN Helpfulness=None
#    - Support: 0.141
#    - Confidence: 0.382
#    - Lift: 1.026
#
# 👉 IF Review_Length=Short THEN Rating=Medium
#    - Support: 0.112
#    - Confidence: 0.304
#    - Lift: 1.024
#
# 👉 IF Review_Length=Short THEN Sentiment=Neutral
#    - Support: 0.112
#    - Confidence: 0.304
#    - Lift: 1.024
#
# 👉 IF Review_Length=Short THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.112
#    - Confidence: 0.304
#    - Lift: 1.024
#
# 👉 IF Review_Length=Short THEN Helpfulness=More Helpful
#    - Support: 0.098
#    - Confidence: 0.266
#    - Lift: 0.997
#
# 👉 IF Review_Length=Short THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.101
#    - Confidence: 0.274
#    - Lift: 0.977
#
# 👉 IF Review_Length=Short THEN Helpfulness=Less Helpful
#    - Support: 0.13
#    - Confidence: 0.352
#    - Lift: 0.975
#
# 👉 IF Review_Length=Short THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.076
#    - Confidence: 0.207
#    - Lift: 0.975
#
# 👉 IF Review_Length=Short THEN Reviewer_Type=Infrequent
#    - Support: 0.214
#    - Confidence: 0.581
#    - Lift: 0.971
#
# 👉 IF Review_Length=Short THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.113
#    - Confidence: 0.306
#    - Lift: 0.965
#
# 👉 IF Review_Length=Short THEN Verified=Not Verified
#    - Support: 0.173
#    - Confidence: 0.468
#    - Lift: 0.96
#
# 👉 IF Review_Length=Short THEN Sentiment=Positive AND Rating=High
#    - Support: 0.141
#    - Confidence: 0.382
#    - Lift: 0.955
#
# 👉 IF Review_Length=Short THEN Sentiment=Positive
#    - Support: 0.141
#    - Confidence: 0.382
#    - Lift: 0.955
#
# 👉 IF Review_Length=Short THEN Rating=High
#    - Support: 0.141
#    - Confidence: 0.382
#    - Lift: 0.955
#
# 👉 IF Review_Length=Short THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.075
#    - Confidence: 0.204
#    - Lift: 0.94
#
# 👉 IF Review_Length=Short THEN Reviewer_Type=Infrequent AND Sentiment=Positive
#    - Support: 0.075
#    - Confidence: 0.204
#    - Lift: 0.94
#
# 👉 IF Review_Length=Short THEN Reviewer_Type=Infrequent AND Sentiment=Positive AND Rating=High
#    - Support: 0.075
#    - Confidence: 0.204
#    - Lift: 0.94
#
#
# 📁 Rules for 'Review_Length=Long':
# 👉 IF Review_Length=Long THEN Verified=Not Verified AND Rating=High
#    - Support: 0.064
#    - Confidence: 0.222
#    - Lift: 1.107
#
# 👉 IF Review_Length=Long THEN Sentiment=Positive AND Verified=Not Verified AND Rating=High
#    - Support: 0.064
#    - Confidence: 0.222
#    - Lift: 1.107
#
# 👉 IF Review_Length=Long THEN Sentiment=Positive AND Verified=Not Verified
#    - Support: 0.064
#    - Confidence: 0.222
#    - Lift: 1.107
#
# 👉 IF Review_Length=Long THEN Reviewer_Type=Infrequent AND Sentiment=Positive
#    - Support: 0.069
#    - Confidence: 0.239
#    - Lift: 1.1
#
# 👉 IF Review_Length=Long THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.069
#    - Confidence: 0.239
#    - Lift: 1.1
#
# 👉 IF Review_Length=Long THEN Reviewer_Type=Infrequent AND Sentiment=Positive AND Rating=High
#    - Support: 0.069
#    - Confidence: 0.239
#    - Lift: 1.1
#
# 👉 IF Review_Length=Long THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.065
#    - Confidence: 0.225
#    - Lift: 1.097
#
# 👉 IF Review_Length=Long THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.087
#    - Confidence: 0.3
#    - Lift: 1.07
#
# 👉 IF Review_Length=Long THEN Verified=Not Verified
#    - Support: 0.151
#    - Confidence: 0.519
#    - Lift: 1.065
#
# 👉 IF Review_Length=Long THEN Helpfulness=More Helpful
#    - Support: 0.082
#    - Confidence: 0.283
#    - Lift: 1.061
#
# 👉 IF Review_Length=Long THEN Reviewer_Type=Infrequent
#    - Support: 0.185
#    - Confidence: 0.635
#    - Lift: 1.061
#
# 👉 IF Review_Length=Long THEN Sentiment=Positive
#    - Support: 0.123
#    - Confidence: 0.423
#    - Lift: 1.059
#
# 👉 IF Review_Length=Long THEN Verified=Not Verified AND Reviewer_Type=Frequent
#    - Support: 0.063
#    - Confidence: 0.218
#    - Lift: 1.059
#
# 👉 IF Review_Length=Long THEN Rating=High
#    - Support: 0.123
#    - Confidence: 0.423
#    - Lift: 1.059
#
# 👉 IF Review_Length=Long THEN Sentiment=Positive AND Rating=High
#    - Support: 0.123
#    - Confidence: 0.423
#    - Lift: 1.059
#
# 👉 IF Review_Length=Long THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.097
#    - Confidence: 0.334
#    - Lift: 1.054
#
# 👉 IF Review_Length=Long THEN Reviewer_Type=Infrequent AND Sentiment=Negative
#    - Support: 0.059
#    - Confidence: 0.201
#    - Lift: 1.03
#
# 👉 IF Review_Length=Long THEN Reviewer_Type=Infrequent AND Rating=Low
#    - Support: 0.059
#    - Confidence: 0.201
#    - Lift: 1.03
#
# 👉 IF Review_Length=Long THEN Reviewer_Type=Infrequent AND Rating=Low AND Sentiment=Negative
#    - Support: 0.059
#    - Confidence: 0.201
#    - Lift: 1.03
#
# 👉 IF Review_Length=Long THEN Helpfulness=Less Helpful
#    - Support: 0.108
#    - Confidence: 0.372
#    - Lift: 1.03
#
# 👉 IF Review_Length=Long THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.063
#    - Confidence: 0.218
#    - Lift: 1.029
#
# 👉 IF Review_Length=Long THEN Verified=Not Verified AND Helpfulness=None
#    - Support: 0.059
#    - Confidence: 0.201
#    - Lift: 1.025
#
# 👉 IF Review_Length=Long THEN Rating=High AND Verified=Verified
#    - Support: 0.059
#    - Confidence: 0.201
#    - Lift: 1.01
#
# 👉 IF Review_Length=Long THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.059
#    - Confidence: 0.201
#    - Lift: 1.01
#
# 👉 IF Review_Length=Long THEN Sentiment=Positive AND Rating=High AND Verified=Verified
#    - Support: 0.059
#    - Confidence: 0.201
#    - Lift: 1.01
#
# 👉 IF Review_Length=Long THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.085
#    - Confidence: 0.294
#    - Lift: 0.967
#
# 👉 IF Review_Length=Long THEN Sentiment=Negative
#    - Support: 0.085
#    - Confidence: 0.294
#    - Lift: 0.967
#
# 👉 IF Review_Length=Long THEN Rating=Low
#    - Support: 0.085
#    - Confidence: 0.294
#    - Lift: 0.967
#
# 👉 IF Review_Length=Long THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.082
#    - Confidence: 0.283
#    - Lift: 0.955
#
# 👉 IF Review_Length=Long THEN Sentiment=Neutral
#    - Support: 0.082
#    - Confidence: 0.283
#    - Lift: 0.955
#
# 👉 IF Review_Length=Long THEN Rating=Medium
#    - Support: 0.082
#    - Confidence: 0.283
#    - Lift: 0.955
#
# 👉 IF Review_Length=Long THEN Verified=Verified
#    - Support: 0.14
#    - Confidence: 0.481
#    - Lift: 0.938
#
# 👉 IF Review_Length=Long THEN Helpfulness=None
#    - Support: 0.1
#    - Confidence: 0.345
#    - Lift: 0.927
#
# 👉 IF Review_Length=Long THEN Reviewer_Type=Frequent
#    - Support: 0.106
#    - Confidence: 0.365
#    - Lift: 0.909

# %%
from mlxtend.frequent_patterns import apriori, association_rules
import pandas as pd
import os

# Run Apriori (adjust thresholds as needed)
frequent_itemsets = apriori(df_trans, min_support=0.01, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)

# Create output directory
os.makedirs("sentiment_rules", exist_ok=True)

# Define sentiment tags
sentiment_tags = ['Sentiment=Positive','Sentiment=Neutral', 'Sentiment=Negative']

print("\n🧠 Generating Discrimination Rules Based on Sentiment\n")

for sentiment in sentiment_tags:
    print(f"\n📁 Rules for '{sentiment}':")
    
    # Filter rules where the only antecedent is the sentiment tag
    sentiment_rules = rules[rules['antecedents'].apply(
        lambda x: sentiment in x and len(x) == 1
    )].sort_values(by='lift', ascending=False)
    
    if not sentiment_rules.empty:
        for _, row in sentiment_rules.iterrows():
            antecedent = ' AND '.join(list(row['antecedents']))
            consequent = ' AND '.join(list(row['consequents']))
            print(f"👉 IF {antecedent} THEN {consequent}")
            print(f"   - Support: {round(row['support'], 3)}")
            print(f"   - Confidence: {round(row['confidence'], 3)}")
            print(f"   - Lift: {round(row['lift'], 3)}\n")

        # Save to CSV
        summary_df = sentiment_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].copy()
        summary_df['antecedents'] = summary_df['antecedents'].apply(lambda x: ' AND '.join(x))
        summary_df['consequents'] = summary_df['consequents'].apply(lambda x: ' AND '.join(x))
        filename = sentiment.replace("=", "_") + "_rules_summary.csv"
        summary_df.to_csv(f"sentiment_rules/{filename}", index=False)
    else:
        print(f"❌ No rules generated for sentiment '{sentiment}'.")
# Out:
# 🧠 Generating Discrimination Rules Based on Sentiment
#
#
# 📁 Rules for 'Sentiment=Positive':
# 👉 IF Sentiment=Positive THEN Helpfulness=None AND Rating=High
#    - Support: 0.139
#    - Confidence: 0.347
#    - Lift: 2.501
#
# 👉 IF Sentiment=Positive THEN Rating=High
#    - Support: 0.4
#    - Confidence: 1.0
#    - Lift: 2.501
#
# 👉 IF Sentiment=Positive THEN Reviewer_Type=Frequent AND Rating=High AND Verified=Verified
#    - Support: 0.087
#    - Confidence: 0.218
#    - Lift: 2.501
#
# 👉 IF Sentiment=Positive THEN Verified=Not Verified AND Reviewer_Type=Frequent AND Rating=High
#    - Support: 0.095
#    - Confidence: 0.238
#    - Lift: 2.501
#
# 👉 IF Sentiment=Positive THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.217
#    - Confidence: 0.543
#    - Lift: 2.501
#
# 👉 IF Sentiment=Positive THEN Review_Length=Short AND Rating=High
#    - Support: 0.141
#    - Confidence: 0.352
#    - Lift: 2.501
#
# 👉 IF Sentiment=Positive THEN Review_Length=Long AND Rating=High
#    - Support: 0.123
#    - Confidence: 0.308
#    - Lift: 2.501
#
# 👉 IF Sentiment=Positive THEN Reviewer_Type=Infrequent AND Verified=Not Verified AND Rating=High
#    - Support: 0.105
#    - Confidence: 0.263
#    - Lift: 2.501
#
# 👉 IF Sentiment=Positive THEN Rating=High AND Verified=Verified
#    - Support: 0.199
#    - Confidence: 0.499
#    - Lift: 2.501
#
# 👉 IF Sentiment=Positive THEN Verified=Not Verified AND Rating=High
#    - Support: 0.2
#    - Confidence: 0.501
#    - Lift: 2.501
#
# 👉 IF Sentiment=Positive THEN Reviewer_Type=Frequent AND Rating=High
#    - Support: 0.183
#    - Confidence: 0.457
#    - Lift: 2.501
#
# 👉 IF Sentiment=Positive THEN Review_Length=Medium AND Rating=High
#    - Support: 0.136
#    - Confidence: 0.34
#    - Lift: 2.501
#
# 👉 IF Sentiment=Positive THEN Reviewer_Type=Infrequent AND Rating=High AND Verified=Verified
#    - Support: 0.112
#    - Confidence: 0.28
#    - Lift: 2.501
#
# 👉 IF Sentiment=Positive THEN Helpfulness=More Helpful AND Rating=High
#    - Support: 0.123
#    - Confidence: 0.308
#    - Lift: 2.501
#
# 👉 IF Sentiment=Positive THEN Helpfulness=Less Helpful AND Rating=High
#    - Support: 0.138
#    - Confidence: 0.345
#    - Lift: 2.501
#
# 👉 IF Sentiment=Positive THEN Verified=Not Verified AND Reviewer_Type=Frequent
#    - Support: 0.095
#    - Confidence: 0.238
#    - Lift: 1.154
#
# 👉 IF Sentiment=Positive THEN Helpfulness=More Helpful
#    - Support: 0.123
#    - Confidence: 0.308
#    - Lift: 1.153
#
# 👉 IF Sentiment=Positive THEN Reviewer_Type=Frequent
#    - Support: 0.183
#    - Confidence: 0.457
#    - Lift: 1.136
#
# 👉 IF Sentiment=Positive THEN Reviewer_Type=Frequent AND Verified=Verified
#    - Support: 0.087
#    - Confidence: 0.218
#    - Lift: 1.117
#
# 👉 IF Sentiment=Positive THEN Review_Length=Long
#    - Support: 0.123
#    - Confidence: 0.308
#    - Lift: 1.059
#
# 👉 IF Sentiment=Positive THEN Verified=Not Verified
#    - Support: 0.2
#    - Confidence: 0.501
#    - Lift: 1.029
#
# 👉 IF Sentiment=Positive THEN Review_Length=Medium
#    - Support: 0.136
#    - Confidence: 0.34
#    - Lift: 0.999
#
# 👉 IF Sentiment=Positive THEN Verified=Verified
#    - Support: 0.199
#    - Confidence: 0.499
#    - Lift: 0.972
#
# 👉 IF Sentiment=Positive THEN Helpfulness=Less Helpful
#    - Support: 0.138
#    - Confidence: 0.345
#    - Lift: 0.955
#
# 👉 IF Sentiment=Positive THEN Review_Length=Short
#    - Support: 0.141
#    - Confidence: 0.352
#    - Lift: 0.955
#
# 👉 IF Sentiment=Positive THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.105
#    - Confidence: 0.263
#    - Lift: 0.937
#
# 👉 IF Sentiment=Positive THEN Helpfulness=None
#    - Support: 0.139
#    - Confidence: 0.347
#    - Lift: 0.934
#
# 👉 IF Sentiment=Positive THEN Reviewer_Type=Infrequent
#    - Support: 0.217
#    - Confidence: 0.543
#    - Lift: 0.908
#
# 👉 IF Sentiment=Positive THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.112
#    - Confidence: 0.28
#    - Lift: 0.883
#
#
# 📁 Rules for 'Sentiment=Neutral':
# 👉 IF Sentiment=Neutral THEN Verified=Verified AND Review_Length=Short AND Rating=Medium
#    - Support: 0.062
#    - Confidence: 0.207
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Verified=Not Verified AND Helpfulness=None AND Rating=Medium
#    - Support: 0.062
#    - Confidence: 0.207
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Review_Length=Medium AND Rating=Medium
#    - Support: 0.102
#    - Confidence: 0.344
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Review_Length=Long AND Rating=Medium
#    - Support: 0.082
#    - Confidence: 0.278
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Reviewer_Type=Infrequent AND Verified=Not Verified AND Rating=Medium
#    - Support: 0.082
#    - Confidence: 0.278
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Reviewer_Type=Infrequent AND Review_Length=Short AND Rating=Medium
#    - Support: 0.065
#    - Confidence: 0.221
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Reviewer_Type=Infrequent AND Review_Length=Medium AND Rating=Medium
#    - Support: 0.063
#    - Confidence: 0.214
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Reviewer_Type=Infrequent AND Helpfulness=None AND Rating=Medium
#    - Support: 0.068
#    - Confidence: 0.231
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful AND Rating=Medium
#    - Support: 0.067
#    - Confidence: 0.227
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Verified=Verified AND Rating=Medium
#    - Support: 0.157
#    - Confidence: 0.528
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Verified=Not Verified AND Rating=Medium
#    - Support: 0.14
#    - Confidence: 0.472
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Reviewer_Type=Infrequent AND Rating=Medium
#    - Support: 0.186
#    - Confidence: 0.625
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Reviewer_Type=Frequent AND Rating=Medium
#    - Support: 0.111
#    - Confidence: 0.375
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Review_Length=Short AND Rating=Medium
#    - Support: 0.112
#    - Confidence: 0.378
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Verified=Verified AND Reviewer_Type=Infrequent AND Rating=Medium
#    - Support: 0.103
#    - Confidence: 0.348
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Helpfulness=None AND Rating=Medium
#    - Support: 0.118
#    - Confidence: 0.398
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Helpfulness=More Helpful AND Rating=Medium
#    - Support: 0.065
#    - Confidence: 0.221
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Helpfulness=Less Helpful AND Rating=Medium
#    - Support: 0.113
#    - Confidence: 0.381
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Rating=Medium
#    - Support: 0.297
#    - Confidence: 1.0
#    - Lift: 3.371
#
# 👉 IF Sentiment=Neutral THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.067
#    - Confidence: 0.227
#    - Lift: 1.107
#
# 👉 IF Sentiment=Neutral THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.103
#    - Confidence: 0.348
#    - Lift: 1.096
#
# 👉 IF Sentiment=Neutral THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.068
#    - Confidence: 0.231
#    - Lift: 1.087
#
# 👉 IF Sentiment=Neutral THEN Reviewer_Type=Infrequent AND Review_Length=Medium
#    - Support: 0.063
#    - Confidence: 0.214
#    - Lift: 1.073
#
# 👉 IF Sentiment=Neutral THEN Helpfulness=None
#    - Support: 0.118
#    - Confidence: 0.398
#    - Lift: 1.07
#
# 👉 IF Sentiment=Neutral THEN Helpfulness=Less Helpful
#    - Support: 0.113
#    - Confidence: 0.381
#    - Lift: 1.056
#
# 👉 IF Sentiment=Neutral THEN Verified=Not Verified AND Helpfulness=None
#    - Support: 0.062
#    - Confidence: 0.207
#    - Lift: 1.056
#
# 👉 IF Sentiment=Neutral THEN Review_Length=Short AND Verified=Verified
#    - Support: 0.062
#    - Confidence: 0.207
#    - Lift: 1.056
#
# 👉 IF Sentiment=Neutral THEN Reviewer_Type=Infrequent
#    - Support: 0.186
#    - Confidence: 0.625
#    - Lift: 1.045
#
# 👉 IF Sentiment=Neutral THEN Verified=Verified
#    - Support: 0.157
#    - Confidence: 0.528
#    - Lift: 1.03
#
# 👉 IF Sentiment=Neutral THEN Reviewer_Type=Infrequent AND Review_Length=Short
#    - Support: 0.065
#    - Confidence: 0.221
#    - Lift: 1.03
#
# 👉 IF Sentiment=Neutral THEN Review_Length=Short
#    - Support: 0.112
#    - Confidence: 0.378
#    - Lift: 1.024
#
# 👉 IF Sentiment=Neutral THEN Review_Length=Medium
#    - Support: 0.102
#    - Confidence: 0.344
#    - Lift: 1.012
#
# 👉 IF Sentiment=Neutral THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.082
#    - Confidence: 0.278
#    - Lift: 0.989
#
# 👉 IF Sentiment=Neutral THEN Verified=Not Verified
#    - Support: 0.14
#    - Confidence: 0.472
#    - Lift: 0.968
#
# 👉 IF Sentiment=Neutral THEN Review_Length=Long
#    - Support: 0.082
#    - Confidence: 0.278
#    - Lift: 0.955
#
# 👉 IF Sentiment=Neutral THEN Reviewer_Type=Frequent
#    - Support: 0.111
#    - Confidence: 0.375
#    - Lift: 0.932
#
# 👉 IF Sentiment=Neutral THEN Helpfulness=More Helpful
#    - Support: 0.065
#    - Confidence: 0.221
#    - Lift: 0.827
#
#
# 📁 Rules for 'Sentiment=Negative':
# 👉 IF Sentiment=Negative THEN Review_Length=Long AND Rating=Low
#    - Support: 0.085
#    - Confidence: 0.281
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Rating=Low AND Review_Length=Medium
#    - Support: 0.102
#    - Confidence: 0.337
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Reviewer_Type=Infrequent AND Verified=Not Verified AND Rating=Low
#    - Support: 0.093
#    - Confidence: 0.307
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Rating=Low AND Review_Length=Short AND Verified=Verified
#    - Support: 0.062
#    - Confidence: 0.206
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Reviewer_Type=Infrequent AND Rating=Low AND Review_Length=Short
#    - Support: 0.073
#    - Confidence: 0.242
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Reviewer_Type=Infrequent AND Rating=Low AND Review_Length=Medium
#    - Support: 0.063
#    - Confidence: 0.209
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Verified=Not Verified AND Rating=Low AND Helpfulness=None
#    - Support: 0.062
#    - Confidence: 0.206
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Reviewer_Type=Infrequent AND Rating=Low AND Helpfulness=None
#    - Support: 0.069
#    - Confidence: 0.229
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Reviewer_Type=Infrequent AND Rating=Low AND Helpfulness=Less Helpful
#    - Support: 0.065
#    - Confidence: 0.216
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Rating=Low AND Verified=Verified
#    - Support: 0.157
#    - Confidence: 0.516
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Verified=Not Verified AND Rating=Low
#    - Support: 0.147
#    - Confidence: 0.484
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Reviewer_Type=Infrequent AND Rating=Low
#    - Support: 0.195
#    - Confidence: 0.644
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Rating=Low AND Reviewer_Type=Frequent
#    - Support: 0.108
#    - Confidence: 0.356
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Rating=Low AND Review_Length=Short
#    - Support: 0.116
#    - Confidence: 0.382
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Reviewer_Type=Infrequent AND Rating=Low AND Verified=Verified
#    - Support: 0.102
#    - Confidence: 0.337
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Rating=Low
#    - Support: 0.304
#    - Confidence: 1.0
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Helpfulness=More Helpful AND Rating=Low
#    - Support: 0.078
#    - Confidence: 0.258
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Rating=Low AND Helpfulness=Less Helpful
#    - Support: 0.11
#    - Confidence: 0.363
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Rating=Low AND Helpfulness=None
#    - Support: 0.115
#    - Confidence: 0.379
#    - Lift: 3.294
#
# 👉 IF Sentiment=Negative THEN Reviewer_Type=Infrequent AND Review_Length=Short
#    - Support: 0.073
#    - Confidence: 0.242
#    - Lift: 1.129
#
# 👉 IF Sentiment=Negative THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.093
#    - Confidence: 0.307
#    - Lift: 1.094
#
# 👉 IF Sentiment=Negative THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.069
#    - Confidence: 0.229
#    - Lift: 1.078
#
# 👉 IF Sentiment=Negative THEN Reviewer_Type=Infrequent
#    - Support: 0.195
#    - Confidence: 0.644
#    - Lift: 1.076
#
# 👉 IF Sentiment=Negative THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.102
#    - Confidence: 0.337
#    - Lift: 1.06
#
# 👉 IF Sentiment=Negative THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.065
#    - Confidence: 0.216
#    - Lift: 1.05
#
# 👉 IF Sentiment=Negative THEN Reviewer_Type=Infrequent AND Review_Length=Medium
#    - Support: 0.063
#    - Confidence: 0.209
#    - Lift: 1.049
#
# 👉 IF Sentiment=Negative THEN Review_Length=Short AND Verified=Verified
#    - Support: 0.062
#    - Confidence: 0.206
#    - Lift: 1.048
#
# 👉 IF Sentiment=Negative THEN Verified=Not Verified AND Helpfulness=None
#    - Support: 0.062
#    - Confidence: 0.206
#    - Lift: 1.048
#
# 👉 IF Sentiment=Negative THEN Review_Length=Short
#    - Support: 0.116
#    - Confidence: 0.382
#    - Lift: 1.036
#
# 👉 IF Sentiment=Negative THEN Helpfulness=None
#    - Support: 0.115
#    - Confidence: 0.379
#    - Lift: 1.019
#
# 👉 IF Sentiment=Negative THEN Verified=Verified
#    - Support: 0.157
#    - Confidence: 0.516
#    - Lift: 1.007
#
# 👉 IF Sentiment=Negative THEN Helpfulness=Less Helpful
#    - Support: 0.11
#    - Confidence: 0.363
#    - Lift: 1.005
#
# 👉 IF Sentiment=Negative THEN Verified=Not Verified
#    - Support: 0.147
#    - Confidence: 0.484
#    - Lift: 0.993
#
# 👉 IF Sentiment=Negative THEN Review_Length=Medium
#    - Support: 0.102
#    - Confidence: 0.337
#    - Lift: 0.989
#
# 👉 IF Sentiment=Negative THEN Helpfulness=More Helpful
#    - Support: 0.078
#    - Confidence: 0.258
#    - Lift: 0.967
#
# 👉 IF Sentiment=Negative THEN Review_Length=Long
#    - Support: 0.085
#    - Confidence: 0.281
#    - Lift: 0.967
#
# 👉 IF Sentiment=Negative THEN Reviewer_Type=Frequent
#    - Support: 0.108
#    - Confidence: 0.356
#    - Lift: 0.887

# %%
# Step 1: Create subsets for each reviewer type
frequent_df = df_trans[df_trans['Reviewer_Type=Frequent'] == True]
infrequent_df = df_trans[df_trans['Reviewer_Type=Infrequent'] == True]

def compute_t_d_weight(rules_df, target_df, contrast_df, target_label):
    t_weights = []
    d_weights = []

    # Calculate total support of target class
    total_target = len(target_df)

    for _, row in rules_df.iterrows():
        antecedent_items = list(row['antecedents'])

        # Find rows in which all items of antecedent are True
        antecedent_support_target = target_df[antecedent_items].all(axis=1).sum() / len(df_trans)
        antecedent_support_contrast = contrast_df[antecedent_items].all(axis=1).sum() / len(df_trans)

        t_weight = antecedent_support_target / (target_df['Reviewer_Type=' + target_label].sum() / len(df_trans))
        d_weight = antecedent_support_target - antecedent_support_contrast

        t_weights.append(round(t_weight, 3))
        d_weights.append(round(d_weight, 3))

    rules_df['T-Weight'] = t_weights
    rules_df['D-Weight'] = d_weights

    return rules_df

# Compute T-Weight and D-Weight for each group
frequent_reviewer_rules = compute_t_d_weight(frequent_reviewer_rules, frequent_df, infrequent_df, "Frequent")
infrequent_reviewer_rules = compute_t_d_weight(infrequent_reviewer_rules, infrequent_df, frequent_df, "Infrequent")

# %%
frequent_summary_df = frequent_reviewer_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift', 'T-Weight', 'D-Weight']].copy()
frequent_summary_df['antecedents'] = frequent_summary_df['antecedents'].apply(lambda x: ' AND '.join(x))
frequent_summary_df['consequents'] = frequent_summary_df['consequents'].apply(lambda x: ' AND '.join(x))

infrequent_summary_df = infrequent_reviewer_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift', 'T-Weight', 'D-Weight']].copy()
infrequent_summary_df['antecedents'] = infrequent_summary_df['antecedents'].apply(lambda x: ' AND '.join(x))
infrequent_summary_df['consequents'] = infrequent_summary_df['consequents'].apply(lambda x: ' AND '.join(x))

# %%
import pandas as pd

# === Step A: Function to calculate T-Weight and D-Weight ===
def add_t_d_weights(rules_df):
    rules_df = rules_df.copy()

    # Convert frozensets to strings for easier grouping
    rules_df['antecedents_str'] = rules_df['antecedents'].apply(lambda x: ' AND '.join(sorted(list(x))))
    rules_df['consequents_str'] = rules_df['consequents'].apply(lambda x: ' AND '.join(sorted(list(x))))

    # T-Weight: grouped by consequent
    t_weight_map = rules_df.groupby('consequents_str')['support'].transform('sum')
    rules_df['T-Weight'] = rules_df['support'] / t_weight_map

    # D-Weight: grouped by antecedent
    d_weight_map = rules_df.groupby('antecedents_str')['support'].transform('sum')
    rules_df['D-Weight'] = rules_df['support'] / d_weight_map

    return rules_df

# Apply weights to both groups
frequent_reviewer_rules = add_t_d_weights(frequent_reviewer_rules)
infrequent_reviewer_rules = add_t_d_weights(infrequent_reviewer_rules)

# === Step B: Display Rules with Weights ===
def display_rules_with_weights(rules_df, label):
    print(f"\n📋 {label}:\n")
    if not rules_df.empty:
        for _, row in rules_df.iterrows():
            antecedent = row['antecedents_str']
            consequent = row['consequents_str']
            print(f"👉 IF {antecedent} THEN {consequent}")
            print(f"Support: {row['support']:.5f}")  # Adjust precision as necessary, or just use {row['support']}
            print(f"Confidence: {row['confidence']}")
            print(f"Lift: {row['lift']}")
            print(f"T-Weight: {row['T-Weight']}")
            print(f"D-Weight: {row['D-Weight']}\n")

    else:
        print("No rules found.")

# Display rules with weights
display_rules_with_weights(frequent_reviewer_rules, "Reviewer Type = Frequent (with T & D Weights)")
display_rules_with_weights(infrequent_reviewer_rules, "Reviewer Type = Infrequent (with T & D Weights)")

# === Step C: Exporting to CSV with weights ===
frequent_reviewer_rules.to_csv('reviewer_type_frequent_rules_with_weights.csv', index=False)
infrequent_reviewer_rules.to_csv('reviewer_type_infrequent_rules_with_weights.csv', index=False)

print("\n✅ Rules with T-Weight and D-Weight saved to CSV.")
# Out:
# 📋 Reviewer Type = Frequent (with T & D Weights):
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High AND Sentiment=Positive AND Verified=Not Verified
# Support: 0.09524
# Confidence: 0.23703703703703702
# Lift: 1.1828382838283826
# T-Weight: 1.0
# D-Weight: 0.030389363722697058
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Positive AND Verified=Not Verified
# Support: 0.09524
# Confidence: 0.23703703703703702
# Lift: 1.1828382838283826
# T-Weight: 1.0
# D-Weight: 0.030389363722697058
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High AND Verified=Not Verified
# Support: 0.09524
# Confidence: 0.23703703703703702
# Lift: 1.1828382838283826
# T-Weight: 1.0
# D-Weight: 0.030389363722697058
#
# 👉 IF Reviewer_Type=Frequent THEN Helpfulness=None AND Verified=Not Verified
# Support: 0.09226
# Confidence: 0.22962962962962963
# Lift: 1.169023569023569
# T-Weight: 1.0
# D-Weight: 0.029439696106362778
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Positive
# Support: 0.18254
# Confidence: 0.45432098765432094
# Lift: 1.1363661428177556
# T-Weight: 1.0
# D-Weight: 0.05824628046850269
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High
# Support: 0.18254
# Confidence: 0.45432098765432094
# Lift: 1.1363661428177556
# T-Weight: 1.0
# D-Weight: 0.05824628046850269
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High AND Sentiment=Positive
# Support: 0.18254
# Confidence: 0.45432098765432094
# Lift: 1.1363661428177556
# T-Weight: 1.0
# D-Weight: 0.05824628046850269
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High AND Sentiment=Positive AND Verified=Verified
# Support: 0.08730
# Confidence: 0.21728395061728392
# Lift: 1.0896627971254835
# T-Weight: 1.0
# D-Weight: 0.027856916745805635
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Positive AND Verified=Verified
# Support: 0.08730
# Confidence: 0.21728395061728392
# Lift: 1.0896627971254835
# T-Weight: 1.0
# D-Weight: 0.027856916745805635
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High AND Verified=Verified
# Support: 0.08730
# Confidence: 0.21728395061728392
# Lift: 1.0896627971254835
# T-Weight: 1.0
# D-Weight: 0.027856916745805635
#
# 👉 IF Reviewer_Type=Frequent THEN Helpfulness=Less Helpful
# Support: 0.15575
# Confidence: 0.3876543209876543
# Lift: 1.0735042735042735
# T-Weight: 1.0
# D-Weight: 0.04969927192149415
#
# 👉 IF Reviewer_Type=Frequent THEN Helpfulness=None
# Support: 0.15972
# Confidence: 0.3975308641975308
# Lift: 1.0685629629629627
# T-Weight: 1.0
# D-Weight: 0.05096549540993985
#
# 👉 IF Reviewer_Type=Frequent THEN Review_Length=Short AND Verified=Verified
# Support: 0.08333
# Confidence: 0.2074074074074074
# Lift: 1.0558922558922559
# T-Weight: 1.0
# D-Weight: 0.026590693257359924
#
# 👉 IF Reviewer_Type=Frequent THEN Verified=Not Verified
# Support: 0.20635
# Confidence: 0.5135802469135802
# Lift: 1.054356189183073
# T-Weight: 1.0
# D-Weight: 0.06584362139917696
#
# 👉 IF Reviewer_Type=Frequent THEN Review_Length=Short
# Support: 0.15476
# Confidence: 0.3851851851851852
# Lift: 1.0437275985663081
# T-Weight: 1.0
# D-Weight: 0.04938271604938272
#
# 👉 IF Reviewer_Type=Frequent THEN Review_Length=Medium
# Support: 0.14087
# Confidence: 0.35061728395061725
# Lift: 1.0303854875283445
# T-Weight: 1.0
# D-Weight: 0.04495093383982273
#
# 👉 IF Reviewer_Type=Frequent THEN Verified=Verified
# Support: 0.19544
# Confidence: 0.4864197530864197
# Lift: 0.9483773909305824
# T-Weight: 1.0
# D-Weight: 0.062361506805951254
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Neutral
# Support: 0.11111
# Confidence: 0.2765432098765432
# Lift: 0.9322928279450018
# T-Weight: 1.0
# D-Weight: 0.0354542576764799
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=Medium AND Sentiment=Neutral
# Support: 0.11111
# Confidence: 0.2765432098765432
# Lift: 0.9322928279450018
# T-Weight: 1.0
# D-Weight: 0.0354542576764799
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=Medium
# Support: 0.11111
# Confidence: 0.2765432098765432
# Lift: 0.9322928279450018
# T-Weight: 1.0
# D-Weight: 0.0354542576764799
#
# 👉 IF Reviewer_Type=Frequent THEN Review_Length=Long
# Support: 0.10615
# Confidence: 0.2641975308641975
# Lift: 0.9089116420174439
# T-Weight: 1.0
# D-Weight: 0.033871478315922764
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Negative
# Support: 0.10813
# Confidence: 0.2691358024691358
# Lift: 0.8865649963689181
# T-Weight: 1.0
# D-Weight: 0.03450459006014562
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=Low AND Sentiment=Negative
# Support: 0.10813
# Confidence: 0.2691358024691358
# Lift: 0.8865649963689181
# T-Weight: 1.0
# D-Weight: 0.03450459006014562
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=Low
# Support: 0.10813
# Confidence: 0.2691358024691358
# Lift: 0.8865649963689181
# T-Weight: 1.0
# D-Weight: 0.03450459006014562
#
# 👉 IF Reviewer_Type=Frequent THEN Helpfulness=More Helpful
# Support: 0.08631
# Confidence: 0.2148148148148148
# Lift: 0.8049566294919454
# T-Weight: 1.0
# D-Weight: 0.02754036087369421
#
#
# 📋 Reviewer Type = Infrequent (with T & D Weights):
#
# 👉 IF Reviewer_Type=Infrequent THEN Helpfulness=More Helpful
# Support: 0.18056
# Confidence: 0.3018242122719735
# Lift: 1.1309992786994396
# T-Weight: 1.0
# D-Weight: 0.050304035378662244
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=Low AND Sentiment=Negative
# Support: 0.19544
# Confidence: 0.32669983416252074
# Lift: 1.0761876890059507
# T-Weight: 1.0
# D-Weight: 0.05444997236042012
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=Low
# Support: 0.19544
# Confidence: 0.32669983416252074
# Lift: 1.0761876890059507
# T-Weight: 1.0
# D-Weight: 0.05444997236042012
#
# 👉 IF Reviewer_Type=Infrequent THEN Sentiment=Negative
# Support: 0.19544
# Confidence: 0.32669983416252074
# Lift: 1.0761876890059507
# T-Weight: 1.0
# D-Weight: 0.05444997236042012
#
# 👉 IF Reviewer_Type=Infrequent THEN Review_Length=Long
# Support: 0.18452
# Confidence: 0.3084577114427861
# Lift: 1.0611787478987316
# T-Weight: 1.0
# D-Weight: 0.05140961857379768
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=Medium AND Sentiment=Neutral
# Support: 0.18552
# Confidence: 0.31011608623548925
# Lift: 1.0454749663055958
# T-Weight: 1.0
# D-Weight: 0.05168601437258154
#
# 👉 IF Reviewer_Type=Infrequent THEN Sentiment=Neutral
# Support: 0.18552
# Confidence: 0.31011608623548925
# Lift: 1.0454749663055958
# T-Weight: 1.0
# D-Weight: 0.05168601437258154
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=Medium
# Support: 0.18552
# Confidence: 0.31011608623548925
# Lift: 1.0454749663055958
# T-Weight: 1.0
# D-Weight: 0.05168601437258154
#
# 👉 IF Reviewer_Type=Infrequent THEN Verified=Verified
# Support: 0.31746
# Confidence: 0.5306799336650083
# Lift: 1.034671901613788
# T-Weight: 1.0
# D-Weight: 0.0884466556108347
#
# 👉 IF Reviewer_Type=Infrequent THEN Review_Length=Medium
# Support: 0.19940
# Confidence: 0.33333333333333337
# Lift: 0.979591836734694
# T-Weight: 1.0
# D-Weight: 0.05555555555555556
#
# 👉 IF Reviewer_Type=Infrequent THEN Review_Length=Short
# Support: 0.21429
# Confidence: 0.3582089552238806
# Lift: 0.9706307173808376
# T-Weight: 1.0
# D-Weight: 0.059701492537313425
#
# 👉 IF Reviewer_Type=Infrequent THEN Verified=Not Verified
# Support: 0.28075
# Confidence: 0.46932006633499174
# Lift: 0.9634921117427122
# T-Weight: 1.0
# D-Weight: 0.07822001105583194
#
# 👉 IF Reviewer_Type=Infrequent THEN Helpfulness=None
# Support: 0.21230
# Confidence: 0.3548922056384743
# Lift: 0.9539502487562188
# T-Weight: 1.0
# D-Weight: 0.05914870093974571
#
# 👉 IF Reviewer_Type=Infrequent THEN Helpfulness=Less Helpful
# Support: 0.20536
# Confidence: 0.34328358208955223
# Lift: 0.9506314580941446
# T-Weight: 1.0
# D-Weight: 0.0572139303482587
#
# 👉 IF Reviewer_Type=Infrequent THEN Sentiment=Positive
# Support: 0.21726
# Confidence: 0.36318407960199006
# Lift: 0.9084107996000148
# T-Weight: 1.0
# D-Weight: 0.06053067993366501
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=High
# Support: 0.21726
# Confidence: 0.36318407960199006
# Lift: 0.9084107996000148
# T-Weight: 1.0
# D-Weight: 0.06053067993366501
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=High AND Sentiment=Positive
# Support: 0.21726
# Confidence: 0.36318407960199006
# Lift: 0.9084107996000148
# T-Weight: 1.0
# D-Weight: 0.06053067993366501
#
#
# ✅ Rules with T-Weight and D-Weight saved to CSV.

# %%
import pandas as pd

# === Step A: Function to calculate T-Weight and D-Weight ===
def compute_t_d_weight(rules_df, target_df, contrast_df, target_label):
    t_weights = []
    d_weights = []

    # Calculate total support of target class
    total_target = len(target_df)

    for _, row in rules_df.iterrows():
        antecedent_items = list(row['antecedents'])

        # Find rows in which all items of antecedent are True
        antecedent_support_target = target_df[antecedent_items].all(axis=1).sum() / len(df_trans)
        antecedent_support_contrast = contrast_df[antecedent_items].all(axis=1).sum() / len(df_trans)

        t_weight = antecedent_support_target / (target_df['Reviewer_Type=' + target_label].sum() / len(df_trans))
        d_weight = antecedent_support_target - antecedent_support_contrast

        t_weights.append(round(t_weight, 3))
        d_weights.append(round(d_weight, 3))

    rules_df['T-Weight'] = t_weights
    rules_df['D-Weight'] = d_weights

    return rules_df

# === Step B: Add T and D weights based on antecedent and consequent ===
def add_t_d_weights(rules_df):
    rules_df = rules_df.copy()

    # Convert frozensets to strings for easier grouping
    rules_df['antecedents_str'] = rules_df['antecedents'].apply(lambda x: ' AND '.join(sorted(list(x))))
    rules_df['consequents_str'] = rules_df['consequents'].apply(lambda x: ' AND '.join(sorted(list(x))))

    # T-Weight: grouped by consequent
    t_weight_map = rules_df.groupby('consequents_str')['support'].transform('sum')
    rules_df['T-Weight'] = rules_df['support'] / t_weight_map

    # D-Weight: grouped by antecedent
    d_weight_map = rules_df.groupby('antecedents_str')['support'].transform('sum')
    rules_df['D-Weight'] = rules_df['support'] / d_weight_map

    return rules_df

# === Step C: Display Rules with Weights ===
def display_rules_with_weights(rules_df, label):
    print(f"\n📋 {label}:\n")
    if not rules_df.empty:
        for _, row in rules_df.iterrows():
            antecedent = row['antecedents_str']
            consequent = row['consequents_str']
            print(f"👉 IF {antecedent} THEN {consequent}")
            print(f"   - Support: {round(row['support'], 3)}")
            print(f"   - Confidence: {round(row['confidence'], 3)}")
            print(f"   - Lift: {round(row['lift'], 3)}")
            print(f"   - T-Weight: {round(row['T-Weight'], 3)}")
            print(f"   - D-Weight: {round(row['D-Weight'], 3)}\n")
    else:
        print("No rules found.")

# === Step D: Exporting to CSV with weights ===
def export_to_csv(frequent_reviewer_rules, infrequent_reviewer_rules):
    frequent_reviewer_rules.to_csv('reviewer_type_frequent_rules_with_weights.csv', index=False)
    infrequent_reviewer_rules.to_csv('reviewer_type_infrequent_rules_with_weights.csv', index=False)
    print("\n✅ Rules with T-Weight and D-Weight saved to CSV.")

# === Step E: Process the data ===
# Step 1: Create subsets for each reviewer type
frequent_df = df_trans[df_trans['Reviewer_Type=Frequent'] == True]
infrequent_df = df_trans[df_trans['Reviewer_Type=Infrequent'] == True]

# Apply the T and D weights functions to both groups
frequent_reviewer_rules = add_t_d_weights(frequent_reviewer_rules)
infrequent_reviewer_rules = add_t_d_weights(infrequent_reviewer_rules)

# Display the results with weights
display_rules_with_weights(frequent_reviewer_rules, "Reviewer Type = Frequent (with T & D Weights)")
display_rules_with_weights(infrequent_reviewer_rules, "Reviewer Type = Infrequent (with T & D Weights)")

# Save the output
export_to_csv(frequent_reviewer_rules, infrequent_reviewer_rules)
# Out:
# 📋 Reviewer Type = Frequent (with T & D Weights):
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High AND Sentiment=Positive AND Verified=Not Verified
#    - Support: 0.095
#    - Confidence: 0.237
#    - Lift: 1.183
#    - T-Weight: 1.0
#    - D-Weight: 0.03
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Positive AND Verified=Not Verified
#    - Support: 0.095
#    - Confidence: 0.237
#    - Lift: 1.183
#    - T-Weight: 1.0
#    - D-Weight: 0.03
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High AND Verified=Not Verified
#    - Support: 0.095
#    - Confidence: 0.237
#    - Lift: 1.183
#    - T-Weight: 1.0
#    - D-Weight: 0.03
#
# 👉 IF Reviewer_Type=Frequent THEN Helpfulness=None AND Verified=Not Verified
#    - Support: 0.092
#    - Confidence: 0.23
#    - Lift: 1.169
#    - T-Weight: 1.0
#    - D-Weight: 0.029
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Positive
#    - Support: 0.183
#    - Confidence: 0.454
#    - Lift: 1.136
#    - T-Weight: 1.0
#    - D-Weight: 0.058
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High
#    - Support: 0.183
#    - Confidence: 0.454
#    - Lift: 1.136
#    - T-Weight: 1.0
#    - D-Weight: 0.058
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High AND Sentiment=Positive
#    - Support: 0.183
#    - Confidence: 0.454
#    - Lift: 1.136
#    - T-Weight: 1.0
#    - D-Weight: 0.058
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High AND Sentiment=Positive AND Verified=Verified
#    - Support: 0.087
#    - Confidence: 0.217
#    - Lift: 1.09
#    - T-Weight: 1.0
#    - D-Weight: 0.028
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.087
#    - Confidence: 0.217
#    - Lift: 1.09
#    - T-Weight: 1.0
#    - D-Weight: 0.028
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High AND Verified=Verified
#    - Support: 0.087
#    - Confidence: 0.217
#    - Lift: 1.09
#    - T-Weight: 1.0
#    - D-Weight: 0.028
#
# 👉 IF Reviewer_Type=Frequent THEN Helpfulness=Less Helpful
#    - Support: 0.156
#    - Confidence: 0.388
#    - Lift: 1.074
#    - T-Weight: 1.0
#    - D-Weight: 0.05
#
# 👉 IF Reviewer_Type=Frequent THEN Helpfulness=None
#    - Support: 0.16
#    - Confidence: 0.398
#    - Lift: 1.069
#    - T-Weight: 1.0
#    - D-Weight: 0.051
#
# 👉 IF Reviewer_Type=Frequent THEN Review_Length=Short AND Verified=Verified
#    - Support: 0.083
#    - Confidence: 0.207
#    - Lift: 1.056
#    - T-Weight: 1.0
#    - D-Weight: 0.027
#
# 👉 IF Reviewer_Type=Frequent THEN Verified=Not Verified
#    - Support: 0.206
#    - Confidence: 0.514
#    - Lift: 1.054
#    - T-Weight: 1.0
#    - D-Weight: 0.066
#
# 👉 IF Reviewer_Type=Frequent THEN Review_Length=Short
#    - Support: 0.155
#    - Confidence: 0.385
#    - Lift: 1.044
#    - T-Weight: 1.0
#    - D-Weight: 0.049
#
# 👉 IF Reviewer_Type=Frequent THEN Review_Length=Medium
#    - Support: 0.141
#    - Confidence: 0.351
#    - Lift: 1.03
#    - T-Weight: 1.0
#    - D-Weight: 0.045
#
# 👉 IF Reviewer_Type=Frequent THEN Verified=Verified
#    - Support: 0.195
#    - Confidence: 0.486
#    - Lift: 0.948
#    - T-Weight: 1.0
#    - D-Weight: 0.062
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Neutral
#    - Support: 0.111
#    - Confidence: 0.277
#    - Lift: 0.932
#    - T-Weight: 1.0
#    - D-Weight: 0.035
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=Medium AND Sentiment=Neutral
#    - Support: 0.111
#    - Confidence: 0.277
#    - Lift: 0.932
#    - T-Weight: 1.0
#    - D-Weight: 0.035
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=Medium
#    - Support: 0.111
#    - Confidence: 0.277
#    - Lift: 0.932
#    - T-Weight: 1.0
#    - D-Weight: 0.035
#
# 👉 IF Reviewer_Type=Frequent THEN Review_Length=Long
#    - Support: 0.106
#    - Confidence: 0.264
#    - Lift: 0.909
#    - T-Weight: 1.0
#    - D-Weight: 0.034
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Negative
#    - Support: 0.108
#    - Confidence: 0.269
#    - Lift: 0.887
#    - T-Weight: 1.0
#    - D-Weight: 0.035
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.108
#    - Confidence: 0.269
#    - Lift: 0.887
#    - T-Weight: 1.0
#    - D-Weight: 0.035
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=Low
#    - Support: 0.108
#    - Confidence: 0.269
#    - Lift: 0.887
#    - T-Weight: 1.0
#    - D-Weight: 0.035
#
# 👉 IF Reviewer_Type=Frequent THEN Helpfulness=More Helpful
#    - Support: 0.086
#    - Confidence: 0.215
#    - Lift: 0.805
#    - T-Weight: 1.0
#    - D-Weight: 0.028
#
#
# 📋 Reviewer Type = Infrequent (with T & D Weights):
#
# 👉 IF Reviewer_Type=Infrequent THEN Helpfulness=More Helpful
#    - Support: 0.181
#    - Confidence: 0.302
#    - Lift: 1.131
#    - T-Weight: 1.0
#    - D-Weight: 0.05
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.195
#    - Confidence: 0.327
#    - Lift: 1.076
#    - T-Weight: 1.0
#    - D-Weight: 0.054
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=Low
#    - Support: 0.195
#    - Confidence: 0.327
#    - Lift: 1.076
#    - T-Weight: 1.0
#    - D-Weight: 0.054
#
# 👉 IF Reviewer_Type=Infrequent THEN Sentiment=Negative
#    - Support: 0.195
#    - Confidence: 0.327
#    - Lift: 1.076
#    - T-Weight: 1.0
#    - D-Weight: 0.054
#
# 👉 IF Reviewer_Type=Infrequent THEN Review_Length=Long
#    - Support: 0.185
#    - Confidence: 0.308
#    - Lift: 1.061
#    - T-Weight: 1.0
#    - D-Weight: 0.051
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=Medium AND Sentiment=Neutral
#    - Support: 0.186
#    - Confidence: 0.31
#    - Lift: 1.045
#    - T-Weight: 1.0
#    - D-Weight: 0.052
#
# 👉 IF Reviewer_Type=Infrequent THEN Sentiment=Neutral
#    - Support: 0.186
#    - Confidence: 0.31
#    - Lift: 1.045
#    - T-Weight: 1.0
#    - D-Weight: 0.052
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=Medium
#    - Support: 0.186
#    - Confidence: 0.31
#    - Lift: 1.045
#    - T-Weight: 1.0
#    - D-Weight: 0.052
#
# 👉 IF Reviewer_Type=Infrequent THEN Verified=Verified
#    - Support: 0.317
#    - Confidence: 0.531
#    - Lift: 1.035
#    - T-Weight: 1.0
#    - D-Weight: 0.088
#
# 👉 IF Reviewer_Type=Infrequent THEN Review_Length=Medium
#    - Support: 0.199
#    - Confidence: 0.333
#    - Lift: 0.98
#    - T-Weight: 1.0
#    - D-Weight: 0.056
#
# 👉 IF Reviewer_Type=Infrequent THEN Review_Length=Short
#    - Support: 0.214
#    - Confidence: 0.358
#    - Lift: 0.971
#    - T-Weight: 1.0
#    - D-Weight: 0.06
#
# 👉 IF Reviewer_Type=Infrequent THEN Verified=Not Verified
#    - Support: 0.281
#    - Confidence: 0.469
#    - Lift: 0.963
#    - T-Weight: 1.0
#    - D-Weight: 0.078
#
# 👉 IF Reviewer_Type=Infrequent THEN Helpfulness=None
#    - Support: 0.212
#    - Confidence: 0.355
#    - Lift: 0.954
#    - T-Weight: 1.0
#    - D-Weight: 0.059
#
# 👉 IF Reviewer_Type=Infrequent THEN Helpfulness=Less Helpful
#    - Support: 0.205
#    - Confidence: 0.343
#    - Lift: 0.951
#    - T-Weight: 1.0
#    - D-Weight: 0.057
#
# 👉 IF Reviewer_Type=Infrequent THEN Sentiment=Positive
#    - Support: 0.217
#    - Confidence: 0.363
#    - Lift: 0.908
#    - T-Weight: 1.0
#    - D-Weight: 0.061
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=High
#    - Support: 0.217
#    - Confidence: 0.363
#    - Lift: 0.908
#    - T-Weight: 1.0
#    - D-Weight: 0.061
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=High AND Sentiment=Positive
#    - Support: 0.217
#    - Confidence: 0.363
#    - Lift: 0.908
#    - T-Weight: 1.0
#    - D-Weight: 0.061
#
#
# ✅ Rules with T-Weight and D-Weight saved to CSV.

# %%
from tabulate import tabulate

# === Step A: Function to calculate T-Weight and D-Weight ===
def add_t_d_weights(rules_df):
    rules_df = rules_df.copy()

    # Convert frozensets to strings for easier grouping
    rules_df['antecedents_str'] = rules_df['antecedents'].apply(lambda x: ' AND '.join(sorted(list(x))))
    rules_df['consequents_str'] = rules_df['consequents'].apply(lambda x: ' AND '.join(sorted(list(x))))

    # T-Weight: grouped by consequent
    t_weight_map = rules_df.groupby('consequents_str')['support'].transform('sum')
    rules_df['T-Weight'] = rules_df['support'] / t_weight_map

    # D-Weight: grouped by antecedent
    d_weight_map = rules_df.groupby('antecedents_str')['support'].transform('sum')
    rules_df['D-Weight'] = rules_df['support'] / d_weight_map

    # Adding Percentage Columns for T-Weight and D-Weight
    total_support = rules_df['support'].sum()
    rules_df['T-Weight (%)'] = (rules_df['T-Weight'] / total_support) * 100
    rules_df['D-Weight (%)'] = (rules_df['D-Weight'] / total_support) * 100

    return rules_df

# Apply weights to both groups
frequent_reviewer_rules = add_t_d_weights(frequent_reviewer_rules)
infrequent_reviewer_rules = add_t_d_weights(infrequent_reviewer_rules)

# === Step B: Tabulate Rules with Weights ===
def tabulate_rules_with_weights(rules_df, label):
    print(f"\n📋 {label}:\n")
    if not rules_df.empty:
        # Prepare table headers
        headers = ["Antecedents", "Consequents", "Support", "Confidence", "Lift", "T-Weight (%)", "D-Weight (%)"]
        
        # Prepare the rows for the table
        table_data = []
        for _, row in rules_df.iterrows():
            antecedent = row['antecedents_str']
            consequent = row['consequents_str']
            table_data.append([antecedent, consequent, round(row['support'], 3), 
                               round(row['confidence'], 3), round(row['lift'], 3),
                               round(row['T-Weight (%)'], 2), round(row['D-Weight (%)'], 2)])
        
        # Display the table
        print(tabulate(table_data, headers=headers, tablefmt="grid"))
    else:
        print("No rules found.")

# Display rules with weights in tabular format
tabulate_rules_with_weights(frequent_reviewer_rules, "Reviewer Type = Frequent (with T & D Weights)")
tabulate_rules_with_weights(infrequent_reviewer_rules, "Reviewer Type = Infrequent (with T & D Weights)")

# === Step C: Exporting to CSV with weights ===
frequent_reviewer_rules.to_csv('reviewer_type_frequent_rules_with_weights.csv', index=False)
infrequent_reviewer_rules.to_csv('reviewer_type_infrequent_rules_with_weights.csv', index=False)

print("\n✅ Rules with T-Weight and D-Weight saved to CSV.")
# Out:
# 📋 Reviewer Type = Frequent (with T & D Weights):
#
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Antecedents            | Consequents                                                  |   Support |   Confidence |   Lift |   T-Weight (%) |   D-Weight (%) |
# +========================+==============================================================+===========+==============+========+================+================+
# | Reviewer_Type=Frequent | Rating=High AND Sentiment=Positive AND Verified=Not Verified |     0.095 |        0.237 |  1.183 |          31.91 |           0.97 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Sentiment=Positive AND Verified=Not Verified                 |     0.095 |        0.237 |  1.183 |          31.91 |           0.97 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Rating=High AND Verified=Not Verified                        |     0.095 |        0.237 |  1.183 |          31.91 |           0.97 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Helpfulness=None AND Verified=Not Verified                   |     0.092 |        0.23  |  1.169 |          31.91 |           0.94 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Sentiment=Positive                                           |     0.183 |        0.454 |  1.136 |          31.91 |           1.86 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Rating=High                                                  |     0.183 |        0.454 |  1.136 |          31.91 |           1.86 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Rating=High AND Sentiment=Positive                           |     0.183 |        0.454 |  1.136 |          31.91 |           1.86 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Rating=High AND Sentiment=Positive AND Verified=Verified     |     0.087 |        0.217 |  1.09  |          31.91 |           0.89 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Sentiment=Positive AND Verified=Verified                     |     0.087 |        0.217 |  1.09  |          31.91 |           0.89 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Rating=High AND Verified=Verified                            |     0.087 |        0.217 |  1.09  |          31.91 |           0.89 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Helpfulness=Less Helpful                                     |     0.156 |        0.388 |  1.074 |          31.91 |           1.59 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Helpfulness=None                                             |     0.16  |        0.398 |  1.069 |          31.91 |           1.63 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Review_Length=Short AND Verified=Verified                    |     0.083 |        0.207 |  1.056 |          31.91 |           0.85 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Verified=Not Verified                                        |     0.206 |        0.514 |  1.054 |          31.91 |           2.1  |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Review_Length=Short                                          |     0.155 |        0.385 |  1.044 |          31.91 |           1.58 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Review_Length=Medium                                         |     0.141 |        0.351 |  1.03  |          31.91 |           1.43 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Verified=Verified                                            |     0.195 |        0.486 |  0.948 |          31.91 |           1.99 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Sentiment=Neutral                                            |     0.111 |        0.277 |  0.932 |          31.91 |           1.13 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Rating=Medium AND Sentiment=Neutral                          |     0.111 |        0.277 |  0.932 |          31.91 |           1.13 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Rating=Medium                                                |     0.111 |        0.277 |  0.932 |          31.91 |           1.13 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Review_Length=Long                                           |     0.106 |        0.264 |  0.909 |          31.91 |           1.08 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Sentiment=Negative                                           |     0.108 |        0.269 |  0.887 |          31.91 |           1.1  |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Rating=Low AND Sentiment=Negative                            |     0.108 |        0.269 |  0.887 |          31.91 |           1.1  |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Rating=Low                                                   |     0.108 |        0.269 |  0.887 |          31.91 |           1.1  |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Frequent | Helpfulness=More Helpful                                     |     0.086 |        0.215 |  0.805 |          31.91 |           0.88 |
# +------------------------+--------------------------------------------------------------+-----------+--------------+--------+----------------+----------------+
#
# 📋 Reviewer Type = Infrequent (with T & D Weights):
#
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Antecedents              | Consequents                         |   Support |   Confidence |   Lift |   T-Weight (%) |   D-Weight (%) |
# +==========================+=====================================+===========+==============+========+================+================+
# | Reviewer_Type=Infrequent | Helpfulness=More Helpful            |     0.181 |        0.302 |  1.131 |          27.86 |           1.4  |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Infrequent | Rating=Low AND Sentiment=Negative   |     0.195 |        0.327 |  1.076 |          27.86 |           1.52 |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Infrequent | Rating=Low                          |     0.195 |        0.327 |  1.076 |          27.86 |           1.52 |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Infrequent | Sentiment=Negative                  |     0.195 |        0.327 |  1.076 |          27.86 |           1.52 |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Infrequent | Review_Length=Long                  |     0.185 |        0.308 |  1.061 |          27.86 |           1.43 |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Infrequent | Rating=Medium AND Sentiment=Neutral |     0.186 |        0.31  |  1.045 |          27.86 |           1.44 |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Infrequent | Sentiment=Neutral                   |     0.186 |        0.31  |  1.045 |          27.86 |           1.44 |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Infrequent | Rating=Medium                       |     0.186 |        0.31  |  1.045 |          27.86 |           1.44 |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Infrequent | Verified=Verified                   |     0.317 |        0.531 |  1.035 |          27.86 |           2.46 |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Infrequent | Review_Length=Medium                |     0.199 |        0.333 |  0.98  |          27.86 |           1.55 |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Infrequent | Review_Length=Short                 |     0.214 |        0.358 |  0.971 |          27.86 |           1.66 |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Infrequent | Verified=Not Verified               |     0.281 |        0.469 |  0.963 |          27.86 |           2.18 |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Infrequent | Helpfulness=None                    |     0.212 |        0.355 |  0.954 |          27.86 |           1.65 |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Infrequent | Helpfulness=Less Helpful            |     0.205 |        0.343 |  0.951 |          27.86 |           1.59 |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Infrequent | Sentiment=Positive                  |     0.217 |        0.363 |  0.908 |          27.86 |           1.69 |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Infrequent | Rating=High                         |     0.217 |        0.363 |  0.908 |          27.86 |           1.69 |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
# | Reviewer_Type=Infrequent | Rating=High AND Sentiment=Positive  |     0.217 |        0.363 |  0.908 |          27.86 |           1.69 |
# +--------------------------+-------------------------------------+-----------+--------------+--------+----------------+----------------+
#
# ✅ Rules with T-Weight and D-Weight saved to CSV.

# %%
print(df_trans.columns)
# Out:
# Index(['Fashion_Category=Accessories', 'Fashion_Category=Activewear',
#        'Fashion_Category=Bottoms', 'Fashion_Category=Dresses',
#        'Fashion_Category=Ethnic Wear', 'Fashion_Category=Footwear',
#        'Fashion_Category=Kidswear', 'Fashion_Category=Lingerie & Sleepwear',
#        'Fashion_Category=Menswear', 'Fashion_Category=Outerwear',
#        'Fashion_Category=Tops & Tees', 'Fashion_Category=Unknown',
#        'Fashion_Category=Womenswear', 'Helpfulness=Less Helpful',
#        'Helpfulness=More Helpful', 'Helpfulness=None', 'Rating=High',
#        'Rating=Low', 'Rating=Medium', 'Review_Length=Long',
#        'Review_Length=Medium', 'Review_Length=Short', 'Reviewer_Type=Frequent',
#        'Reviewer_Type=Infrequent', 'Sentiment=Negative', 'Sentiment=Neutral',
#        'Sentiment=Positive', 'Verified=Not Verified', 'Verified=Verified'],
#       dtype='object')

# %%
def calculate_weights(rules_df):
    rules_df = rules_df.copy()
    rules_df['antecedents_str'] = rules_df['antecedents'].apply(lambda x: ' AND '.join(sorted(x)))
    rules_df['consequents_str'] = rules_df['consequents'].apply(lambda x: ' AND '.join(sorted(x)))

    t_total = rules_df.groupby('consequents_str')['support'].transform('sum')
    d_total = rules_df.groupby('antecedents_str')['support'].transform('sum')

    rules_df['T-Weight'] = rules_df['support'] / t_total
    rules_df['D-Weight'] = rules_df['support'] / d_total

    return rules_df

# %%
import pandas as pd

# === Step A: Function to calculate T-Weight and D-Weight ===
def add_t_d_weights(rules_df):
    rules_df = rules_df.copy()

    # Convert frozensets to strings for grouping
    rules_df['antecedents_str'] = rules_df['antecedents'].apply(lambda x: ' AND '.join(sorted(list(x))))
    rules_df['consequents_str'] = rules_df['consequents'].apply(lambda x: ' AND '.join(sorted(list(x))))

    # T-Weight: support of the rule / total support for that consequent group
    rules_df['T-Weight (%)'] = rules_df.groupby('consequents_str')['support'].transform(
        lambda x: 100 * x / x.sum()
    )

    # D-Weight: support of the rule / total support for that antecedent group
    rules_df['D-Weight (%)'] = rules_df.groupby('antecedents_str')['support'].transform(
        lambda x: 100 * x / x.sum()
    )

    return rules_df

# Apply weights to both groups
frequent_reviewer_rules = add_t_d_weights(frequent_reviewer_rules)
infrequent_reviewer_rules = add_t_d_weights(infrequent_reviewer_rules)

# === Step B: Display Rules with Weights ===
def display_rules_with_weights(rules_df, label):
    print(f"\n📋 {label}:\n")
    if not rules_df.empty:
        for _, row in rules_df.iterrows():
            antecedent = row['antecedents_str']
            consequent = row['consequents_str']
            print(f"👉 IF {antecedent} THEN {consequent}")
            print(f"   - Support: {round(row['support'], 3)}")
            print(f"   - Confidence: {round(row['confidence'], 3)}")
            print(f"   - Lift: {round(row['lift'], 3)}")
            print(f"   - T-Weight:  {round(row['T-Weight (%)'], 2)}%")
            print(f"   - D-Weight:  {round(row['D-Weight (%)'], 2)}%\n")
    else:
        print("No rules found.")

# Display rules with weights
display_rules_with_weights(frequent_reviewer_rules, "Reviewer Type = Frequent (with T & D Weights)")
display_rules_with_weights(infrequent_reviewer_rules, "Reviewer Type = Infrequent (with T & D Weights)")

# === Step C: Exporting to CSV with weights ===
frequent_reviewer_rules.to_csv('reviewer_type_frequent_rules_with_weights.csv', index=False)
infrequent_reviewer_rules.to_csv('reviewer_type_infrequent_rules_with_weights.csv', index=False)

print("\n✅ Rules with T-Weight and D-Weight saved to CSV.")
# Out:
# 📋 Reviewer Type = Frequent (with T & D Weights):
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High AND Sentiment=Positive AND Verified=Not Verified
#    - Support: 0.095
#    - Confidence: 0.237
#    - Lift: 1.183
#    - T-Weight:  100.0%
#    - D-Weight:  3.04%
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Positive AND Verified=Not Verified
#    - Support: 0.095
#    - Confidence: 0.237
#    - Lift: 1.183
#    - T-Weight:  100.0%
#    - D-Weight:  3.04%
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High AND Verified=Not Verified
#    - Support: 0.095
#    - Confidence: 0.237
#    - Lift: 1.183
#    - T-Weight:  100.0%
#    - D-Weight:  3.04%
#
# 👉 IF Reviewer_Type=Frequent THEN Helpfulness=None AND Verified=Not Verified
#    - Support: 0.092
#    - Confidence: 0.23
#    - Lift: 1.169
#    - T-Weight:  100.0%
#    - D-Weight:  2.94%
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Positive
#    - Support: 0.183
#    - Confidence: 0.454
#    - Lift: 1.136
#    - T-Weight:  100.0%
#    - D-Weight:  5.82%
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High
#    - Support: 0.183
#    - Confidence: 0.454
#    - Lift: 1.136
#    - T-Weight:  100.0%
#    - D-Weight:  5.82%
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High AND Sentiment=Positive
#    - Support: 0.183
#    - Confidence: 0.454
#    - Lift: 1.136
#    - T-Weight:  100.0%
#    - D-Weight:  5.82%
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High AND Sentiment=Positive AND Verified=Verified
#    - Support: 0.087
#    - Confidence: 0.217
#    - Lift: 1.09
#    - T-Weight:  100.0%
#    - D-Weight:  2.79%
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.087
#    - Confidence: 0.217
#    - Lift: 1.09
#    - T-Weight:  100.0%
#    - D-Weight:  2.79%
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=High AND Verified=Verified
#    - Support: 0.087
#    - Confidence: 0.217
#    - Lift: 1.09
#    - T-Weight:  100.0%
#    - D-Weight:  2.79%
#
# 👉 IF Reviewer_Type=Frequent THEN Helpfulness=Less Helpful
#    - Support: 0.156
#    - Confidence: 0.388
#    - Lift: 1.074
#    - T-Weight:  100.0%
#    - D-Weight:  4.97%
#
# 👉 IF Reviewer_Type=Frequent THEN Helpfulness=None
#    - Support: 0.16
#    - Confidence: 0.398
#    - Lift: 1.069
#    - T-Weight:  100.0%
#    - D-Weight:  5.1%
#
# 👉 IF Reviewer_Type=Frequent THEN Review_Length=Short AND Verified=Verified
#    - Support: 0.083
#    - Confidence: 0.207
#    - Lift: 1.056
#    - T-Weight:  100.0%
#    - D-Weight:  2.66%
#
# 👉 IF Reviewer_Type=Frequent THEN Verified=Not Verified
#    - Support: 0.206
#    - Confidence: 0.514
#    - Lift: 1.054
#    - T-Weight:  100.0%
#    - D-Weight:  6.58%
#
# 👉 IF Reviewer_Type=Frequent THEN Review_Length=Short
#    - Support: 0.155
#    - Confidence: 0.385
#    - Lift: 1.044
#    - T-Weight:  100.0%
#    - D-Weight:  4.94%
#
# 👉 IF Reviewer_Type=Frequent THEN Review_Length=Medium
#    - Support: 0.141
#    - Confidence: 0.351
#    - Lift: 1.03
#    - T-Weight:  100.0%
#    - D-Weight:  4.5%
#
# 👉 IF Reviewer_Type=Frequent THEN Verified=Verified
#    - Support: 0.195
#    - Confidence: 0.486
#    - Lift: 0.948
#    - T-Weight:  100.0%
#    - D-Weight:  6.24%
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Neutral
#    - Support: 0.111
#    - Confidence: 0.277
#    - Lift: 0.932
#    - T-Weight:  100.0%
#    - D-Weight:  3.55%
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=Medium AND Sentiment=Neutral
#    - Support: 0.111
#    - Confidence: 0.277
#    - Lift: 0.932
#    - T-Weight:  100.0%
#    - D-Weight:  3.55%
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=Medium
#    - Support: 0.111
#    - Confidence: 0.277
#    - Lift: 0.932
#    - T-Weight:  100.0%
#    - D-Weight:  3.55%
#
# 👉 IF Reviewer_Type=Frequent THEN Review_Length=Long
#    - Support: 0.106
#    - Confidence: 0.264
#    - Lift: 0.909
#    - T-Weight:  100.0%
#    - D-Weight:  3.39%
#
# 👉 IF Reviewer_Type=Frequent THEN Sentiment=Negative
#    - Support: 0.108
#    - Confidence: 0.269
#    - Lift: 0.887
#    - T-Weight:  100.0%
#    - D-Weight:  3.45%
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.108
#    - Confidence: 0.269
#    - Lift: 0.887
#    - T-Weight:  100.0%
#    - D-Weight:  3.45%
#
# 👉 IF Reviewer_Type=Frequent THEN Rating=Low
#    - Support: 0.108
#    - Confidence: 0.269
#    - Lift: 0.887
#    - T-Weight:  100.0%
#    - D-Weight:  3.45%
#
# 👉 IF Reviewer_Type=Frequent THEN Helpfulness=More Helpful
#    - Support: 0.086
#    - Confidence: 0.215
#    - Lift: 0.805
#    - T-Weight:  100.0%
#    - D-Weight:  2.75%
#
#
# 📋 Reviewer Type = Infrequent (with T & D Weights):
#
# 👉 IF Reviewer_Type=Infrequent THEN Helpfulness=More Helpful
#    - Support: 0.181
#    - Confidence: 0.302
#    - Lift: 1.131
#    - T-Weight:  100.0%
#    - D-Weight:  5.03%
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.195
#    - Confidence: 0.327
#    - Lift: 1.076
#    - T-Weight:  100.0%
#    - D-Weight:  5.44%
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=Low
#    - Support: 0.195
#    - Confidence: 0.327
#    - Lift: 1.076
#    - T-Weight:  100.0%
#    - D-Weight:  5.44%
#
# 👉 IF Reviewer_Type=Infrequent THEN Sentiment=Negative
#    - Support: 0.195
#    - Confidence: 0.327
#    - Lift: 1.076
#    - T-Weight:  100.0%
#    - D-Weight:  5.44%
#
# 👉 IF Reviewer_Type=Infrequent THEN Review_Length=Long
#    - Support: 0.185
#    - Confidence: 0.308
#    - Lift: 1.061
#    - T-Weight:  100.0%
#    - D-Weight:  5.14%
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=Medium AND Sentiment=Neutral
#    - Support: 0.186
#    - Confidence: 0.31
#    - Lift: 1.045
#    - T-Weight:  100.0%
#    - D-Weight:  5.17%
#
# 👉 IF Reviewer_Type=Infrequent THEN Sentiment=Neutral
#    - Support: 0.186
#    - Confidence: 0.31
#    - Lift: 1.045
#    - T-Weight:  100.0%
#    - D-Weight:  5.17%
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=Medium
#    - Support: 0.186
#    - Confidence: 0.31
#    - Lift: 1.045
#    - T-Weight:  100.0%
#    - D-Weight:  5.17%
#
# 👉 IF Reviewer_Type=Infrequent THEN Verified=Verified
#    - Support: 0.317
#    - Confidence: 0.531
#    - Lift: 1.035
#    - T-Weight:  100.0%
#    - D-Weight:  8.84%
#
# 👉 IF Reviewer_Type=Infrequent THEN Review_Length=Medium
#    - Support: 0.199
#    - Confidence: 0.333
#    - Lift: 0.98
#    - T-Weight:  100.0%
#    - D-Weight:  5.56%
#
# 👉 IF Reviewer_Type=Infrequent THEN Review_Length=Short
#    - Support: 0.214
#    - Confidence: 0.358
#    - Lift: 0.971
#    - T-Weight:  100.0%
#    - D-Weight:  5.97%
#
# 👉 IF Reviewer_Type=Infrequent THEN Verified=Not Verified
#    - Support: 0.281
#    - Confidence: 0.469
#    - Lift: 0.963
#    - T-Weight:  100.0%
#    - D-Weight:  7.82%
#
# 👉 IF Reviewer_Type=Infrequent THEN Helpfulness=None
#    - Support: 0.212
#    - Confidence: 0.355
#    - Lift: 0.954
#    - T-Weight:  100.0%
#    - D-Weight:  5.91%
#
# 👉 IF Reviewer_Type=Infrequent THEN Helpfulness=Less Helpful
#    - Support: 0.205
#    - Confidence: 0.343
#    - Lift: 0.951
#    - T-Weight:  100.0%
#    - D-Weight:  5.72%
#
# 👉 IF Reviewer_Type=Infrequent THEN Sentiment=Positive
#    - Support: 0.217
#    - Confidence: 0.363
#    - Lift: 0.908
#    - T-Weight:  100.0%
#    - D-Weight:  6.05%
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=High
#    - Support: 0.217
#    - Confidence: 0.363
#    - Lift: 0.908
#    - T-Weight:  100.0%
#    - D-Weight:  6.05%
#
# 👉 IF Reviewer_Type=Infrequent THEN Rating=High AND Sentiment=Positive
#    - Support: 0.217
#    - Confidence: 0.363
#    - Lift: 0.908
#    - T-Weight:  100.0%
#    - D-Weight:  6.05%
#
#
# ✅ Rules with T-Weight and D-Weight saved to CSV.

# %%
import pandas as pd

# ---------------------------
# Helper function to calculate T and D weights
# ---------------------------
def calculate_weights_percentage(rules_df, category_column):
    def compute_t_weight(row):
        return row['support'] * 100 if category_column in str(row['antecedents']) else 0

    def compute_d_weight(row, max_lift):
        return (row['lift'] / max_lift) * 100 if category_column in str(row['antecedents']) else 0

    # Compute T Weight normally
    rules_df['T Weight (%)'] = rules_df.apply(compute_t_weight, axis=1)
    
    # Normalize D Weight using the maximum lift
    max_lift = rules_df[rules_df['antecedents'].astype(str).str.contains(category_column)]['lift'].max()
    rules_df['D Weight (%)'] = rules_df.apply(lambda row: compute_d_weight(row, max_lift), axis=1)

    return rules_df


# ---------------------------
# Main loop to process each fashion category
# ---------------------------
for category in fashion_categories:
    cat_tag = f"Fashion_Category={category}"

    if cat_tag in df_trans.columns:
        # Strict filter: only that category alone in the antecedent
        cat_rules = rules[rules['antecedents'].apply(
            lambda x: cat_tag in str(x) and len(x) == 1
        )].sort_values(by='lift', ascending=False)

        print(f"\n📂 Rules for '{cat_tag}':")
        if not cat_rules.empty:
            # ✅ Add T/D Weights as percentage
            cat_rules = calculate_weights_percentage(cat_rules, cat_tag)

            for _, row in cat_rules.iterrows():
                antecedent = ' AND '.join(list(row['antecedents']))
                consequent = ' AND '.join(list(row['consequents']))
                print(f"👉 IF {antecedent} THEN {consequent}")
                print(f"   - Support: {round(row['support'], 3)}")
                print(f"   - Confidence: {round(row['confidence'], 3)}")
                print(f"   - Lift: {round(row['lift'], 3)}")
                print(f"   - T Weight (Typicality): {row['T Weight (%)']:.2f}%")
                print(f"   - D Weight (Discriminability): {row['D Weight (%)']:.2f}%")

            # ✅ Save summary to CSV
            summary_df = cat_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift',
                                    'T Weight (%)', 'D Weight (%)']].copy()
            summary_df['antecedents'] = summary_df['antecedents'].apply(lambda x: ' AND '.join(x))
            summary_df['consequents'] = summary_df['consequents'].apply(lambda x: ' AND '.join(x))
            summary_df.to_csv(f"fashion_category_rules/{category}_category_rules_summary.csv", index=False)
        else:
            print(f"❌ No rules generated for category '{category}'.")
    else:
        print(f"❌ Column '{cat_tag}' not found in the DataFrame.")
# Out:
# 📂 Rules for 'Fashion_Category=Accessories':
# 👉 IF Fashion_Category=Accessories THEN Reviewer_Type=Frequent AND Verified=Verified
#    - Support: 0.023
#    - Confidence: 0.235
#    - Lift: 1.201
#    - T Weight (Typicality): 2.28%
#    - D Weight (Discriminability): 100.00%
# 👉 IF Fashion_Category=Accessories THEN Reviewer_Type=Frequent
#    - Support: 0.045
#    - Confidence: 0.459
#    - Lift: 1.143
#    - T Weight (Typicality): 4.46%
#    - D Weight (Discriminability): 95.17%
# 👉 IF Fashion_Category=Accessories THEN Sentiment=Negative
#    - Support: 0.033
#    - Confidence: 0.337
#    - Lift: 1.109
#    - T Weight (Typicality): 3.27%
#    - D Weight (Discriminability): 92.37%
# 👉 IF Fashion_Category=Accessories THEN Rating=Low
#    - Support: 0.033
#    - Confidence: 0.337
#    - Lift: 1.109
#    - T Weight (Typicality): 3.27%
#    - D Weight (Discriminability): 92.37%
# 👉 IF Fashion_Category=Accessories THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.033
#    - Confidence: 0.337
#    - Lift: 1.109
#    - T Weight (Typicality): 3.27%
#    - D Weight (Discriminability): 92.37%
# 👉 IF Fashion_Category=Accessories THEN Review_Length=Long
#    - Support: 0.031
#    - Confidence: 0.316
#    - Lift: 1.088
#    - T Weight (Typicality): 3.08%
#    - D Weight (Discriminability): 90.62%
# 👉 IF Fashion_Category=Accessories THEN Verified=Not Verified AND Reviewer_Type=Frequent
#    - Support: 0.022
#    - Confidence: 0.224
#    - Lift: 1.088
#    - T Weight (Typicality): 2.18%
#    - D Weight (Discriminability): 90.59%
# 👉 IF Fashion_Category=Accessories THEN Helpfulness=More Helpful
#    - Support: 0.028
#    - Confidence: 0.286
#    - Lift: 1.071
#    - T Weight (Typicality): 2.78%
#    - D Weight (Discriminability): 89.15%
# 👉 IF Fashion_Category=Accessories THEN Helpfulness=Less Helpful
#    - Support: 0.036
#    - Confidence: 0.367
#    - Lift: 1.017
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 84.71%
# 👉 IF Fashion_Category=Accessories THEN Verified=Not Verified
#    - Support: 0.048
#    - Confidence: 0.49
#    - Lift: 1.006
#    - T Weight (Typicality): 4.76%
#    - D Weight (Discriminability): 83.73%
# 👉 IF Fashion_Category=Accessories THEN Sentiment=Neutral
#    - Support: 0.029
#    - Confidence: 0.296
#    - Lift: 0.998
#    - T Weight (Typicality): 2.88%
#    - D Weight (Discriminability): 83.07%
# 👉 IF Fashion_Category=Accessories THEN Rating=Medium
#    - Support: 0.029
#    - Confidence: 0.296
#    - Lift: 0.998
#    - T Weight (Typicality): 2.88%
#    - D Weight (Discriminability): 83.07%
# 👉 IF Fashion_Category=Accessories THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.029
#    - Confidence: 0.296
#    - Lift: 0.998
#    - T Weight (Typicality): 2.88%
#    - D Weight (Discriminability): 83.07%
# 👉 IF Fashion_Category=Accessories THEN Verified=Verified
#    - Support: 0.05
#    - Confidence: 0.51
#    - Lift: 0.995
#    - T Weight (Typicality): 4.96%
#    - D Weight (Discriminability): 82.84%
# 👉 IF Fashion_Category=Accessories THEN Review_Length=Medium
#    - Support: 0.033
#    - Confidence: 0.337
#    - Lift: 0.99
#    - T Weight (Typicality): 3.27%
#    - D Weight (Discriminability): 82.41%
# 👉 IF Fashion_Category=Accessories THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.026
#    - Confidence: 0.265
#    - Lift: 0.945
#    - T Weight (Typicality): 2.58%
#    - D Weight (Discriminability): 78.69%
# 👉 IF Fashion_Category=Accessories THEN Review_Length=Short
#    - Support: 0.034
#    - Confidence: 0.347
#    - Lift: 0.94
#    - T Weight (Typicality): 3.37%
#    - D Weight (Discriminability): 78.28%
# 👉 IF Fashion_Category=Accessories THEN Helpfulness=None
#    - Support: 0.034
#    - Confidence: 0.347
#    - Lift: 0.933
#    - T Weight (Typicality): 3.37%
#    - D Weight (Discriminability): 77.66%
# 👉 IF Fashion_Category=Accessories THEN Sentiment=Positive
#    - Support: 0.036
#    - Confidence: 0.367
#    - Lift: 0.919
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 76.51%
# 👉 IF Fashion_Category=Accessories THEN Sentiment=Positive AND Rating=High
#    - Support: 0.036
#    - Confidence: 0.367
#    - Lift: 0.919
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 76.51%
# 👉 IF Fashion_Category=Accessories THEN Rating=High
#    - Support: 0.036
#    - Confidence: 0.367
#    - Lift: 0.919
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 76.51%
# 👉 IF Fashion_Category=Accessories THEN Reviewer_Type=Infrequent
#    - Support: 0.053
#    - Confidence: 0.541
#    - Lift: 0.904
#    - T Weight (Typicality): 5.26%
#    - D Weight (Discriminability): 75.28%
# 👉 IF Fashion_Category=Accessories THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.027
#    - Confidence: 0.276
#    - Lift: 0.868
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 72.27%
#
# 📂 Rules for 'Fashion_Category=Tops & Tees':
# 👉 IF Fashion_Category=Tops & Tees THEN Reviewer_Type=Frequent AND Verified=Verified
#    - Support: 0.022
#    - Confidence: 0.227
#    - Lift: 1.161
#    - T Weight (Typicality): 2.18%
#    - D Weight (Discriminability): 100.00%
# 👉 IF Fashion_Category=Tops & Tees THEN Reviewer_Type=Frequent
#    - Support: 0.044
#    - Confidence: 0.454
#    - Lift: 1.129
#    - T Weight (Typicality): 4.37%
#    - D Weight (Discriminability): 97.28%
# 👉 IF Fashion_Category=Tops & Tees THEN Review_Length=Long
#    - Support: 0.031
#    - Confidence: 0.32
#    - Lift: 1.099
#    - T Weight (Typicality): 3.08%
#    - D Weight (Discriminability): 94.74%
# 👉 IF Fashion_Category=Tops & Tees THEN Verified=Not Verified AND Reviewer_Type=Frequent
#    - Support: 0.022
#    - Confidence: 0.227
#    - Lift: 1.099
#    - T Weight (Typicality): 2.18%
#    - D Weight (Discriminability): 94.71%
# 👉 IF Fashion_Category=Tops & Tees THEN Sentiment=Negative
#    - Support: 0.031
#    - Confidence: 0.32
#    - Lift: 1.053
#    - T Weight (Typicality): 3.08%
#    - D Weight (Discriminability): 90.72%
# 👉 IF Fashion_Category=Tops & Tees THEN Rating=Low
#    - Support: 0.031
#    - Confidence: 0.32
#    - Lift: 1.053
#    - T Weight (Typicality): 3.08%
#    - D Weight (Discriminability): 90.72%
# 👉 IF Fashion_Category=Tops & Tees THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.031
#    - Confidence: 0.32
#    - Lift: 1.053
#    - T Weight (Typicality): 3.08%
#    - D Weight (Discriminability): 90.72%
# 👉 IF Fashion_Category=Tops & Tees THEN Helpfulness=More Helpful
#    - Support: 0.027
#    - Confidence: 0.278
#    - Lift: 1.043
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 89.88%
# 👉 IF Fashion_Category=Tops & Tees THEN Rating=Medium
#    - Support: 0.03
#    - Confidence: 0.309
#    - Lift: 1.043
#    - T Weight (Typicality): 2.98%
#    - D Weight (Discriminability): 89.84%
# 👉 IF Fashion_Category=Tops & Tees THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.03
#    - Confidence: 0.309
#    - Lift: 1.043
#    - T Weight (Typicality): 2.98%
#    - D Weight (Discriminability): 89.84%
# 👉 IF Fashion_Category=Tops & Tees THEN Sentiment=Neutral
#    - Support: 0.03
#    - Confidence: 0.309
#    - Lift: 1.043
#    - T Weight (Typicality): 2.98%
#    - D Weight (Discriminability): 89.84%
# 👉 IF Fashion_Category=Tops & Tees THEN Helpfulness=Less Helpful
#    - Support: 0.036
#    - Confidence: 0.371
#    - Lift: 1.028
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 88.56%
# 👉 IF Fashion_Category=Tops & Tees THEN Verified=Not Verified
#    - Support: 0.048
#    - Confidence: 0.495
#    - Lift: 1.016
#    - T Weight (Typicality): 4.76%
#    - D Weight (Discriminability): 87.54%
# 👉 IF Fashion_Category=Tops & Tees THEN Verified=Verified
#    - Support: 0.049
#    - Confidence: 0.505
#    - Lift: 0.985
#    - T Weight (Typicality): 4.86%
#    - D Weight (Discriminability): 84.87%
# 👉 IF Fashion_Category=Tops & Tees THEN Review_Length=Medium
#    - Support: 0.032
#    - Confidence: 0.33
#    - Lift: 0.969
#    - T Weight (Typicality): 3.17%
#    - D Weight (Discriminability): 83.54%
# 👉 IF Fashion_Category=Tops & Tees THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.026
#    - Confidence: 0.268
#    - Lift: 0.955
#    - T Weight (Typicality): 2.58%
#    - D Weight (Discriminability): 82.27%
# 👉 IF Fashion_Category=Tops & Tees THEN Review_Length=Short
#    - Support: 0.034
#    - Confidence: 0.351
#    - Lift: 0.95
#    - T Weight (Typicality): 3.37%
#    - D Weight (Discriminability): 81.84%
# 👉 IF Fashion_Category=Tops & Tees THEN Helpfulness=None
#    - Support: 0.034
#    - Confidence: 0.351
#    - Lift: 0.942
#    - T Weight (Typicality): 3.37%
#    - D Weight (Discriminability): 81.19%
# 👉 IF Fashion_Category=Tops & Tees THEN Sentiment=Positive
#    - Support: 0.036
#    - Confidence: 0.371
#    - Lift: 0.928
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 79.99%
# 👉 IF Fashion_Category=Tops & Tees THEN Sentiment=Positive AND Rating=High
#    - Support: 0.036
#    - Confidence: 0.371
#    - Lift: 0.928
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 79.99%
# 👉 IF Fashion_Category=Tops & Tees THEN Rating=High
#    - Support: 0.036
#    - Confidence: 0.371
#    - Lift: 0.928
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 79.99%
# 👉 IF Fashion_Category=Tops & Tees THEN Reviewer_Type=Infrequent
#    - Support: 0.053
#    - Confidence: 0.546
#    - Lift: 0.913
#    - T Weight (Typicality): 5.26%
#    - D Weight (Discriminability): 78.70%
# 👉 IF Fashion_Category=Tops & Tees THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.027
#    - Confidence: 0.278
#    - Lift: 0.877
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 75.55%
#
# 📂 Rules for 'Fashion_Category=Bottoms':
# 👉 IF Fashion_Category=Bottoms THEN Reviewer_Type=Frequent AND Verified=Verified
#    - Support: 0.02
#    - Confidence: 0.222
#    - Lift: 1.137
#    - T Weight (Typicality): 1.98%
#    - D Weight (Discriminability): 100.00%
# 👉 IF Fashion_Category=Bottoms THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.028
#    - Confidence: 0.311
#    - Lift: 1.049
#    - T Weight (Typicality): 2.78%
#    - D Weight (Discriminability): 92.24%
# 👉 IF Fashion_Category=Bottoms THEN Sentiment=Neutral
#    - Support: 0.028
#    - Confidence: 0.311
#    - Lift: 1.049
#    - T Weight (Typicality): 2.78%
#    - D Weight (Discriminability): 92.24%
# 👉 IF Fashion_Category=Bottoms THEN Rating=Medium
#    - Support: 0.028
#    - Confidence: 0.311
#    - Lift: 1.049
#    - T Weight (Typicality): 2.78%
#    - D Weight (Discriminability): 92.24%
# 👉 IF Fashion_Category=Bottoms THEN Helpfulness=More Helpful
#    - Support: 0.025
#    - Confidence: 0.278
#    - Lift: 1.041
#    - T Weight (Typicality): 2.48%
#    - D Weight (Discriminability): 91.54%
# 👉 IF Fashion_Category=Bottoms THEN Review_Length=Long
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 1.032
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 90.77%
# 👉 IF Fashion_Category=Bottoms THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.026
#    - Confidence: 0.289
#    - Lift: 1.029
#    - T Weight (Typicality): 2.58%
#    - D Weight (Discriminability): 90.49%
# 👉 IF Fashion_Category=Bottoms THEN Reviewer_Type=Frequent
#    - Support: 0.037
#    - Confidence: 0.411
#    - Lift: 1.023
#    - T Weight (Typicality): 3.67%
#    - D Weight (Discriminability): 89.99%
# 👉 IF Fashion_Category=Bottoms THEN Verified=Verified
#    - Support: 0.047
#    - Confidence: 0.522
#    - Lift: 1.018
#    - T Weight (Typicality): 4.66%
#    - D Weight (Discriminability): 89.55%
# 👉 IF Fashion_Category=Bottoms THEN Review_Length=Medium
#    - Support: 0.031
#    - Confidence: 0.344
#    - Lift: 1.012
#    - T Weight (Typicality): 3.08%
#    - D Weight (Discriminability): 89.02%
# 👉 IF Fashion_Category=Bottoms THEN Rating=High
#    - Support: 0.036
#    - Confidence: 0.4
#    - Lift: 1.0
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 87.99%
# 👉 IF Fashion_Category=Bottoms THEN Sentiment=Positive
#    - Support: 0.036
#    - Confidence: 0.4
#    - Lift: 1.0
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 87.99%
# 👉 IF Fashion_Category=Bottoms THEN Sentiment=Positive AND Rating=High
#    - Support: 0.036
#    - Confidence: 0.4
#    - Lift: 1.0
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 87.99%
# 👉 IF Fashion_Category=Bottoms THEN Helpfulness=None
#    - Support: 0.033
#    - Confidence: 0.367
#    - Lift: 0.986
#    - T Weight (Typicality): 3.27%
#    - D Weight (Discriminability): 86.68%
# 👉 IF Fashion_Category=Bottoms THEN Helpfulness=Less Helpful
#    - Support: 0.032
#    - Confidence: 0.356
#    - Lift: 0.985
#    - T Weight (Typicality): 3.17%
#    - D Weight (Discriminability): 86.59%
# 👉 IF Fashion_Category=Bottoms THEN Reviewer_Type=Infrequent
#    - Support: 0.053
#    - Confidence: 0.589
#    - Lift: 0.984
#    - T Weight (Typicality): 5.26%
#    - D Weight (Discriminability): 86.58%
# 👉 IF Fashion_Category=Bottoms THEN Verified=Not Verified
#    - Support: 0.043
#    - Confidence: 0.478
#    - Lift: 0.981
#    - T Weight (Typicality): 4.27%
#    - D Weight (Discriminability): 86.26%
# 👉 IF Fashion_Category=Bottoms THEN Review_Length=Short
#    - Support: 0.032
#    - Confidence: 0.356
#    - Lift: 0.963
#    - T Weight (Typicality): 3.17%
#    - D Weight (Discriminability): 84.73%
# 👉 IF Fashion_Category=Bottoms THEN Sentiment=Negative
#    - Support: 0.026
#    - Confidence: 0.289
#    - Lift: 0.952
#    - T Weight (Typicality): 2.58%
#    - D Weight (Discriminability): 83.69%
# 👉 IF Fashion_Category=Bottoms THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.026
#    - Confidence: 0.289
#    - Lift: 0.952
#    - T Weight (Typicality): 2.58%
#    - D Weight (Discriminability): 83.69%
# 👉 IF Fashion_Category=Bottoms THEN Rating=Low
#    - Support: 0.026
#    - Confidence: 0.289
#    - Lift: 0.952
#    - T Weight (Typicality): 2.58%
#    - D Weight (Discriminability): 83.69%
# 👉 IF Fashion_Category=Bottoms THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 0.945
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 83.11%
#
# 📂 Rules for 'Fashion_Category=Dresses':
# 👉 IF Fashion_Category=Dresses THEN Reviewer_Type=Frequent AND Verified=Verified
#    - Support: 0.023
#    - Confidence: 0.235
#    - Lift: 1.201
#    - T Weight (Typicality): 2.28%
#    - D Weight (Discriminability): 100.00%
# 👉 IF Fashion_Category=Dresses THEN Reviewer_Type=Frequent
#    - Support: 0.046
#    - Confidence: 0.469
#    - Lift: 1.168
#    - T Weight (Typicality): 4.56%
#    - D Weight (Discriminability): 97.28%
# 👉 IF Fashion_Category=Dresses THEN Verified=Not Verified AND Reviewer_Type=Frequent
#    - Support: 0.023
#    - Confidence: 0.235
#    - Lift: 1.137
#    - T Weight (Typicality): 2.28%
#    - D Weight (Discriminability): 94.71%
# 👉 IF Fashion_Category=Dresses THEN Review_Length=Long
#    - Support: 0.032
#    - Confidence: 0.327
#    - Lift: 1.123
#    - T Weight (Typicality): 3.17%
#    - D Weight (Discriminability): 93.55%
# 👉 IF Fashion_Category=Dresses THEN Sentiment=Negative
#    - Support: 0.032
#    - Confidence: 0.327
#    - Lift: 1.076
#    - T Weight (Typicality): 3.17%
#    - D Weight (Discriminability): 89.57%
# 👉 IF Fashion_Category=Dresses THEN Rating=Low
#    - Support: 0.032
#    - Confidence: 0.327
#    - Lift: 1.076
#    - T Weight (Typicality): 3.17%
#    - D Weight (Discriminability): 89.57%
# 👉 IF Fashion_Category=Dresses THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.032
#    - Confidence: 0.327
#    - Lift: 1.076
#    - T Weight (Typicality): 3.17%
#    - D Weight (Discriminability): 89.57%
# 👉 IF Fashion_Category=Dresses THEN Helpfulness=More Helpful
#    - Support: 0.028
#    - Confidence: 0.286
#    - Lift: 1.071
#    - T Weight (Typicality): 2.78%
#    - D Weight (Discriminability): 89.15%
# 👉 IF Fashion_Category=Dresses THEN Rating=Medium
#    - Support: 0.03
#    - Confidence: 0.306
#    - Lift: 1.032
#    - T Weight (Typicality): 2.98%
#    - D Weight (Discriminability): 85.94%
# 👉 IF Fashion_Category=Dresses THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.03
#    - Confidence: 0.306
#    - Lift: 1.032
#    - T Weight (Typicality): 2.98%
#    - D Weight (Discriminability): 85.94%
# 👉 IF Fashion_Category=Dresses THEN Sentiment=Neutral
#    - Support: 0.03
#    - Confidence: 0.306
#    - Lift: 1.032
#    - T Weight (Typicality): 2.98%
#    - D Weight (Discriminability): 85.94%
# 👉 IF Fashion_Category=Dresses THEN Helpfulness=Less Helpful
#    - Support: 0.036
#    - Confidence: 0.367
#    - Lift: 1.017
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 84.71%
# 👉 IF Fashion_Category=Dresses THEN Verified=Not Verified
#    - Support: 0.048
#    - Confidence: 0.49
#    - Lift: 1.006
#    - T Weight (Typicality): 4.76%
#    - D Weight (Discriminability): 83.73%
# 👉 IF Fashion_Category=Dresses THEN Verified=Verified
#    - Support: 0.05
#    - Confidence: 0.51
#    - Lift: 0.995
#    - T Weight (Typicality): 4.96%
#    - D Weight (Discriminability): 82.84%
# 👉 IF Fashion_Category=Dresses THEN Review_Length=Medium
#    - Support: 0.032
#    - Confidence: 0.327
#    - Lift: 0.96
#    - T Weight (Typicality): 3.17%
#    - D Weight (Discriminability): 79.91%
# 👉 IF Fashion_Category=Dresses THEN Review_Length=Short
#    - Support: 0.034
#    - Confidence: 0.347
#    - Lift: 0.94
#    - T Weight (Typicality): 3.37%
#    - D Weight (Discriminability): 78.28%
# 👉 IF Fashion_Category=Dresses THEN Helpfulness=None
#    - Support: 0.034
#    - Confidence: 0.347
#    - Lift: 0.933
#    - T Weight (Typicality): 3.37%
#    - D Weight (Discriminability): 77.66%
# 👉 IF Fashion_Category=Dresses THEN Sentiment=Positive
#    - Support: 0.036
#    - Confidence: 0.367
#    - Lift: 0.919
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 76.51%
# 👉 IF Fashion_Category=Dresses THEN Sentiment=Positive AND Rating=High
#    - Support: 0.036
#    - Confidence: 0.367
#    - Lift: 0.919
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 76.51%
# 👉 IF Fashion_Category=Dresses THEN Rating=High
#    - Support: 0.036
#    - Confidence: 0.367
#    - Lift: 0.919
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 76.51%
# 👉 IF Fashion_Category=Dresses THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.025
#    - Confidence: 0.255
#    - Lift: 0.909
#    - T Weight (Typicality): 2.48%
#    - D Weight (Discriminability): 75.66%
# 👉 IF Fashion_Category=Dresses THEN Reviewer_Type=Infrequent
#    - Support: 0.052
#    - Confidence: 0.531
#    - Lift: 0.887
#    - T Weight (Typicality): 5.16%
#    - D Weight (Discriminability): 73.86%
# 👉 IF Fashion_Category=Dresses THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.027
#    - Confidence: 0.276
#    - Lift: 0.868
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 72.27%
#
# 📂 Rules for 'Fashion_Category=Outerwear':
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Review_Length=Long
#    - Support: 0.017
#    - Confidence: 0.21
#    - Lift: 1.137
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 100.00%
# 👉 IF Fashion_Category=Outerwear THEN Verified=Not Verified AND Helpfulness=None
#    - Support: 0.018
#    - Confidence: 0.222
#    - Lift: 1.131
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 99.47%
# 👉 IF Fashion_Category=Outerwear THEN Helpfulness=None
#    - Support: 0.034
#    - Confidence: 0.42
#    - Lift: 1.128
#    - T Weight (Typicality): 3.37%
#    - D Weight (Discriminability): 99.20%
# 👉 IF Fashion_Category=Outerwear THEN Review_Length=Long
#    - Support: 0.026
#    - Confidence: 0.321
#    - Lift: 1.104
#    - T Weight (Typicality): 2.58%
#    - D Weight (Discriminability): 97.09%
# 👉 IF Fashion_Category=Outerwear THEN Rating=Medium
#    - Support: 0.026
#    - Confidence: 0.321
#    - Lift: 1.082
#    - T Weight (Typicality): 2.58%
#    - D Weight (Discriminability): 95.14%
# 👉 IF Fashion_Category=Outerwear THEN Rating=Medium AND Sentiment=Neutral
#    - Support: 0.026
#    - Confidence: 0.321
#    - Lift: 1.082
#    - T Weight (Typicality): 2.58%
#    - D Weight (Discriminability): 95.14%
# 👉 IF Fashion_Category=Outerwear THEN Sentiment=Neutral
#    - Support: 0.026
#    - Confidence: 0.321
#    - Lift: 1.082
#    - T Weight (Typicality): 2.58%
#    - D Weight (Discriminability): 95.14%
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.027
#    - Confidence: 0.333
#    - Lift: 1.05
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 92.32%
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.018
#    - Confidence: 0.222
#    - Lift: 1.047
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 92.03%
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Sentiment=Positive AND Rating=High
#    - Support: 0.018
#    - Confidence: 0.222
#    - Lift: 1.023
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 89.93%
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Sentiment=Positive
#    - Support: 0.018
#    - Confidence: 0.222
#    - Lift: 1.023
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 89.93%
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.018
#    - Confidence: 0.222
#    - Lift: 1.023
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 89.93%
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.017
#    - Confidence: 0.21
#    - Lift: 1.022
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 89.86%
# 👉 IF Fashion_Category=Outerwear THEN Verified=Not Verified AND Reviewer_Type=Frequent
#    - Support: 0.017
#    - Confidence: 0.21
#    - Lift: 1.017
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 89.42%
# 👉 IF Fashion_Category=Outerwear THEN Review_Length=Medium
#    - Support: 0.028
#    - Confidence: 0.346
#    - Lift: 1.016
#    - T Weight (Typicality): 2.78%
#    - D Weight (Discriminability): 89.32%
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent
#    - Support: 0.049
#    - Confidence: 0.605
#    - Lift: 1.011
#    - T Weight (Typicality): 4.86%
#    - D Weight (Discriminability): 88.91%
# 👉 IF Fashion_Category=Outerwear THEN Verified=Verified
#    - Support: 0.042
#    - Confidence: 0.519
#    - Lift: 1.011
#    - T Weight (Typicality): 4.17%
#    - D Weight (Discriminability): 88.88%
# 👉 IF Fashion_Category=Outerwear THEN Helpfulness=Less Helpful
#    - Support: 0.029
#    - Confidence: 0.358
#    - Lift: 0.991
#    - T Weight (Typicality): 2.88%
#    - D Weight (Discriminability): 87.17%
# 👉 IF Fashion_Category=Outerwear THEN Verified=Not Verified
#    - Support: 0.039
#    - Confidence: 0.481
#    - Lift: 0.988
#    - T Weight (Typicality): 3.87%
#    - D Weight (Discriminability): 86.91%
# 👉 IF Fashion_Category=Outerwear THEN Sentiment=Positive
#    - Support: 0.032
#    - Confidence: 0.395
#    - Lift: 0.988
#    - T Weight (Typicality): 3.17%
#    - D Weight (Discriminability): 86.88%
# 👉 IF Fashion_Category=Outerwear THEN Sentiment=Positive AND Rating=High
#    - Support: 0.032
#    - Confidence: 0.395
#    - Lift: 0.988
#    - T Weight (Typicality): 3.17%
#    - D Weight (Discriminability): 86.88%
# 👉 IF Fashion_Category=Outerwear THEN Rating=High
#    - Support: 0.032
#    - Confidence: 0.395
#    - Lift: 0.988
#    - T Weight (Typicality): 3.17%
#    - D Weight (Discriminability): 86.88%
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Frequent
#    - Support: 0.032
#    - Confidence: 0.395
#    - Lift: 0.983
#    - T Weight (Typicality): 3.17%
#    - D Weight (Discriminability): 86.45%
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Review_Length=Short
#    - Support: 0.017
#    - Confidence: 0.21
#    - Lift: 0.979
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 86.11%
# 👉 IF Fashion_Category=Outerwear THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.022
#    - Confidence: 0.272
#    - Lift: 0.967
#    - T Weight (Typicality): 2.18%
#    - D Weight (Discriminability): 85.06%
# 👉 IF Fashion_Category=Outerwear THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.023
#    - Confidence: 0.284
#    - Lift: 0.935
#    - T Weight (Typicality): 2.28%
#    - D Weight (Discriminability): 82.24%
# 👉 IF Fashion_Category=Outerwear THEN Sentiment=Negative
#    - Support: 0.023
#    - Confidence: 0.284
#    - Lift: 0.935
#    - T Weight (Typicality): 2.28%
#    - D Weight (Discriminability): 82.24%
# 👉 IF Fashion_Category=Outerwear THEN Rating=Low
#    - Support: 0.023
#    - Confidence: 0.284
#    - Lift: 0.935
#    - T Weight (Typicality): 2.28%
#    - D Weight (Discriminability): 82.24%
# 👉 IF Fashion_Category=Outerwear THEN Review_Length=Short
#    - Support: 0.027
#    - Confidence: 0.333
#    - Lift: 0.903
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 79.41%
# 👉 IF Fashion_Category=Outerwear THEN Helpfulness=More Helpful
#    - Support: 0.018
#    - Confidence: 0.222
#    - Lift: 0.833
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 73.21%
#
# 📂 Rules for 'Fashion_Category=Ethnic Wear':
# 👉 IF Fashion_Category=Ethnic Wear THEN Reviewer_Type=Infrequent
#    - Support: 0.012
#    - Confidence: 0.923
#    - Lift: 1.543
#    - T Weight (Typicality): 1.19%
#    - D Weight (Discriminability): 100.00%
#
# 📂 Rules for 'Fashion_Category=Footwear':
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Review_Length=Long
#    - Support: 0.017
#    - Confidence: 0.23
#    - Lift: 1.245
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 100.00%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Rating=Low AND Sentiment=Negative
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.245
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 99.97%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Sentiment=Negative
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.245
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 99.97%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Rating=Low
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.245
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 99.97%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Review_Length=Medium
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.22
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 97.98%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.025
#    - Confidence: 0.338
#    - Lift: 1.203
#    - T Weight (Typicality): 2.48%
#    - D Weight (Discriminability): 96.65%
# 👉 IF Fashion_Category=Footwear THEN Helpfulness=More Helpful AND Reviewer_Type=Infrequent
#    - Support: 0.016
#    - Confidence: 0.216
#    - Lift: 1.198
#    - T Weight (Typicality): 1.59%
#    - D Weight (Discriminability): 96.19%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.184
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 95.14%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent
#    - Support: 0.052
#    - Confidence: 0.703
#    - Lift: 1.175
#    - T Weight (Typicality): 5.16%
#    - D Weight (Discriminability): 94.35%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Sentiment=Neutral AND Rating=Medium
#    - Support: 0.016
#    - Confidence: 0.216
#    - Lift: 1.165
#    - T Weight (Typicality): 1.59%
#    - D Weight (Discriminability): 93.61%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Sentiment=Neutral
#    - Support: 0.016
#    - Confidence: 0.216
#    - Lift: 1.165
#    - T Weight (Typicality): 1.59%
#    - D Weight (Discriminability): 93.61%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Rating=Medium
#    - Support: 0.016
#    - Confidence: 0.216
#    - Lift: 1.165
#    - T Weight (Typicality): 1.59%
#    - D Weight (Discriminability): 93.61%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.027
#    - Confidence: 0.365
#    - Lift: 1.149
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 92.32%
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Positive AND Verified=Not Verified AND Rating=High
#    - Support: 0.017
#    - Confidence: 0.23
#    - Lift: 1.146
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 92.08%
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Positive AND Verified=Not Verified
#    - Support: 0.017
#    - Confidence: 0.23
#    - Lift: 1.146
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 92.08%
# 👉 IF Fashion_Category=Footwear THEN Verified=Not Verified AND Rating=High
#    - Support: 0.017
#    - Confidence: 0.23
#    - Lift: 1.146
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 92.08%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.146
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 92.03%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.12
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 89.93%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Sentiment=Positive
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.12
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 89.93%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Sentiment=Positive AND Rating=High
#    - Support: 0.018
#    - Confidence: 0.243
#    - Lift: 1.12
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 89.93%
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Positive AND Rating=High
#    - Support: 0.033
#    - Confidence: 0.446
#    - Lift: 1.115
#    - T Weight (Typicality): 3.27%
#    - D Weight (Discriminability): 89.59%
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Positive
#    - Support: 0.033
#    - Confidence: 0.446
#    - Lift: 1.115
#    - T Weight (Typicality): 3.27%
#    - D Weight (Discriminability): 89.59%
# 👉 IF Fashion_Category=Footwear THEN Rating=High
#    - Support: 0.033
#    - Confidence: 0.446
#    - Lift: 1.115
#    - T Weight (Typicality): 3.27%
#    - D Weight (Discriminability): 89.59%
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Positive AND Reviewer_Type=Frequent AND Rating=High
#    - Support: 0.015
#    - Confidence: 0.203
#    - Lift: 1.11
#    - T Weight (Typicality): 1.49%
#    - D Weight (Discriminability): 89.19%
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Positive AND Reviewer_Type=Frequent
#    - Support: 0.015
#    - Confidence: 0.203
#    - Lift: 1.11
#    - T Weight (Typicality): 1.49%
#    - D Weight (Discriminability): 89.19%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Frequent AND Rating=High
#    - Support: 0.015
#    - Confidence: 0.203
#    - Lift: 1.11
#    - T Weight (Typicality): 1.49%
#    - D Weight (Discriminability): 89.19%
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.016
#    - Confidence: 0.216
#    - Lift: 1.084
#    - T Weight (Typicality): 1.59%
#    - D Weight (Discriminability): 87.09%
# 👉 IF Fashion_Category=Footwear THEN Rating=High AND Verified=Verified
#    - Support: 0.016
#    - Confidence: 0.216
#    - Lift: 1.084
#    - T Weight (Typicality): 1.59%
#    - D Weight (Discriminability): 87.09%
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Positive AND Rating=High AND Verified=Verified
#    - Support: 0.016
#    - Confidence: 0.216
#    - Lift: 1.084
#    - T Weight (Typicality): 1.59%
#    - D Weight (Discriminability): 87.09%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Infrequent AND Review_Length=Short
#    - Support: 0.017
#    - Confidence: 0.23
#    - Lift: 1.072
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 86.11%
# 👉 IF Fashion_Category=Footwear THEN Helpfulness=None
#    - Support: 0.029
#    - Confidence: 0.392
#    - Lift: 1.053
#    - T Weight (Typicality): 2.88%
#    - D Weight (Discriminability): 84.61%
# 👉 IF Fashion_Category=Footwear THEN Review_Length=Medium
#    - Support: 0.026
#    - Confidence: 0.351
#    - Lift: 1.033
#    - T Weight (Typicality): 2.58%
#    - D Weight (Discriminability): 82.94%
# 👉 IF Fashion_Category=Footwear THEN Review_Length=Short AND Verified=Verified
#    - Support: 0.015
#    - Confidence: 0.203
#    - Lift: 1.032
#    - T Weight (Typicality): 1.49%
#    - D Weight (Discriminability): 82.89%
# 👉 IF Fashion_Category=Footwear THEN Verified=Not Verified AND Helpfulness=None
#    - Support: 0.015
#    - Confidence: 0.203
#    - Lift: 1.032
#    - T Weight (Typicality): 1.49%
#    - D Weight (Discriminability): 82.89%
# 👉 IF Fashion_Category=Footwear THEN Review_Length=Short
#    - Support: 0.028
#    - Confidence: 0.378
#    - Lift: 1.025
#    - T Weight (Typicality): 2.78%
#    - D Weight (Discriminability): 82.35%
# 👉 IF Fashion_Category=Footwear THEN Helpfulness=More Helpful
#    - Support: 0.02
#    - Confidence: 0.27
#    - Lift: 1.013
#    - T Weight (Typicality): 1.98%
#    - D Weight (Discriminability): 81.35%
# 👉 IF Fashion_Category=Footwear THEN Verified=Verified
#    - Support: 0.038
#    - Confidence: 0.514
#    - Lift: 1.001
#    - T Weight (Typicality): 3.77%
#    - D Weight (Discriminability): 80.42%
# 👉 IF Fashion_Category=Footwear THEN Verified=Not Verified
#    - Support: 0.036
#    - Confidence: 0.486
#    - Lift: 0.999
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 80.22%
# 👉 IF Fashion_Category=Footwear THEN Helpfulness=Less Helpful
#    - Support: 0.025
#    - Confidence: 0.338
#    - Lift: 0.936
#    - T Weight (Typicality): 2.48%
#    - D Weight (Discriminability): 75.15%
# 👉 IF Fashion_Category=Footwear THEN Rating=Low
#    - Support: 0.021
#    - Confidence: 0.284
#    - Lift: 0.935
#    - T Weight (Typicality): 2.08%
#    - D Weight (Discriminability): 75.09%
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Negative
#    - Support: 0.021
#    - Confidence: 0.284
#    - Lift: 0.935
#    - T Weight (Typicality): 2.08%
#    - D Weight (Discriminability): 75.09%
# 👉 IF Fashion_Category=Footwear THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.021
#    - Confidence: 0.284
#    - Lift: 0.935
#    - T Weight (Typicality): 2.08%
#    - D Weight (Discriminability): 75.09%
# 👉 IF Fashion_Category=Footwear THEN Review_Length=Long
#    - Support: 0.02
#    - Confidence: 0.27
#    - Lift: 0.93
#    - T Weight (Typicality): 1.98%
#    - D Weight (Discriminability): 74.68%
# 👉 IF Fashion_Category=Footwear THEN Rating=Medium
#    - Support: 0.02
#    - Confidence: 0.27
#    - Lift: 0.911
#    - T Weight (Typicality): 1.98%
#    - D Weight (Discriminability): 73.19%
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.02
#    - Confidence: 0.27
#    - Lift: 0.911
#    - T Weight (Typicality): 1.98%
#    - D Weight (Discriminability): 73.19%
# 👉 IF Fashion_Category=Footwear THEN Sentiment=Neutral
#    - Support: 0.02
#    - Confidence: 0.27
#    - Lift: 0.911
#    - T Weight (Typicality): 1.98%
#    - D Weight (Discriminability): 73.19%
# 👉 IF Fashion_Category=Footwear THEN Reviewer_Type=Frequent
#    - Support: 0.022
#    - Confidence: 0.297
#    - Lift: 0.74
#    - T Weight (Typicality): 2.18%
#    - D Weight (Discriminability): 59.43%
#
# 📂 Rules for 'Fashion_Category=Lingerie & Sleepwear':
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Verified=Not Verified AND Reviewer_Type=Frequent
#    - Support: 0.021
#    - Confidence: 0.233
#    - Lift: 1.131
#    - T Weight (Typicality): 2.08%
#    - D Weight (Discriminability): 100.00%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Reviewer_Type=Frequent
#    - Support: 0.038
#    - Confidence: 0.422
#    - Lift: 1.051
#    - T Weight (Typicality): 3.77%
#    - D Weight (Discriminability): 92.93%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Verified=Not Verified
#    - Support: 0.046
#    - Confidence: 0.511
#    - Lift: 1.049
#    - T Weight (Typicality): 4.56%
#    - D Weight (Discriminability): 92.79%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Helpfulness=More Helpful
#    - Support: 0.025
#    - Confidence: 0.278
#    - Lift: 1.041
#    - T Weight (Typicality): 2.48%
#    - D Weight (Discriminability): 92.05%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Review_Length=Long
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 1.032
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 91.27%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Review_Length=Short
#    - Support: 0.034
#    - Confidence: 0.378
#    - Lift: 1.024
#    - T Weight (Typicality): 3.37%
#    - D Weight (Discriminability): 90.53%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Helpfulness=Less Helpful
#    - Support: 0.033
#    - Confidence: 0.367
#    - Lift: 1.015
#    - T Weight (Typicality): 3.27%
#    - D Weight (Discriminability): 89.80%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Rating=Medium
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 1.011
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 89.44%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 1.011
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 89.44%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Sentiment=Neutral
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 1.011
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 89.44%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Sentiment=Positive AND Rating=High
#    - Support: 0.036
#    - Confidence: 0.4
#    - Lift: 1.0
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 88.48%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Rating=High
#    - Support: 0.036
#    - Confidence: 0.4
#    - Lift: 1.0
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 88.48%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Sentiment=Positive
#    - Support: 0.036
#    - Confidence: 0.4
#    - Lift: 1.0
#    - T Weight (Typicality): 3.57%
#    - D Weight (Discriminability): 88.48%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.025
#    - Confidence: 0.278
#    - Lift: 0.989
#    - T Weight (Typicality): 2.48%
#    - D Weight (Discriminability): 87.50%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 0.988
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 87.39%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Sentiment=Negative
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 0.988
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 87.39%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Rating=Low
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 0.988
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 87.39%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Reviewer_Type=Infrequent
#    - Support: 0.052
#    - Confidence: 0.578
#    - Lift: 0.966
#    - T Weight (Typicality): 5.16%
#    - D Weight (Discriminability): 85.41%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Helpfulness=None
#    - Support: 0.032
#    - Confidence: 0.356
#    - Lift: 0.956
#    - T Weight (Typicality): 3.17%
#    - D Weight (Discriminability): 84.52%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Verified=Verified
#    - Support: 0.044
#    - Confidence: 0.489
#    - Lift: 0.953
#    - T Weight (Typicality): 4.37%
#    - D Weight (Discriminability): 84.30%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Review_Length=Medium
#    - Support: 0.029
#    - Confidence: 0.322
#    - Lift: 0.947
#    - T Weight (Typicality): 2.88%
#    - D Weight (Discriminability): 83.74%
# 👉 IF Fashion_Category=Lingerie & Sleepwear THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.027
#    - Confidence: 0.3
#    - Lift: 0.945
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 83.57%
#
# 📂 Rules for 'Fashion_Category=Activewear':
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent AND Sentiment=Positive AND Rating=High
#    - Support: 0.017
#    - Confidence: 0.395
#    - Lift: 1.82
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 100.00%
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent AND Sentiment=Positive
#    - Support: 0.017
#    - Confidence: 0.395
#    - Lift: 1.82
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 100.00%
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.017
#    - Confidence: 0.395
#    - Lift: 1.82
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 100.00%
# 👉 IF Fashion_Category=Activewear THEN Sentiment=Positive AND Verified=Not Verified AND Rating=High
#    - Support: 0.014
#    - Confidence: 0.326
#    - Lift: 1.625
#    - T Weight (Typicality): 1.39%
#    - D Weight (Discriminability): 89.28%
# 👉 IF Fashion_Category=Activewear THEN Sentiment=Positive AND Verified=Not Verified
#    - Support: 0.014
#    - Confidence: 0.326
#    - Lift: 1.625
#    - T Weight (Typicality): 1.39%
#    - D Weight (Discriminability): 89.28%
# 👉 IF Fashion_Category=Activewear THEN Verified=Not Verified AND Rating=High
#    - Support: 0.014
#    - Confidence: 0.326
#    - Lift: 1.625
#    - T Weight (Typicality): 1.39%
#    - D Weight (Discriminability): 89.28%
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent AND Review_Length=Short
#    - Support: 0.014
#    - Confidence: 0.326
#    - Lift: 1.519
#    - T Weight (Typicality): 1.39%
#    - D Weight (Discriminability): 83.50%
# 👉 IF Fashion_Category=Activewear THEN Sentiment=Positive AND Rating=High
#    - Support: 0.025
#    - Confidence: 0.581
#    - Lift: 1.454
#    - T Weight (Typicality): 2.48%
#    - D Weight (Discriminability): 79.92%
# 👉 IF Fashion_Category=Activewear THEN Rating=High
#    - Support: 0.025
#    - Confidence: 0.581
#    - Lift: 1.454
#    - T Weight (Typicality): 2.48%
#    - D Weight (Discriminability): 79.92%
# 👉 IF Fashion_Category=Activewear THEN Sentiment=Positive
#    - Support: 0.025
#    - Confidence: 0.581
#    - Lift: 1.454
#    - T Weight (Typicality): 2.48%
#    - D Weight (Discriminability): 79.92%
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.013
#    - Confidence: 0.302
#    - Lift: 1.424
#    - T Weight (Typicality): 1.29%
#    - D Weight (Discriminability): 78.26%
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.019
#    - Confidence: 0.442
#    - Lift: 1.392
#    - T Weight (Typicality): 1.88%
#    - D Weight (Discriminability): 76.49%
# 👉 IF Fashion_Category=Activewear THEN Review_Length=Short AND Verified=Verified
#    - Support: 0.011
#    - Confidence: 0.256
#    - Lift: 1.302
#    - T Weight (Typicality): 1.09%
#    - D Weight (Discriminability): 71.57%
# 👉 IF Fashion_Category=Activewear THEN Rating=High AND Verified=Verified
#    - Support: 0.011
#    - Confidence: 0.256
#    - Lift: 1.283
#    - T Weight (Typicality): 1.09%
#    - D Weight (Discriminability): 70.50%
# 👉 IF Fashion_Category=Activewear THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.011
#    - Confidence: 0.256
#    - Lift: 1.283
#    - T Weight (Typicality): 1.09%
#    - D Weight (Discriminability): 70.50%
# 👉 IF Fashion_Category=Activewear THEN Sentiment=Positive AND Rating=High AND Verified=Verified
#    - Support: 0.011
#    - Confidence: 0.256
#    - Lift: 1.283
#    - T Weight (Typicality): 1.09%
#    - D Weight (Discriminability): 70.50%
# 👉 IF Fashion_Category=Activewear THEN Review_Length=Short
#    - Support: 0.02
#    - Confidence: 0.465
#    - Lift: 1.26
#    - T Weight (Typicality): 1.98%
#    - D Weight (Discriminability): 69.26%
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.011
#    - Confidence: 0.256
#    - Lift: 1.246
#    - T Weight (Typicality): 1.09%
#    - D Weight (Discriminability): 68.46%
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent
#    - Support: 0.032
#    - Confidence: 0.744
#    - Lift: 1.244
#    - T Weight (Typicality): 3.17%
#    - D Weight (Discriminability): 68.36%
# 👉 IF Fashion_Category=Activewear THEN Helpfulness=None
#    - Support: 0.018
#    - Confidence: 0.419
#    - Lift: 1.125
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 61.84%
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.013
#    - Confidence: 0.302
#    - Lift: 1.077
#    - T Weight (Typicality): 1.29%
#    - D Weight (Discriminability): 59.18%
# 👉 IF Fashion_Category=Activewear THEN Helpfulness=Less Helpful
#    - Support: 0.016
#    - Confidence: 0.372
#    - Lift: 1.03
#    - T Weight (Typicality): 1.59%
#    - D Weight (Discriminability): 56.63%
# 👉 IF Fashion_Category=Activewear THEN Verified=Not Verified
#    - Support: 0.021
#    - Confidence: 0.488
#    - Lift: 1.003
#    - T Weight (Typicality): 2.08%
#    - D Weight (Discriminability): 55.10%
# 👉 IF Fashion_Category=Activewear THEN Verified=Verified
#    - Support: 0.022
#    - Confidence: 0.512
#    - Lift: 0.998
#    - T Weight (Typicality): 2.18%
#    - D Weight (Discriminability): 54.82%
# 👉 IF Fashion_Category=Activewear THEN Review_Length=Medium
#    - Support: 0.013
#    - Confidence: 0.302
#    - Lift: 0.888
#    - T Weight (Typicality): 1.29%
#    - D Weight (Discriminability): 48.83%
# 👉 IF Fashion_Category=Activewear THEN Reviewer_Type=Frequent
#    - Support: 0.011
#    - Confidence: 0.256
#    - Lift: 0.637
#    - T Weight (Typicality): 1.09%
#    - D Weight (Discriminability): 34.99%
#
# 📂 Rules for 'Fashion_Category=Kidswear':
# 👉 IF Fashion_Category=Kidswear THEN Verified=Not Verified AND Helpfulness=Less Helpful
#    - Support: 0.016
#    - Confidence: 0.222
#    - Lift: 1.251
#    - T Weight (Typicality): 1.59%
#    - D Weight (Discriminability): 100.00%
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.018
#    - Confidence: 0.25
#    - Lift: 1.217
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 97.28%
# 👉 IF Fashion_Category=Kidswear THEN Helpfulness=Less Helpful
#    - Support: 0.03
#    - Confidence: 0.417
#    - Lift: 1.154
#    - T Weight (Typicality): 2.98%
#    - D Weight (Discriminability): 92.20%
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Sentiment=Negative
#    - Support: 0.016
#    - Confidence: 0.222
#    - Lift: 1.137
#    - T Weight (Typicality): 1.59%
#    - D Weight (Discriminability): 90.86%
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Rating=Low
#    - Support: 0.016
#    - Confidence: 0.222
#    - Lift: 1.137
#    - T Weight (Typicality): 1.59%
#    - D Weight (Discriminability): 90.86%
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Rating=Low AND Sentiment=Negative
#    - Support: 0.016
#    - Confidence: 0.222
#    - Lift: 1.137
#    - T Weight (Typicality): 1.59%
#    - D Weight (Discriminability): 90.86%
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Review_Length=Medium
#    - Support: 0.016
#    - Confidence: 0.222
#    - Lift: 1.114
#    - T Weight (Typicality): 1.59%
#    - D Weight (Discriminability): 89.05%
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Review_Length=Short
#    - Support: 0.017
#    - Confidence: 0.236
#    - Lift: 1.102
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 88.05%
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.025
#    - Confidence: 0.347
#    - Lift: 1.094
#    - T Weight (Typicality): 2.48%
#    - D Weight (Discriminability): 87.40%
# 👉 IF Fashion_Category=Kidswear THEN Review_Length=Short
#    - Support: 0.029
#    - Confidence: 0.403
#    - Lift: 1.091
#    - T Weight (Typicality): 2.88%
#    - D Weight (Discriminability): 87.21%
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Sentiment=Positive
#    - Support: 0.017
#    - Confidence: 0.236
#    - Lift: 1.087
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 86.84%
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.017
#    - Confidence: 0.236
#    - Lift: 1.087
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 86.84%
# 👉 IF Fashion_Category=Kidswear THEN Reviewer_Type=Infrequent AND Sentiment=Positive AND Rating=High
#    - Support: 0.017
#    - Confidence: 0.236
#    - Lift: 1.087
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 86.84%
# 👉 IF Fashion_Category=Kidswear THEN Verified=Not Verified AND Reviewer_Type=Frequent
#    - Support: 0.016
#    - Confidence: 0.222
#    - Lift: 1.077
#    - T Weight (Typicality): 1.59%
#    - D Weight (Discriminability): 86.06%
# 👉 IF Fashion_Category=Kidswear THEN Review_Length=Medium
#    - Support: 0.026
#    - Confidence: 0.361
#    - Lift: 1.061
#    - T Weight (Typicality): 2.58%
#    - D Weight (Discriminability): 84.80%
# 👉 IF Fashion_Category=Kidswear THEN Review_Length=Short AND Verified=Verified
#    - Support: 0.015
#    - Confidence: 0.208
#    - Lift: 1.061
#    - T Weight (Typicality): 1.49%
#    - D Weight (Discriminability): 84.75%
# ...
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.035
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 92.39%
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Rating=Low
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.035
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 92.39%
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Rating=Low AND Sentiment=Negative
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.035
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 92.39%
# 👉 IF Fashion_Category=Menswear THEN Verified=Not Verified AND Helpfulness=None
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.03
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 91.92%
# 👉 IF Fashion_Category=Menswear THEN Helpfulness=None
#    - Support: 0.034
#    - Confidence: 0.382
#    - Lift: 1.027
#    - T Weight (Typicality): 3.37%
#    - D Weight (Discriminability): 91.67%
# 👉 IF Fashion_Category=Menswear THEN Review_Length=Medium
#    - Support: 0.031
#    - Confidence: 0.348
#    - Lift: 1.024
#    - T Weight (Typicality): 3.08%
#    - D Weight (Discriminability): 91.38%
# 👉 IF Fashion_Category=Menswear THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.027
#    - Confidence: 0.303
#    - Lift: 1.023
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 91.30%
# 👉 IF Fashion_Category=Menswear THEN Rating=Medium
#    - Support: 0.027
#    - Confidence: 0.303
#    - Lift: 1.023
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 91.30%
# 👉 IF Fashion_Category=Menswear THEN Sentiment=Neutral
#    - Support: 0.027
#    - Confidence: 0.303
#    - Lift: 1.023
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 91.30%
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent
#    - Support: 0.054
#    - Confidence: 0.607
#    - Lift: 1.014
#    - T Weight (Typicality): 5.36%
#    - D Weight (Discriminability): 90.55%
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Review_Length=Medium
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.014
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 90.55%
# 👉 IF Fashion_Category=Menswear THEN Helpfulness=More Helpful
#    - Support: 0.024
#    - Confidence: 0.27
#    - Lift: 1.01
#    - T Weight (Typicality): 2.38%
#    - D Weight (Discriminability): 90.21%
# 👉 IF Fashion_Category=Menswear THEN Sentiment=Positive AND Verified=Not Verified AND Rating=High
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.009
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 90.10%
# 👉 IF Fashion_Category=Menswear THEN Sentiment=Positive AND Verified=Not Verified
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.009
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 90.10%
# 👉 IF Fashion_Category=Menswear THEN Verified=Not Verified AND Rating=High
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 1.009
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 90.10%
# 👉 IF Fashion_Category=Menswear THEN Review_Length=Short
#    - Support: 0.033
#    - Confidence: 0.371
#    - Lift: 1.005
#    - T Weight (Typicality): 3.27%
#    - D Weight (Discriminability): 89.70%
# 👉 IF Fashion_Category=Menswear THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.027
#    - Confidence: 0.303
#    - Lift: 0.999
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 89.22%
# 👉 IF Fashion_Category=Menswear THEN Rating=Low
#    - Support: 0.027
#    - Confidence: 0.303
#    - Lift: 0.999
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 89.22%
# 👉 IF Fashion_Category=Menswear THEN Sentiment=Negative
#    - Support: 0.027
#    - Confidence: 0.303
#    - Lift: 0.999
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 89.22%
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 0.985
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 87.92%
# 👉 IF Fashion_Category=Menswear THEN Rating=High
#    - Support: 0.035
#    - Confidence: 0.393
#    - Lift: 0.984
#    - T Weight (Typicality): 3.47%
#    - D Weight (Discriminability): 87.81%
# 👉 IF Fashion_Category=Menswear THEN Sentiment=Positive AND Rating=High
#    - Support: 0.035
#    - Confidence: 0.393
#    - Lift: 0.984
#    - T Weight (Typicality): 3.47%
#    - D Weight (Discriminability): 87.81%
# 👉 IF Fashion_Category=Menswear THEN Sentiment=Positive
#    - Support: 0.035
#    - Confidence: 0.393
#    - Lift: 0.984
#    - T Weight (Typicality): 3.47%
#    - D Weight (Discriminability): 87.81%
# 👉 IF Fashion_Category=Menswear THEN Verified=Not Verified AND Reviewer_Type=Frequent
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 0.98
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 87.50%
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Frequent
#    - Support: 0.035
#    - Confidence: 0.393
#    - Lift: 0.979
#    - T Weight (Typicality): 3.47%
#    - D Weight (Discriminability): 87.38%
# 👉 IF Fashion_Category=Menswear THEN Review_Length=Long
#    - Support: 0.025
#    - Confidence: 0.281
#    - Lift: 0.966
#    - T Weight (Typicality): 2.48%
#    - D Weight (Discriminability): 86.27%
# 👉 IF Fashion_Category=Menswear THEN Helpfulness=Less Helpful
#    - Support: 0.031
#    - Confidence: 0.348
#    - Lift: 0.965
#    - T Weight (Typicality): 3.08%
#    - D Weight (Discriminability): 86.11%
# 👉 IF Fashion_Category=Menswear THEN Verified=Verified
#    - Support: 0.044
#    - Confidence: 0.494
#    - Lift: 0.964
#    - T Weight (Typicality): 4.37%
#    - D Weight (Discriminability): 86.05%
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.027
#    - Confidence: 0.303
#    - Lift: 0.956
#    - T Weight (Typicality): 2.68%
#    - D Weight (Discriminability): 85.31%
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 0.953
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 85.05%
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Review_Length=Short
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 0.944
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 84.26%
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Sentiment=Positive
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 0.931
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 83.11%
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Sentiment=Positive AND Rating=High
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 0.931
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 83.11%
# 👉 IF Fashion_Category=Menswear THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.018
#    - Confidence: 0.202
#    - Lift: 0.931
#    - T Weight (Typicality): 1.79%
#    - D Weight (Discriminability): 83.11%
#
# 📂 Rules for 'Fashion_Category=Womenswear':
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Review_Length=Medium
#    - Support: 0.016
#    - Confidence: 0.291
#    - Lift: 1.459
#    - T Weight (Typicality): 1.59%
#    - D Weight (Discriminability): 100.00%
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Helpfulness=None
#    - Support: 0.017
#    - Confidence: 0.309
#    - Lift: 1.456
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 99.80%
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Sentiment=Positive AND Rating=High
#    - Support: 0.017
#    - Confidence: 0.309
#    - Lift: 1.423
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 97.52%
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Sentiment=Positive
#    - Support: 0.017
#    - Confidence: 0.309
#    - Lift: 1.423
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 97.52%
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Rating=High
#    - Support: 0.017
#    - Confidence: 0.309
#    - Lift: 1.423
#    - T Weight (Typicality): 1.69%
#    - D Weight (Discriminability): 97.52%
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Review_Length=Short
#    - Support: 0.016
#    - Confidence: 0.291
#    - Lift: 1.358
#    - T Weight (Typicality): 1.59%
#    - D Weight (Discriminability): 93.06%
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Helpfulness=Less Helpful
#    - Support: 0.015
#    - Confidence: 0.273
#    - Lift: 1.328
#    - T Weight (Typicality): 1.49%
#    - D Weight (Discriminability): 91.03%
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Verified=Verified
#    - Support: 0.023
#    - Confidence: 0.418
#    - Lift: 1.317
#    - T Weight (Typicality): 2.28%
#    - D Weight (Discriminability): 90.29%
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent
#    - Support: 0.042
#    - Confidence: 0.764
#    - Lift: 1.277
#    - T Weight (Typicality): 4.17%
#    - D Weight (Discriminability): 87.50%
# 👉 IF Fashion_Category=Womenswear THEN Rating=High AND Verified=Verified
#    - Support: 0.014
#    - Confidence: 0.255
#    - Lift: 1.277
#    - T Weight (Typicality): 1.39%
#    - D Weight (Discriminability): 87.50%
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.014
#    - Confidence: 0.255
#    - Lift: 1.277
#    - T Weight (Typicality): 1.39%
#    - D Weight (Discriminability): 87.50%
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Positive AND Rating=High AND Verified=Verified
#    - Support: 0.014
#    - Confidence: 0.255
#    - Lift: 1.277
#    - T Weight (Typicality): 1.39%
#    - D Weight (Discriminability): 87.50%
# 👉 IF Fashion_Category=Womenswear THEN Review_Length=Medium AND Verified=Verified
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.236
#    - T Weight (Typicality): 1.19%
#    - D Weight (Discriminability): 84.69%
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Verified=Not Verified
#    - Support: 0.019
#    - Confidence: 0.345
#    - Lift: 1.23
#    - T Weight (Typicality): 1.88%
#    - D Weight (Discriminability): 84.34%
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Rating=Low AND Sentiment=Negative
#    - Support: 0.013
#    - Confidence: 0.236
#    - Lift: 1.209
#    - T Weight (Typicality): 1.29%
#    - D Weight (Discriminability): 82.90%
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Rating=Low
#    - Support: 0.013
#    - Confidence: 0.236
#    - Lift: 1.209
#    - T Weight (Typicality): 1.29%
#    - D Weight (Discriminability): 82.90%
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Sentiment=Negative
#    - Support: 0.013
#    - Confidence: 0.236
#    - Lift: 1.209
#    - T Weight (Typicality): 1.29%
#    - D Weight (Discriminability): 82.90%
# 👉 IF Fashion_Category=Womenswear THEN Review_Length=Short AND Verified=Verified
#    - Support: 0.013
#    - Confidence: 0.236
#    - Lift: 1.203
#    - T Weight (Typicality): 1.29%
#    - D Weight (Discriminability): 82.48%
# 👉 IF Fashion_Category=Womenswear THEN Helpfulness=Less Helpful AND Verified=Verified
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.189
#    - T Weight (Typicality): 1.19%
#    - D Weight (Discriminability): 81.49%
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Positive
#    - Support: 0.026
#    - Confidence: 0.473
#    - Lift: 1.182
#    - T Weight (Typicality): 2.58%
#    - D Weight (Discriminability): 81.05%
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Positive AND Rating=High
#    - Support: 0.026
#    - Confidence: 0.473
#    - Lift: 1.182
#    - T Weight (Typicality): 2.58%
#    - D Weight (Discriminability): 81.05%
# 👉 IF Fashion_Category=Womenswear THEN Rating=High
#    - Support: 0.026
#    - Confidence: 0.473
#    - Lift: 1.182
#    - T Weight (Typicality): 2.58%
#    - D Weight (Discriminability): 81.05%
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Sentiment=Neutral AND Rating=Medium
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.176
#    - T Weight (Typicality): 1.19%
#    - D Weight (Discriminability): 80.61%
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Rating=Medium
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.176
#    - T Weight (Typicality): 1.19%
#    - D Weight (Discriminability): 80.61%
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Infrequent AND Sentiment=Neutral
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.176
#    - T Weight (Typicality): 1.19%
#    - D Weight (Discriminability): 80.61%
# 👉 IF Fashion_Category=Womenswear THEN Review_Length=Medium
#    - Support: 0.022
#    - Confidence: 0.4
#    - Lift: 1.176
#    - T Weight (Typicality): 2.18%
#    - D Weight (Discriminability): 80.58%
# 👉 IF Fashion_Category=Womenswear THEN Verified=Not Verified AND Helpfulness=None
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.111
#    - T Weight (Typicality): 1.19%
#    - D Weight (Discriminability): 76.14%
# 👉 IF Fashion_Category=Womenswear THEN Verified=Verified
#    - Support: 0.031
#    - Confidence: 0.564
#    - Lift: 1.099
#    - T Weight (Typicality): 3.08%
#    - D Weight (Discriminability): 75.33%
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Positive AND Verified=Not Verified AND Rating=High
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.089
#    - T Weight (Typicality): 1.19%
#    - D Weight (Discriminability): 74.63%
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Positive AND Verified=Not Verified
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.089
#    - T Weight (Typicality): 1.19%
#    - D Weight (Discriminability): 74.63%
# 👉 IF Fashion_Category=Womenswear THEN Verified=Not Verified AND Rating=High
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 1.089
#    - T Weight (Typicality): 1.19%
#    - D Weight (Discriminability): 74.63%
# 👉 IF Fashion_Category=Womenswear THEN Review_Length=Short
#    - Support: 0.022
#    - Confidence: 0.4
#    - Lift: 1.084
#    - T Weight (Typicality): 2.18%
#    - D Weight (Discriminability): 74.29%
# 👉 IF Fashion_Category=Womenswear THEN Helpfulness=None
#    - Support: 0.022
#    - Confidence: 0.4
#    - Lift: 1.075
#    - T Weight (Typicality): 2.18%
#    - D Weight (Discriminability): 73.70%
# 👉 IF Fashion_Category=Womenswear THEN Helpfulness=Less Helpful
#    - Support: 0.021
#    - Confidence: 0.382
#    - Lift: 1.057
#    - T Weight (Typicality): 2.08%
#    - D Weight (Discriminability): 72.48%
# 👉 IF Fashion_Category=Womenswear THEN Rating=Low AND Sentiment=Negative
#    - Support: 0.015
#    - Confidence: 0.273
#    - Lift: 0.898
#    - T Weight (Typicality): 1.49%
#    - D Weight (Discriminability): 61.58%
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Negative
#    - Support: 0.015
#    - Confidence: 0.273
#    - Lift: 0.898
#    - T Weight (Typicality): 1.49%
#    - D Weight (Discriminability): 61.58%
# 👉 IF Fashion_Category=Womenswear THEN Rating=Low
#    - Support: 0.015
#    - Confidence: 0.273
#    - Lift: 0.898
#    - T Weight (Typicality): 1.49%
#    - D Weight (Discriminability): 61.58%
# 👉 IF Fashion_Category=Womenswear THEN Verified=Not Verified
#    - Support: 0.024
#    - Confidence: 0.436
#    - Lift: 0.896
#    - T Weight (Typicality): 2.38%
#    - D Weight (Discriminability): 61.41%
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Neutral AND Rating=Medium
#    - Support: 0.014
#    - Confidence: 0.255
#    - Lift: 0.858
#    - T Weight (Typicality): 1.39%
#    - D Weight (Discriminability): 58.82%
# 👉 IF Fashion_Category=Womenswear THEN Sentiment=Neutral
#    - Support: 0.014
#    - Confidence: 0.255
#    - Lift: 0.858
#    - T Weight (Typicality): 1.39%
#    - D Weight (Discriminability): 58.82%
# 👉 IF Fashion_Category=Womenswear THEN Rating=Medium
#    - Support: 0.014
#    - Confidence: 0.255
#    - Lift: 0.858
#    - T Weight (Typicality): 1.39%
#    - D Weight (Discriminability): 58.82%
# 👉 IF Fashion_Category=Womenswear THEN Helpfulness=More Helpful
#    - Support: 0.012
#    - Confidence: 0.218
#    - Lift: 0.818
#    - T Weight (Typicality): 1.19%
#    - D Weight (Discriminability): 56.04%
# 👉 IF Fashion_Category=Womenswear THEN Reviewer_Type=Frequent
#    - Support: 0.013
#    - Confidence: 0.236
#    - Lift: 0.588
#    - T Weight (Typicality): 1.29%
#    - D Weight (Discriminability): 40.32%
