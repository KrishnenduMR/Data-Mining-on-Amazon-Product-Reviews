# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
from textblob import TextBlob
from sklearn.feature_extraction.text import TfidfVectorizer
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
from collections import Counter
from itertools import chain
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import seaborn as sns
from wordcloud import WordCloud

# %%
file_path = "cleaned.csv"  # Update with actual file path

df = pd.read_csv(file_path)

# %%
df.head
# Out:
# <bound method NDFrame.head of          Unnamed: 0  rating  \
# 0                 0     5.0
# 1                 1     5.0
# 2                 2     2.0
# 3                 3     1.0
# 4                 4     5.0
# ...             ...     ...
# 2500934     2500934     5.0
# 2500935     2500935     1.0
# 2500936     2500936     3.0
# 2500937     2500937     5.0
# 2500938     2500938     1.0
#
#                                                      title  \
# 0                                            Pretty locket
# 1                                                        A
# 2                                                Two Stars
# 3                                          Won’t buy again
# 4                                     I LOVE these glasses
# ...                                                    ...
# 2500934  ... allowed them to be used to add military ri...
# 2500935                           Didn’t come with all ten
# 2500936                            Not checked for quality
# 2500937                                            Awesome
# 2500938                                  Empty plastic bag
#
#                                                       text images        asin  \
# 0        i think this locket is really pretty. the insi...     []  B00LOPVX74
# 1                                                    great     []  B07B4JXK8D
# 2        one of the stones fell out within the first 2 ...     []  B007ZSEQ4Q
# 3        crappy socks. money wasted. bought to wear wit...     []  B07F2BTFS9
# 4        i love these glasses!  they fit perfectly over...     []  B00PKRFU4O
# ...                                                    ...    ...         ...
# 2500934  the tie tacks were the size that allowed them ...     []  B00YGFMQC0
# 2500935          says ten tie clips but o only received 7.     []  B00YGFMQC0
# 2500936  when i received them 2-3 of them did not open ...     []  B00YGFMQC0
# 2500937                                     great product.     []  B00YGFMQC0
# 2500938  i got an empty bag in my package of 10 that i ...     []  B00YGFMQC0
#
#         parent_asin                       user_id                timestamp  \
# 0        B00LOPVX74  AGBFYI2DDIKXC5Y4FARTYDTQBMFQ  2020-01-09 00:06:34.489
# 1        B07B4JXK8D  AFQLNQNQYFWQZPJQZS6V3NZU4QBQ  2020-12-20 01:04:06.701
# 2        B007ZSEQ4Q  AHITBJSS7KYUBVZPX7M2WJCOIVKQ  2015-05-23 01:33:48.000
# 3        B07F2BTFS9  AFVNEEPDEIH5SPUN5BWC6NKL3WNQ  2018-12-31 20:57:27.095
# 4        B00XESJTDE  AHSPLDNW5OOUK2PLH7GXLACFBZNQ  2015-08-13 14:29:26.000
# ...             ...                           ...                      ...
# 2500934  B00YGFMQC0  AFXSFD3FTZ2CLN3TYV4B63CQM5BQ  2016-06-24 20:12:38.000
# 2500935  B00YGFMQC0  AEH7WP5HGM6FGLSSC6GSTYUXBHGQ  2018-05-08 17:05:05.585
# 2500936  B00YGFMQC0  AEL2TSSBVLIPWQ7YVMK364DUYURQ  2016-12-17 22:28:31.000
# 2500937  B00YGFMQC0  AGZ6IIYSPCW4YXWH6VFEOI7MTBZA  2017-04-15 17:34:26.000
# 2500938  B00YGFMQC0  AGN3P7MZ3WYZQTPOCSIWNTHD5RDQ  2017-03-15 00:25:02.000
#
#          helpful_vote  verified_purchase  \
# 0                   3               True
# 1                   0               True
# 2                   3               True
# 3                   2               True
# 4                   0               True
# ...               ...                ...
# 2500934             0               True
# 2500935             0               True
# 2500936             0               True
# 2500937             1               True
# 2500938             1               True
#
#                                                     tokens  \
# 0        ['think', 'locket', 'really', 'pretty', '.', '...
# 1                                                ['great']
# 2        ['stone', 'fell', '2', 'week', 'wearing', '.',...
# 3        ['crappy', 'sock', '.', 'money', 'wasted', '.'...
# 4        ['love', 'glass', '!', 'fit', 'perfectly', 're...
# ...                                                    ...
# 2500934  ['tie', 'tack', 'size', 'allowed', 'used', 'ad...
# 2500935       ['say', 'tie', 'clip', 'received', '7', '.']
# 2500936  ['received', '2-3', 'open', 'properly', '.', '...
# 2500937                          ['great', 'product', '.']
# 2500938  ['got', 'bag', 'package', '10', 'purchased', '...
#
#                                               cleaned_text  review_length
# 0        think locket really pretty . inside solid silv...             36
# 1                                                    great              1
# 2        stone fell 2 week wearing . stone smaller expe...             10
# 3        crappy sock . money wasted . bought wear tieks...             14
# 4        love glass ! fit perfectly regular , rectangul...             29
# ...                                                    ...            ...
# 2500934  tie tack size allowed used add military ribbon...             16
# 2500935                          say tie clip received 7 .              6
# 2500936     received 2-3 open properly . look break easily              8
# 2500937                                    great product .              3
# 2500938            got bag package 10 purchased . thanks !              8
#
# [2500939 rows x 14 columns]>

# %%
# === STEP 1: Preprocess and Label ===
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Label each review with lockdown period
df['lockdown_period'] = df['timestamp'].apply(
    lambda x: 'Post-COVID' if x >= pd.Timestamp('2020-03-15') else 'Pre-COVID'
)

def get_season(month):
    if month in [4, 5, 6, 7, 8]:
        return 'Summer'
    elif month in [11, 12, 1, 2]:
        return 'Winter'
    else:
        return 'Other'

df['season'] = df['timestamp'].dt.month.apply(get_season)
df = df[df['season'].isin(['Summer', 'Winter'])]

# %%
# Generalize Rating
rating_hierarchy = {
    1: 'Low',
    2: 'Low',
    3: 'Medium',
    4: 'High',
    5: 'High'
}
df['rating_generalized'] = df['rating'].map(rating_hierarchy)

# Add Sentiment based on rating
def map_sentiment(rating):
    if rating >= 4:
        return 'Positive'
    elif rating == 3:
        return 'Neutral'
    else:
        return 'Negative'

df['sentiment'] = df['rating'].apply(map_sentiment)

# Generalize Review Length
def categorize_length(length):
    if length < 50:
        return 'Short'
    elif 50 <= length <= 100:
        return 'Medium'
    else:
        return 'Long'

df['review_length_category'] = df['cleaned_text'].apply(
    lambda x: categorize_length(len(str(x).split()))
)

# Generalize Helpful Votes
def generalize_helpful(votes):
    if votes == 0:
        return 'None'
    elif 1 <= votes <= 5:
        return 'Less Helpful'
    else:
        return 'More Helpful'

df['helpful_vote_category'] = df['helpful_vote'].apply(generalize_helpful)

# Generalize Verified Purchase
df['verified_status'] = df['verified_purchase'].map({True: 'Verified', False: 'Not Verified'})



# Final selection of generalized attributes
generalized_df = df[[
    'rating_generalized',
    'sentiment',
    'review_length_category',
    'helpful_vote_category',
    'verified_status',
    'lockdown_period',
    'season'
]]

# Display top rows
print(generalized_df.head())
# Out:
# C:\Users\krish\AppData\Local\Temp\ipykernel_9300\545175802.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating_generalized'] = df['rating'].map(rating_hierarchy)
# C:\Users\krish\AppData\Local\Temp\ipykernel_9300\545175802.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sentiment'] = df['rating'].apply(map_sentiment)
# C:\Users\krish\AppData\Local\Temp\ipykernel_9300\545175802.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['review_length_category'] = df['cleaned_text'].apply(
# C:\Users\krish\AppData\Local\Temp\ipykernel_9300\545175802.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['helpful_vote_category'] = df['helpful_vote'].apply(generalize_helpful)
#   rating_generalized sentiment review_length_category helpful_vote_category  \
# 0               High  Positive                  Short          Less Helpful
# 1               High  Positive                  Short                  None
# 2                Low  Negative                  Short          Less Helpful
# 3                Low  Negative                  Short          Less Helpful
# 4               High  Positive                  Short                  None
#
#   verified_status lockdown_period  season
# 0        Verified       Pre-COVID  Winter
# 1        Verified      Post-COVID  Winter
# 2        Verified       Pre-COVID  Summer
# 3        Verified       Pre-COVID  Winter
# 4        Verified       Pre-COVID  Summer
# C:\Users\krish\AppData\Local\Temp\ipykernel_9300\545175802.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['verified_status'] = df['verified_purchase'].map({True: 'Verified', False: 'Not Verified'})

# %%
summary = df.groupby(
    ["lockdown_period", "season", "rating_generalized", "sentiment", 
     "review_length_category", "helpful_vote_category", "verified_status"]
).agg(
    review_count=("rating", "count"),
    avg_rating=("rating", "mean"),
    avg_helpful_vote=("helpful_vote", "mean")
).reset_index()

# %%
summary
# Out:
#     lockdown_period  season rating_generalized sentiment  \
# 0        Post-COVID  Summer               High  Positive
# 1        Post-COVID  Summer               High  Positive
# 2        Post-COVID  Summer               High  Positive
# 3        Post-COVID  Summer               High  Positive
# 4        Post-COVID  Summer               High  Positive
# ..              ...     ...                ...       ...
# 210       Pre-COVID  Winter             Medium   Neutral
# 211       Pre-COVID  Winter             Medium   Neutral
# 212       Pre-COVID  Winter             Medium   Neutral
# 213       Pre-COVID  Winter             Medium   Neutral
# 214       Pre-COVID  Winter             Medium   Neutral
#
#     review_length_category helpful_vote_category verified_status  \
# 0                     Long          Less Helpful    Not Verified
# 1                     Long          Less Helpful        Verified
# 2                     Long          More Helpful    Not Verified
# 3                     Long          More Helpful        Verified
# 4                     Long                  None    Not Verified
# ..                     ...                   ...             ...
# 210                  Short          Less Helpful        Verified
# 211                  Short          More Helpful    Not Verified
# 212                  Short          More Helpful        Verified
# 213                  Short                  None    Not Verified
# 214                  Short                  None        Verified
#
#      review_count  avg_rating  avg_helpful_vote
# 0             223    4.578475          1.798206
# 1             311    4.710611          2.234727
# 2              15    4.733333          8.733333
# 3             149    4.691275         21.604027
# 4             330    4.639394          0.000000
# ..            ...         ...               ...
# 210         10688    3.000000          1.576254
# 211            34    3.000000         11.588235
# 212           630    3.000000         11.634921
# 213          2352    3.000000          0.000000
# 214         44818    3.000000          0.000000
#
# [215 rows x 10 columns]

# %%
# Convert the summary dataframe into a transaction-style format
summary_trans = df.apply(lambda row: [
    f"lockdown_period={row['lockdown_period']}",
    f"season={row['season']}",
    f"Rating={row['rating_generalized']}",
    f"Sentiment={row['sentiment']}",
    f"Review_Length={row['review_length_category']}",
    f"Helpfulness={row['helpful_vote_category']}",
    f"Verified={row['verified_status']}"
], axis=1)

# Convert the list of transactions to the right format for rule mining
summary_trans = summary_trans.tolist()

# Example: Print the first 5 transactions
print("Sample Transactions (first 5):", summary_trans[:5])
# Out:
# Sample Transactions (first 5): [['lockdown_period=Pre-COVID', 'season=Winter', 'Rating=High', 'Sentiment=Positive', 'Review_Length=Short', 'Helpfulness=Less Helpful', 'Verified=Verified'], ['lockdown_period=Post-COVID', 'season=Winter', 'Rating=High', 'Sentiment=Positive', 'Review_Length=Short', 'Helpfulness=None', 'Verified=Verified'], ['lockdown_period=Pre-COVID', 'season=Summer', 'Rating=Low', 'Sentiment=Negative', 'Review_Length=Short', 'Helpfulness=Less Helpful', 'Verified=Verified'], ['lockdown_period=Pre-COVID', 'season=Winter', 'Rating=Low', 'Sentiment=Negative', 'Review_Length=Short', 'Helpfulness=Less Helpful', 'Verified=Verified'], ['lockdown_period=Pre-COVID', 'season=Summer', 'Rating=High', 'Sentiment=Positive', 'Review_Length=Short', 'Helpfulness=None', 'Verified=Verified']]

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# Create a TransactionEncoder object to convert the transaction data
te = TransactionEncoder()
te_ary = te.fit(summary_trans).transform(summary_trans)
df_trans = pd.DataFrame(te_ary, columns=te.columns_)

# %%
# Apply apriori with a lower support threshold (e.g., 0.05)
frequent_itemsets = apriori(df_trans, min_support=0.05, use_colnames=True)

# Generate association rules based on confidence with a minimum threshold of 0.2
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)

# === Step 1: Filter for 'lockdown_period=Post-COVID' in antecedents ===
post_covid_rules = rules[rules['antecedents'].apply(
    lambda x: 'lockdown_period=Post-COVID' in str(x) and len(x) == 1)]  # Strict filter for 'Post-COVID' alone

# === Step 2: Filter for 'lockdown_period=Pre-COVID' in antecedents ===
pre_covid_rules = rules[rules['antecedents'].apply(
    lambda x: 'lockdown_period=Pre-COVID' in str(x) and len(x) == 1)]  # Strict filter for 'Pre-COVID' alone

# === Step 3: Sort the rules by lift in descending order ===
post_covid_rules = post_covid_rules.sort_values(by='lift', ascending=False)
pre_covid_rules = pre_covid_rules.sort_values(by='lift', ascending=False)

# === Step 4: Display Rules for Post-COVID ===
print("\n📋 Lockdown Period-Based Discrimination Rules (Strictly 'lockdown_period=Post-COVID'):\n")
if not post_covid_rules.empty:
    for _, row in post_covid_rules.iterrows():
        antecedent = ' AND '.join(list(row['antecedents']))
        consequent = ' AND '.join(list(row['consequents']))
        print(f"-> IF {antecedent} THEN {consequent}")
        print(f"   - Support: {round(row['support'], 3)}")
        print(f"   - Confidence: {round(row['confidence'], 3)}")
        print(f"   - Lift: {round(row['lift'], 3)}\n")
else:
    print("No rules generated for 'lockdown_period=Post-COVID'.")

# === Step 5: Display Rules for Pre-COVID ===
print("\n📋 Lockdown Period-Based Discrimination Rules (Strictly 'lockdown_period=Pre-COVID'):\n")
if not pre_covid_rules.empty:
    for _, row in pre_covid_rules.iterrows():
        antecedent = ' AND '.join(list(row['antecedents']))
        consequent = ' AND '.join(list(row['consequents']))
        print(f"-> IF {antecedent} THEN {consequent}")
        print(f"   - Support: {round(row['support'], 3)}")
        print(f"   - Confidence: {round(row['confidence'], 3)}")
        print(f"   - Lift: {round(row['lift'], 3)}\n")
else:
    print("No rules generated for 'lockdown_period=Pre-COVID'.")

# === Step 6: Summary Tables ===
# Create summary tables for each filter
post_covid_summary_df = post_covid_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].copy()
post_covid_summary_df['antecedents'] = post_covid_summary_df['antecedents'].apply(lambda x: ' AND '.join(x))
post_covid_summary_df['consequents'] = post_covid_summary_df['consequents'].apply(lambda x: ' AND '.join(x))

pre_covid_summary_df = pre_covid_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].copy()
pre_covid_summary_df['antecedents'] = pre_covid_summary_df['antecedents'].apply(lambda x: ' AND '.join(x))
pre_covid_summary_df['consequents'] = pre_covid_summary_df['consequents'].apply(lambda x: ' AND '.join(x))

# Save the summaries to separate CSV files
post_covid_summary_df.to_csv('lockdown_period_post_covid_rules_summary.csv', index=False)
pre_covid_summary_df.to_csv('lockdown_period_pre_covid_rules_summary.csv', index=False)

# Print the summary of the rules
print("\n📄 Summary of Lockdown Period Discrimination Rules (Post-COVID):\n")
print(post_covid_summary_df.head(10))

print("\n📄 Summary of Lockdown Period Discrimination Rules (Pre-COVID):\n")
print(pre_covid_summary_df.head(10))
# Out:
# 📋 Lockdown Period-Based Discrimination Rules (Strictly 'lockdown_period=Post-COVID'):
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Negative AND Review_Length=Short
#    - Support: 0.064
#    - Confidence: 0.218
#    - Lift: 1.196
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Rating=Low
#    - Support: 0.064
#    - Confidence: 0.218
#    - Lift: 1.196
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Sentiment=Negative AND Rating=Low
#    - Support: 0.064
#    - Confidence: 0.218
#    - Lift: 1.196
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Negative
#    - Support: 0.066
#    - Confidence: 0.227
#    - Lift: 1.194
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Negative AND Rating=Low
#    - Support: 0.066
#    - Confidence: 0.227
#    - Lift: 1.194
#
# -> IF lockdown_period=Post-COVID THEN Rating=Low
#    - Support: 0.066
#    - Confidence: 0.227
#    - Lift: 1.194
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Verified=Verified AND Rating=Low
#    - Support: 0.059
#    - Confidence: 0.201
#    - Lift: 1.174
#
# -> IF lockdown_period=Post-COVID THEN Rating=Low AND Sentiment=Negative AND Verified=Verified AND Review_Length=Short
#    - Support: 0.059
#    - Confidence: 0.201
#    - Lift: 1.174
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Negative AND Verified=Verified AND Review_Length=Short
#    - Support: 0.059
#    - Confidence: 0.201
#    - Lift: 1.174
#
# -> IF lockdown_period=Post-COVID THEN Verified=Verified AND Rating=Low
#    - Support: 0.061
#    - Confidence: 0.209
#    - Lift: 1.172
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Negative AND Verified=Verified
#    - Support: 0.061
#    - Confidence: 0.209
#    - Lift: 1.172
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Negative AND Verified=Verified AND Rating=Low
#    - Support: 0.061
#    - Confidence: 0.209
#    - Lift: 1.172
#
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND season=Summer
#    - Support: 0.142
#    - Confidence: 0.485
#    - Lift: 1.137
#
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND season=Summer AND Review_Length=Short
#    - Support: 0.138
#    - Confidence: 0.47
#    - Lift: 1.135
#
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Verified=Verified AND season=Summer
#    - Support: 0.13
#    - Confidence: 0.444
#    - Lift: 1.111
#
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Verified=Verified AND season=Summer AND Review_Length=Short
#    - Support: 0.127
#    - Confidence: 0.434
#    - Lift: 1.108
#
# -> IF lockdown_period=Post-COVID THEN season=Summer AND Review_Length=Short
#    - Support: 0.163
#    - Confidence: 0.556
#    - Lift: 1.093
#
# -> IF lockdown_period=Post-COVID THEN season=Summer
#    - Support: 0.17
#    - Confidence: 0.581
#    - Lift: 1.088
#
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND season=Summer AND Rating=High
#    - Support: 0.096
#    - Confidence: 0.327
#    - Lift: 1.08
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Helpfulness=None AND season=Summer AND Rating=High
#    - Support: 0.096
#    - Confidence: 0.327
#    - Lift: 1.08
#
# -> IF lockdown_period=Post-COVID THEN season=Summer AND Sentiment=Positive AND Helpfulness=None
#    - Support: 0.096
#    - Confidence: 0.327
#    - Lift: 1.08
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.093
#    - Confidence: 0.318
#    - Lift: 1.079
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Helpfulness=None AND season=Summer AND Review_Length=Short
#    - Support: 0.093
#    - Confidence: 0.318
#    - Lift: 1.079
#
# -> IF lockdown_period=Post-COVID THEN Rating=High AND Helpfulness=None AND season=Summer AND Review_Length=Short
#    - Support: 0.093
#    - Confidence: 0.318
#    - Lift: 1.079
#
# -> IF lockdown_period=Post-COVID THEN Verified=Verified AND season=Summer AND Review_Length=Short
#    - Support: 0.151
#    - Confidence: 0.514
#    - Lift: 1.069
#
# -> IF lockdown_period=Post-COVID THEN Verified=Verified AND season=Summer
#    - Support: 0.156
#    - Confidence: 0.532
#    - Lift: 1.065
#
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Verified=Verified AND season=Summer AND Rating=High
#    - Support: 0.088
#    - Confidence: 0.299
#    - Lift: 1.055
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND season=Summer
#    - Support: 0.088
#    - Confidence: 0.299
#    - Lift: 1.055
#
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.088
#    - Confidence: 0.299
#    - Lift: 1.055
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.086
#    - Confidence: 0.293
#    - Lift: 1.054
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND season=Summer AND Rating=High
#    - Support: 0.086
#    - Confidence: 0.293
#    - Lift: 1.054
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND season=Summer
#    - Support: 0.086
#    - Confidence: 0.293
#    - Lift: 1.054
#
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None
#    - Support: 0.245
#    - Confidence: 0.837
#    - Lift: 1.042
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND season=Summer AND Rating=High
#    - Support: 0.109
#    - Confidence: 0.371
#    - Lift: 1.038
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND season=Summer AND Review_Length=Short
#    - Support: 0.109
#    - Confidence: 0.371
#    - Lift: 1.038
#
# -> IF lockdown_period=Post-COVID THEN Rating=High AND Sentiment=Positive AND season=Summer AND Review_Length=Short
#    - Support: 0.109
#    - Confidence: 0.371
#    - Lift: 1.038
#
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Review_Length=Short
#    - Support: 0.238
#    - Confidence: 0.811
#    - Lift: 1.037
#
# -> IF lockdown_period=Post-COVID THEN season=Summer AND Rating=High
#    - Support: 0.114
#    - Confidence: 0.388
#    - Lift: 1.031
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.114
#    - Confidence: 0.388
#    - Lift: 1.031
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND season=Summer
#    - Support: 0.114
#    - Confidence: 0.388
#    - Lift: 1.031
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Verified=Verified AND Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.101
#    - Confidence: 0.344
#    - Lift: 1.015
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Verified=Verified AND season=Summer AND Review_Length=Short
#    - Support: 0.101
#    - Confidence: 0.344
#    - Lift: 1.015
#
# -> IF lockdown_period=Post-COVID THEN Rating=High AND Verified=Verified AND season=Summer AND Review_Length=Short
#    - Support: 0.101
#    - Confidence: 0.344
#    - Lift: 1.015
#
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Verified=Verified
#    - Support: 0.223
#    - Confidence: 0.76
#    - Lift: 1.011
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Verified=Verified AND season=Summer
#    - Support: 0.104
#    - Confidence: 0.355
#    - Lift: 1.01
#
# -> IF lockdown_period=Post-COVID THEN Verified=Verified AND season=Summer AND Rating=High
#    - Support: 0.104
#    - Confidence: 0.355
#    - Lift: 1.01
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Verified=Verified AND season=Summer AND Rating=High
#    - Support: 0.104
#    - Confidence: 0.355
#    - Lift: 1.01
#
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.218
#    - Confidence: 0.743
#    - Lift: 1.009
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short
#    - Support: 0.28
#    - Confidence: 0.956
#    - Lift: 1.001
#
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Rating=High
#    - Support: 0.168
#    - Confidence: 0.573
#    - Lift: 0.99
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Helpfulness=None
#    - Support: 0.168
#    - Confidence: 0.573
#    - Lift: 0.99
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Helpfulness=None AND Rating=High
#    - Support: 0.168
#    - Confidence: 0.573
#    - Lift: 0.99
#
# -> IF lockdown_period=Post-COVID THEN Rating=High AND Sentiment=Positive AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.163
#    - Confidence: 0.556
#    - Lift: 0.986
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Rating=High
#    - Support: 0.163
#    - Confidence: 0.556
#    - Lift: 0.986
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.163
#    - Confidence: 0.556
#    - Lift: 0.986
#
# -> IF lockdown_period=Post-COVID THEN Verified=Verified AND Review_Length=Short
#    - Support: 0.258
#    - Confidence: 0.88
#    - Lift: 0.975
#
# -> IF lockdown_period=Post-COVID THEN Verified=Verified
#    - Support: 0.267
#    - Confidence: 0.91
#    - Lift: 0.973
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.152
#    - Confidence: 0.519
#    - Lift: 0.96
#
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.152
#    - Confidence: 0.519
#    - Lift: 0.96
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Verified=Verified AND Helpfulness=None
#    - Support: 0.152
#    - Confidence: 0.519
#    - Lift: 0.96
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND Rating=High
#    - Support: 0.149
#    - Confidence: 0.509
#    - Lift: 0.957
#
# -> IF lockdown_period=Post-COVID THEN Rating=High AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.149
#    - Confidence: 0.509
#    - Lift: 0.957
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.149
#    - Confidence: 0.509
#    - Lift: 0.957
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Rating=High
#    - Support: 0.19
#    - Confidence: 0.647
#    - Lift: 0.95
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Review_Length=Short
#    - Support: 0.19
#    - Confidence: 0.647
#    - Lift: 0.95
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Sentiment=Positive AND Rating=High
#    - Support: 0.19
#    - Confidence: 0.647
#    - Lift: 0.95
#
# -> IF lockdown_period=Post-COVID THEN Rating=High
#    - Support: 0.198
#    - Confidence: 0.676
#    - Lift: 0.949
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive
#    - Support: 0.198
#    - Confidence: 0.676
#    - Lift: 0.949
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Rating=High
#    - Support: 0.198
#    - Confidence: 0.676
#    - Lift: 0.949
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Helpfulness=None
#    - Support: 0.103
#    - Confidence: 0.352
#    - Lift: 0.935
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.1
#    - Confidence: 0.341
#    - Lift: 0.927
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.174
#    - Confidence: 0.595
#    - Lift: 0.924
#
# -> IF lockdown_period=Post-COVID THEN Rating=High AND Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.174
#    - Confidence: 0.595
#    - Lift: 0.924
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Verified=Verified AND Rating=High
#    - Support: 0.174
#    - Confidence: 0.595
#    - Lift: 0.924
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.18
#    - Confidence: 0.614
#    - Lift: 0.922
#
# -> IF lockdown_period=Post-COVID THEN Verified=Verified AND Rating=High
#    - Support: 0.18
#    - Confidence: 0.614
#    - Lift: 0.922
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Verified=Verified AND Rating=High
#    - Support: 0.18
#    - Confidence: 0.614
#    - Lift: 0.922
#
# -> IF lockdown_period=Post-COVID THEN season=Winter
#    - Support: 0.123
#    - Confidence: 0.419
#    - Lift: 0.9
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Helpfulness=None AND Verified=Verified
#    - Support: 0.093
#    - Confidence: 0.316
#    - Lift: 0.899
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Review_Length=Short
#    - Support: 0.117
#    - Confidence: 0.401
#    - Lift: 0.896
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.091
#    - Confidence: 0.309
#    - Lift: 0.896
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Sentiment=Positive AND Helpfulness=None
#    - Support: 0.072
#    - Confidence: 0.246
#    - Lift: 0.891
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Helpfulness=None AND Rating=High
#    - Support: 0.072
#    - Confidence: 0.246
#    - Lift: 0.891
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND season=Winter AND Helpfulness=None AND Rating=High
#    - Support: 0.072
#    - Confidence: 0.246
#    - Lift: 0.891
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND season=Winter AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.07
#    - Confidence: 0.238
#    - Lift: 0.883
#
# -> IF lockdown_period=Post-COVID THEN Rating=High AND season=Winter AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.07
#    - Confidence: 0.238
#    - Lift: 0.883
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.07
#    - Confidence: 0.238
#    - Lift: 0.883
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Verified=Verified AND Review_Length=Short
#    - Support: 0.107
#    - Confidence: 0.366
#    - Lift: 0.868
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Verified=Verified
#    - Support: 0.111
#    - Confidence: 0.378
#    - Lift: 0.867
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Sentiment=Positive
#    - Support: 0.084
#    - Confidence: 0.288
#    - Lift: 0.857
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Rating=High
#    - Support: 0.084
#    - Confidence: 0.288
#    - Lift: 0.857
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.084
#    - Confidence: 0.288
#    - Lift: 0.857
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.064
#    - Confidence: 0.22
#    - Lift: 0.854
#
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Verified=Verified AND season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.064
#    - Confidence: 0.22
#    - Lift: 0.854
#
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND season=Winter AND Helpfulness=None AND Verified=Verified
#    - Support: 0.064
#    - Confidence: 0.22
#    - Lift: 0.854
#
# -> IF lockdown_period=Post-COVID THEN Rating=High AND season=Winter AND Sentiment=Positive AND Review_Length=Short
#    - Support: 0.081
#    - Confidence: 0.276
#    - Lift: 0.853
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Sentiment=Positive AND Review_Length=Short
#    - Support: 0.081
#    - Confidence: 0.276
#    - Lift: 0.853
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND season=Winter AND Rating=High
#    - Support: 0.081
#    - Confidence: 0.276
#    - Lift: 0.853
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND season=Winter AND Sentiment=Positive
#    - Support: 0.063
#    - Confidence: 0.216
#    - Lift: 0.851
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.063
#    - Confidence: 0.216
#    - Lift: 0.851
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND season=Winter AND Rating=High
#    - Support: 0.063
#    - Confidence: 0.216
#    - Lift: 0.851
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.074
#    - Confidence: 0.251
#    - Lift: 0.824
#
# -> IF lockdown_period=Post-COVID THEN Rating=High AND season=Winter AND Verified=Verified AND Review_Length=Short
#    - Support: 0.074
#    - Confidence: 0.251
#    - Lift: 0.824
#
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Verified=Verified AND season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.074
#    - Confidence: 0.251
#    - Lift: 0.824
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Verified=Verified AND Rating=High
#    - Support: 0.076
#    - Confidence: 0.259
#    - Lift: 0.823
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Sentiment=Positive AND Verified=Verified
#    - Support: 0.076
#    - Confidence: 0.259
#    - Lift: 0.823
#
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Sentiment=Positive AND Verified=Verified AND Rating=High
#    - Support: 0.076
#    - Confidence: 0.259
#    - Lift: 0.823
#
#
# 📋 Lockdown Period-Based Discrimination Rules (Strictly 'lockdown_period=Pre-COVID'):
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Sentiment=Positive AND Verified=Verified AND Rating=High
#    - Support: 0.239
#    - Confidence: 0.338
#    - Lift: 1.073
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Verified=Verified AND Rating=High
#    - Support: 0.239
#    - Confidence: 0.338
#    - Lift: 1.073
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Sentiment=Positive AND Verified=Verified
#    - Support: 0.239
#    - Confidence: 0.338
#    - Lift: 1.073
#
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND season=Winter AND Verified=Verified AND Review_Length=Short
#    - Support: 0.231
#    - Confidence: 0.327
#    - Lift: 1.073
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Verified=Verified AND season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.231
#    - Confidence: 0.327
#    - Lift: 1.073
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.231
#    - Confidence: 0.327
#    - Lift: 1.073
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND season=Winter AND Sentiment=Positive
#    - Support: 0.19
#    - Confidence: 0.269
#    - Lift: 1.062
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND season=Winter AND Rating=High
#    - Support: 0.19
#    - Confidence: 0.269
#    - Lift: 1.062
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.19
#    - Confidence: 0.269
#    - Lift: 1.062
#
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND season=Winter AND Sentiment=Positive AND Review_Length=Short
#    - Support: 0.242
#    - Confidence: 0.343
#    - Lift: 1.061
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND season=Winter AND Rating=High
#    - Support: 0.242
#    - Confidence: 0.343
#    - Lift: 1.061
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Sentiment=Positive AND Review_Length=Short
#    - Support: 0.242
#    - Confidence: 0.343
#    - Lift: 1.061
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.193
#    - Confidence: 0.273
#    - Lift: 1.061
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND season=Winter AND Helpfulness=None AND Verified=Verified
#    - Support: 0.193
#    - Confidence: 0.273
#    - Lift: 1.061
#
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Verified=Verified AND season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.193
#    - Confidence: 0.273
#    - Lift: 1.061
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.252
#    - Confidence: 0.356
#    - Lift: 1.059
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Rating=High
#    - Support: 0.252
#    - Confidence: 0.356
#    - Lift: 1.059
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Sentiment=Positive
#    - Support: 0.252
#    - Confidence: 0.356
#    - Lift: 1.059
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Verified=Verified
#    - Support: 0.325
#    - Confidence: 0.46
#    - Lift: 1.055
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Verified=Verified AND Review_Length=Short
#    - Support: 0.314
#    - Confidence: 0.444
#    - Lift: 1.055
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND season=Winter AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.2
#    - Confidence: 0.282
#    - Lift: 1.048
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.2
#    - Confidence: 0.282
#    - Lift: 1.048
#
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND season=Winter AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.2
#    - Confidence: 0.282
#    - Lift: 1.048
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Helpfulness=None AND Rating=High
#    - Support: 0.204
#    - Confidence: 0.288
#    - Lift: 1.045
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND season=Winter AND Helpfulness=None AND Rating=High
#    - Support: 0.204
#    - Confidence: 0.288
#    - Lift: 1.045
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Sentiment=Positive AND Helpfulness=None
#    - Support: 0.204
#    - Confidence: 0.288
#    - Lift: 1.045
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.255
#    - Confidence: 0.36
#    - Lift: 1.043
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Review_Length=Short
#    - Support: 0.33
#    - Confidence: 0.466
#    - Lift: 1.043
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Helpfulness=None AND Verified=Verified
#    - Support: 0.259
#    - Confidence: 0.366
#    - Lift: 1.042
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter
#    - Support: 0.343
#    - Confidence: 0.486
#    - Lift: 1.042
#
# -> IF lockdown_period=Pre-COVID THEN Verified=Verified AND Rating=High
#    - Support: 0.486
#    - Confidence: 0.688
#    - Lift: 1.033
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.486
#    - Confidence: 0.688
#    - Lift: 1.033
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Verified=Verified AND Rating=High
#    - Support: 0.486
#    - Confidence: 0.688
#    - Lift: 1.033
#
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.469
#    - Confidence: 0.664
#    - Lift: 1.031
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.469
#    - Confidence: 0.664
#    - Lift: 1.031
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Verified=Verified AND Rating=High
#    - Support: 0.469
#    - Confidence: 0.664
#    - Lift: 1.031
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.268
#    - Confidence: 0.378
#    - Lift: 1.03
#
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Helpfulness=None
#    - Support: 0.273
#    - Confidence: 0.387
#    - Lift: 1.027
#
# -> IF lockdown_period=Pre-COVID THEN Rating=High
#    - Support: 0.514
#    - Confidence: 0.728
#    - Lift: 1.021
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive
#    - Support: 0.514
#    - Confidence: 0.728
#    - Lift: 1.021
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Rating=High
#    - Support: 0.514
#    - Confidence: 0.728
#    - Lift: 1.021
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Review_Length=Short
#    - Support: 0.491
#    - Confidence: 0.695
#    - Lift: 1.021
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Rating=High
#    - Support: 0.491
#    - Confidence: 0.695
#    - Lift: 1.021
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Sentiment=Positive AND Rating=High
#    - Support: 0.491
#    - Confidence: 0.695
#    - Lift: 1.021
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.383
#    - Confidence: 0.541
#    - Lift: 1.018
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND Rating=High
#    - Support: 0.383
#    - Confidence: 0.541
#    - Lift: 1.018
#
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.383
#    - Confidence: 0.541
#    - Lift: 1.018
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Verified=Verified AND Helpfulness=None
#    - Support: 0.389
#    - Confidence: 0.55
#    - Lift: 1.017
#
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.389
#    - Confidence: 0.55
#    - Lift: 1.017
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.389
#    - Confidence: 0.55
#    - Lift: 1.017
#
# -> IF lockdown_period=Pre-COVID THEN Verified=Verified
#    - Support: 0.669
#    - Confidence: 0.946
#    - Lift: 1.011
#
# -> IF lockdown_period=Pre-COVID THEN Verified=Verified AND Review_Length=Short
#    - Support: 0.644
#    - Confidence: 0.911
#    - Lift: 1.01
#
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND Sentiment=Positive AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.401
#    - Confidence: 0.567
#    - Lift: 1.006
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Rating=High
#    - Support: 0.401
#    - Confidence: 0.567
#    - Lift: 1.006
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.401
#    - Confidence: 0.567
#    - Lift: 1.006
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Helpfulness=None
#    - Support: 0.411
#    - Confidence: 0.581
#    - Lift: 1.004
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Helpfulness=None AND Rating=High
#    - Support: 0.411
#    - Confidence: 0.581
#    - Lift: 1.004
#
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Rating=High
#    - Support: 0.411
#    - Confidence: 0.581
#    - Lift: 1.004
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short
#    - Support: 0.675
#    - Confidence: 0.955
#    - Lift: 0.999
#
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.519
#    - Confidence: 0.734
#    - Lift: 0.996
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Verified=Verified AND season=Summer
#    - Support: 0.247
#    - Confidence: 0.35
#    - Lift: 0.996
#
# -> IF lockdown_period=Pre-COVID THEN Verified=Verified AND season=Summer AND Rating=High
#    - Support: 0.247
#    - Confidence: 0.35
#    - Lift: 0.996
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Verified=Verified AND season=Summer AND Rating=High
#    - Support: 0.247
#    - Confidence: 0.35
#    - Lift: 0.996
#
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Verified=Verified
#    - Support: 0.528
#    - Confidence: 0.748
#    - Lift: 0.995
#
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND Verified=Verified AND season=Summer AND Review_Length=Short
#    - Support: 0.238
#    - Confidence: 0.337
#    - Lift: 0.994
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Verified=Verified AND season=Summer AND Review_Length=Short
#    - Support: 0.238
#    - Confidence: 0.337
#    - Lift: 0.994
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Verified=Verified AND Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.238
#    - Confidence: 0.337
#    - Lift: 0.994
#
# -> IF lockdown_period=Pre-COVID THEN season=Summer AND Rating=High
#    - Support: 0.262
#    - Confidence: 0.371
#    - Lift: 0.987
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.262
#    - Confidence: 0.371
#    - Lift: 0.987
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND season=Summer
#    - Support: 0.262
#    - Confidence: 0.371
#    - Lift: 0.987
#
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Review_Length=Short
#    - Support: 0.544
#    - Confidence: 0.77
#    - Lift: 0.985
#
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND Sentiment=Positive AND season=Summer AND Review_Length=Short
#    - Support: 0.249
#    - Confidence: 0.352
#    - Lift: 0.984
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND season=Summer AND Review_Length=Short
#    - Support: 0.249
#    - Confidence: 0.352
#    - Lift: 0.984
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND season=Summer AND Rating=High
#    - Support: 0.249
#    - Confidence: 0.352
#    - Lift: 0.984
#
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None
#    - Support: 0.558
#    - Confidence: 0.79
#    - Lift: 0.983
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.192
#    - Confidence: 0.272
#    - Lift: 0.978
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND season=Summer
#    - Support: 0.192
#    - Confidence: 0.272
#    - Lift: 0.978
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND season=Summer AND Rating=High
#    - Support: 0.192
#    - Confidence: 0.272
#    - Lift: 0.978
#
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.196
#    - Confidence: 0.277
#    - Lift: 0.977
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND season=Summer
#    - Support: 0.196
#    - Confidence: 0.277
#    - Lift: 0.977
#
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Verified=Verified AND season=Summer AND Rating=High
#    - Support: 0.196
#    - Confidence: 0.277
#    - Lift: 0.977
#
# -> IF lockdown_period=Pre-COVID THEN Verified=Verified AND season=Summer
#    - Support: 0.344
#    - Confidence: 0.486
#    - Lift: 0.973
#
# -> IF lockdown_period=Pre-COVID THEN Verified=Verified AND season=Summer AND Review_Length=Short
#    - Support: 0.33
#    - Confidence: 0.467
#    - Lift: 0.971
#
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND Helpfulness=None AND season=Summer AND Review_Length=Short
#    - Support: 0.201
#    - Confidence: 0.285
#    - Lift: 0.967
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Helpfulness=None AND season=Summer AND Review_Length=Short
#    - Support: 0.201
#    - Confidence: 0.285
#    - Lift: 0.967
#
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.201
#    - Confidence: 0.285
#    - Lift: 0.967
#
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND season=Summer AND Rating=High
#    - Support: 0.207
#    - Confidence: 0.293
#    - Lift: 0.967
#
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Helpfulness=None AND season=Summer AND Rating=High
#    - Support: 0.207
#    - Confidence: 0.293
#    - Lift: 0.967
#
# -> IF lockdown_period=Pre-COVID THEN season=Summer AND Sentiment=Positive AND Helpfulness=None
#    - Support: 0.207
#    - Confidence: 0.293
#    - Lift: 0.967
#
# -> IF lockdown_period=Pre-COVID THEN season=Summer
#    - Support: 0.364
#    - Confidence: 0.514
#    - Lift: 0.964
#
# -> IF lockdown_period=Pre-COVID THEN season=Summer AND Review_Length=Short
#    - Support: 0.345
#    - Confidence: 0.488
#    - Lift: 0.961
#
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Verified=Verified AND season=Summer AND Review_Length=Short
#    - Support: 0.264
#    - Confidence: 0.374
#    - Lift: 0.955
#
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Verified=Verified AND season=Summer
#    - Support: 0.27
#    - Confidence: 0.381
#    - Lift: 0.954
#
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND season=Summer AND Review_Length=Short
#    - Support: 0.277
#    - Confidence: 0.391
#    - Lift: 0.944
#
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND season=Summer
#    - Support: 0.285
#    - Confidence: 0.403
#    - Lift: 0.943
#
#
# 📄 Summary of Lockdown Period Discrimination Rules (Post-COVID):
#
#                      antecedents  \
# 603   lockdown_period=Post-COVID
# 508   lockdown_period=Post-COVID
# 2135  lockdown_period=Post-COVID
# 74    lockdown_period=Post-COVID
# 527   lockdown_period=Post-COVID
# 46    lockdown_period=Post-COVID
# 2179  lockdown_period=Post-COVID
# 4687  lockdown_period=Post-COVID
# 2358  lockdown_period=Post-COVID
# 547   lockdown_period=Post-COVID
#
#                                             consequents   support  confidence  \
# 603          Sentiment=Negative AND Review_Length=Short  0.063813    0.217764
# 508                  Review_Length=Short AND Rating=Low  0.063813    0.217764
# 2135  Review_Length=Short AND Sentiment=Negative AND...  0.063813    0.217764
# 74                                   Sentiment=Negative  0.066430    0.226694
# 527                   Sentiment=Negative AND Rating=Low  0.066430    0.226694
# 46                                           Rating=Low  0.066430    0.226694
# 2179  Review_Length=Short AND Verified=Verified AND ...  0.058969    0.201231
# 4687  Rating=Low AND Sentiment=Negative AND Verified...  0.058969    0.201231
# 2358  Sentiment=Negative AND Verified=Verified AND R...  0.058969    0.201231
# 547                    Verified=Verified AND Rating=Low  0.061108    0.208533
#
#           lift
# 603   1.196382
# 508   1.196382
# 2135  1.196382
# 74    1.194492
# 527   1.194492
# 46    1.194492
# 2179  1.174010
# 4687  1.174010
# 2358  1.174010
# 547   1.171504
#
# 📄 Summary of Lockdown Period Discrimination Rules (Pre-COVID):
#
#                     antecedents  \
# 4661  lockdown_period=Pre-COVID
# 2109  lockdown_period=Pre-COVID
# 2612  lockdown_period=Pre-COVID
# 4558  lockdown_period=Pre-COVID
# 6516  lockdown_period=Pre-COVID
# 5033  lockdown_period=Pre-COVID
# 6305  lockdown_period=Pre-COVID
# 5751  lockdown_period=Pre-COVID
# 7033  lockdown_period=Pre-COVID
# 4458  lockdown_period=Pre-COVID
#
#                                             consequents   support  confidence  \
# 4661  season=Winter AND Sentiment=Positive AND Verif...  0.238892    0.337914
# 2109  season=Winter AND Verified=Verified AND Rating...  0.238892    0.337914
# 2612  season=Winter AND Sentiment=Positive AND Verif...  0.238892    0.337914
# 4558  Rating=High AND season=Winter AND Verified=Ver...  0.231388    0.327299
# 6516  Review_Length=Short AND Verified=Verified AND ...  0.231388    0.327299
# 5033  season=Winter AND Sentiment=Positive AND Verif...  0.231388    0.327299
# 6305  Review_Length=Short AND Helpfulness=None AND V...  0.190220    0.269067
# 5751  Review_Length=Short AND Helpfulness=None AND V...  0.190220    0.269067
# 7033  Review_Length=Short AND Helpfulness=None AND V...  0.190220    0.269067
# 4458  Rating=High AND season=Winter AND Sentiment=Po...  0.242480    0.342988
#
#           lift
# 4661  1.073373
# 2109  1.073373
# 2612  1.073373
# 4558  1.072999
# 6516  1.072999
# 5033  1.072999
# 6305  1.061568
# 5751  1.061568
# 7033  1.061568
# 4458  1.060943

# %%
import os

# Re-run Apriori with lower thresholds to capture more rules
frequent_itemsets = apriori(df_trans, min_support=0.01, use_colnames=True)
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.2)

# Create output directory
os.makedirs("season_rules", exist_ok=True)

# Define seasons
seasons = ['Winter', 'Summer']

print("\n Generating Discrimination Rules Based on Season \n")

for season in seasons:
    season_tag = f"season={season}"
    
    # Strict filter: only that season alone in antecedent
    season_rules = rules[rules['antecedents'].apply(
        lambda x: season_tag in str(x) and len(x) == 1
    )].sort_values(by='lift', ascending=False)

    print(f"\n Rules for '{season_tag}':")
    if not season_rules.empty:
        for _, row in season_rules.iterrows():
            antecedent = ' AND '.join(list(row['antecedents']))
            consequent = ' AND '.join(list(row['consequents']))
            print(f"-> IF {antecedent} THEN {consequent}")
            print(f"   - Support: {round(row['support'], 3)}")
            print(f"   - Confidence: {round(row['confidence'], 3)}")
            print(f"   - Lift: {round(row['lift'], 3)}\n")
        
        # Save summary to CSV
        summary_df = season_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']].copy()
        summary_df['antecedents'] = summary_df['antecedents'].apply(lambda x: ' AND '.join(x))
        summary_df['consequents'] = summary_df['consequents'].apply(lambda x: ' AND '.join(x))
        summary_df.to_csv(f"season_rules/{season.lower()}_season_rules_summary.csv", index=False)
    else:
        print(f"❌ No rules generated for season '{season}'.")
# Out:
#  Generating Discrimination Rules Based on Season
#
#
#  Rules for 'season=Winter':
# -> IF season=Winter THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.2
#    - Confidence: 0.428
#    - Lift: 1.068
#
# -> IF season=Winter THEN Review_Length=Short AND Helpfulness=None AND Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.2
#    - Confidence: 0.428
#    - Lift: 1.068
#
# -> IF season=Winter THEN Rating=High AND lockdown_period=Pre-COVID AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.2
#    - Confidence: 0.428
#    - Lift: 1.068
#
# -> IF season=Winter THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.19
#    - Confidence: 0.408
#    - Lift: 1.066
#
# -> IF season=Winter THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND lockdown_period=Pre-COVID
#    - Support: 0.19
#    - Confidence: 0.408
#    - Lift: 1.066
#
# -> IF season=Winter THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.19
#    - Confidence: 0.408
#    - Lift: 1.066
#
# -> IF season=Winter THEN Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.193
#    - Confidence: 0.414
#    - Lift: 1.065
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.193
#    - Confidence: 0.414
#    - Lift: 1.065
#
# -> IF season=Winter THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Helpfulness=None AND Verified=Verified
#    - Support: 0.193
#    - Confidence: 0.414
#    - Lift: 1.065
#
# -> IF season=Winter THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Helpfulness=None AND Rating=High
#    - Support: 0.204
#    - Confidence: 0.437
#    - Lift: 1.063
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Helpfulness=None
#    - Support: 0.204
#    - Confidence: 0.437
#    - Lift: 1.063
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Rating=High
#    - Support: 0.204
#    - Confidence: 0.437
#    - Lift: 1.063
#
# -> IF season=Winter THEN Review_Length=Short AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.242
#    - Confidence: 0.52
#    - Lift: 1.059
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Review_Length=Short
#    - Support: 0.242
#    - Confidence: 0.52
#    - Lift: 1.059
#
# -> IF season=Winter THEN Rating=High AND lockdown_period=Pre-COVID AND Sentiment=Positive AND Review_Length=Short
#    - Support: 0.242
#    - Confidence: 0.52
#    - Lift: 1.059
#
# -> IF season=Winter THEN Rating=High AND lockdown_period=Pre-COVID AND Verified=Verified AND Review_Length=Short
#    - Support: 0.231
#    - Confidence: 0.496
#    - Lift: 1.057
#
# -> IF season=Winter THEN Review_Length=Short AND Verified=Verified AND Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.231
#    - Confidence: 0.496
#    - Lift: 1.057
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.231
#    - Confidence: 0.496
#    - Lift: 1.057
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.268
#    - Confidence: 0.574
#    - Lift: 1.055
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Verified=Verified AND Rating=High
#    - Support: 0.239
#    - Confidence: 0.512
#    - Lift: 1.054
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Verified=Verified
#    - Support: 0.239
#    - Confidence: 0.512
#    - Lift: 1.054
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Verified=Verified AND Rating=High
#    - Support: 0.239
#    - Confidence: 0.512
#    - Lift: 1.054
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.255
#    - Confidence: 0.546
#    - Lift: 1.052
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Sentiment=Positive
#    - Support: 0.252
#    - Confidence: 0.541
#    - Lift: 1.051
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.252
#    - Confidence: 0.541
#    - Lift: 1.051
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Rating=High
#    - Support: 0.252
#    - Confidence: 0.541
#    - Lift: 1.051
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Helpfulness=None
#    - Support: 0.273
#    - Confidence: 0.587
#    - Lift: 1.051
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Verified=Verified
#    - Support: 0.259
#    - Confidence: 0.555
#    - Lift: 1.051
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Review_Length=Short
#    - Support: 0.33
#    - Confidence: 0.707
#    - Lift: 1.048
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Verified=Verified AND Review_Length=Short
#    - Support: 0.314
#    - Confidence: 0.674
#    - Lift: 1.046
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Verified=Verified
#    - Support: 0.325
#    - Confidence: 0.697
#    - Lift: 1.042
#
# -> IF season=Winter THEN lockdown_period=Pre-COVID
#    - Support: 0.343
#    - Confidence: 0.736
#    - Lift: 1.042
#
# -> IF season=Winter THEN Sentiment=Positive AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.269
#    - Confidence: 0.578
#    - Lift: 1.025
#
# -> IF season=Winter THEN Rating=High AND Sentiment=Positive AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.269
#    - Confidence: 0.578
#    - Lift: 1.025
#
# -> IF season=Winter THEN Review_Length=Short AND Helpfulness=None AND Rating=High
#    - Support: 0.269
#    - Confidence: 0.578
#    - Lift: 1.025
#
# -> IF season=Winter THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND Rating=High
#    - Support: 0.253
#    - Confidence: 0.544
#    - Lift: 1.022
#
# -> IF season=Winter THEN Rating=High AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.253
#    - Confidence: 0.544
#    - Lift: 1.022
#
# -> IF season=Winter THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.253
#    - Confidence: 0.544
#    - Lift: 1.022
#
# -> IF season=Winter THEN Sentiment=Positive AND Helpfulness=None AND Rating=High
#    - Support: 0.276
#    - Confidence: 0.591
#    - Lift: 1.022
#
# -> IF season=Winter THEN Helpfulness=None AND Rating=High
#    - Support: 0.276
#    - Confidence: 0.591
#    - Lift: 1.022
#
# -> IF season=Winter THEN Sentiment=Positive AND Helpfulness=None
#    - Support: 0.276
#    - Confidence: 0.591
#    - Lift: 1.022
#
# -> IF season=Winter THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.258
#    - Confidence: 0.552
#    - Lift: 1.021
#
# -> IF season=Winter THEN Sentiment=Positive AND Verified=Verified AND Helpfulness=None
#    - Support: 0.258
#    - Confidence: 0.552
#    - Lift: 1.021
#
# -> IF season=Winter THEN Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.258
#    - Confidence: 0.552
#    - Lift: 1.021
#
# -> IF season=Winter THEN Review_Length=Short AND Sentiment=Positive AND Rating=High
#    - Support: 0.323
#    - Confidence: 0.694
#    - Lift: 1.018
#
# -> IF season=Winter THEN Review_Length=Short AND Rating=High
#    - Support: 0.323
#    - Confidence: 0.694
#    - Lift: 1.018
#
# -> IF season=Winter THEN Sentiment=Positive AND Review_Length=Short
#    - Support: 0.323
#    - Confidence: 0.694
#    - Lift: 1.018
#
# -> IF season=Winter THEN Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.305
#    - Confidence: 0.654
#    - Lift: 1.016
#
# -> IF season=Winter THEN Review_Length=Short AND Verified=Verified AND Rating=High
#    - Support: 0.305
#    - Confidence: 0.654
#    - Lift: 1.016
#
# -> IF season=Winter THEN Rating=High AND Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.305
#    - Confidence: 0.654
#    - Lift: 1.016
#
# -> IF season=Winter THEN Sentiment=Positive AND Verified=Verified AND Rating=High
#    - Support: 0.315
#    - Confidence: 0.675
#    - Lift: 1.014
#
# -> IF season=Winter THEN Verified=Verified AND Rating=High
#    - Support: 0.315
#    - Confidence: 0.675
#    - Lift: 1.014
#
# -> IF season=Winter THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.315
#    - Confidence: 0.675
#    - Lift: 1.014
#
# -> IF season=Winter THEN Rating=High
#    - Support: 0.336
#    - Confidence: 0.722
#    - Lift: 1.013
#
# -> IF season=Winter THEN Sentiment=Positive AND Rating=High
#    - Support: 0.336
#    - Confidence: 0.722
#    - Lift: 1.013
#
# -> IF season=Winter THEN Sentiment=Positive
#    - Support: 0.336
#    - Confidence: 0.722
#    - Lift: 1.013
#
# -> IF season=Winter THEN Helpfulness=None AND Review_Length=Short
#    - Support: 0.367
#    - Confidence: 0.788
#    - Lift: 1.008
#
# -> IF season=Winter THEN Helpfulness=None
#    - Support: 0.377
#    - Confidence: 0.808
#    - Lift: 1.006
#
# -> IF season=Winter THEN Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.345
#    - Confidence: 0.741
#    - Lift: 1.005
#
# -> IF season=Winter THEN Helpfulness=None AND Verified=Verified
#    - Support: 0.352
#    - Confidence: 0.754
#    - Lift: 1.004
#
# -> IF season=Winter THEN Review_Length=Short
#    - Support: 0.447
#    - Confidence: 0.959
#    - Lift: 1.004
#
# -> IF season=Winter THEN Verified=Verified AND Review_Length=Short
#    - Support: 0.421
#    - Confidence: 0.903
#    - Lift: 1.001
#
# -> IF season=Winter THEN Verified=Verified
#    - Support: 0.436
#    - Confidence: 0.935
#    - Lift: 0.999
#
# -> IF season=Winter THEN Helpfulness=None AND lockdown_period=Post-COVID
#    - Support: 0.103
#    - Confidence: 0.221
#    - Lift: 0.902
#
# -> IF season=Winter THEN Helpfulness=None AND lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.1
#    - Confidence: 0.214
#    - Lift: 0.901
#
# -> IF season=Winter THEN lockdown_period=Post-COVID
#    - Support: 0.123
#    - Confidence: 0.264
#    - Lift: 0.9
#
# -> IF season=Winter THEN lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.117
#    - Confidence: 0.252
#    - Lift: 0.899
#
# -> IF season=Winter THEN Verified=Verified AND lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.107
#    - Confidence: 0.23
#    - Lift: 0.891
#
# -> IF season=Winter THEN Verified=Verified AND lockdown_period=Post-COVID
#    - Support: 0.111
#    - Confidence: 0.238
#    - Lift: 0.891
#
#
#  Rules for 'season=Summer':
# -> IF season=Summer THEN Verified=Verified AND lockdown_period=Post-COVID
#    - Support: 0.156
#    - Confidence: 0.292
#    - Lift: 1.095
#
# -> IF season=Summer THEN Verified=Verified AND lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.151
#    - Confidence: 0.282
#    - Lift: 1.095
#
# -> IF season=Summer THEN Helpfulness=None AND Verified=Verified AND lockdown_period=Post-COVID
#    - Support: 0.13
#    - Confidence: 0.244
#    - Lift: 1.094
#
# -> IF season=Summer THEN Helpfulness=None AND Verified=Verified AND lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.127
#    - Confidence: 0.238
#    - Lift: 1.094
#
# -> IF season=Summer THEN lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.163
#    - Confidence: 0.305
#    - Lift: 1.088
#
# -> IF season=Summer THEN lockdown_period=Post-COVID
#    - Support: 0.17
#    - Confidence: 0.319
#    - Lift: 1.088
#
# -> IF season=Summer THEN Helpfulness=None AND lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.138
#    - Confidence: 0.258
#    - Lift: 1.086
#
# -> IF season=Summer THEN Helpfulness=None AND lockdown_period=Post-COVID
#    - Support: 0.142
#    - Confidence: 0.266
#    - Lift: 1.085
#
# -> IF season=Summer THEN Review_Length=Short AND lockdown_period=Post-COVID AND Rating=High
#    - Support: 0.109
#    - Confidence: 0.204
#    - Lift: 1.075
#
# -> IF season=Summer THEN Rating=High AND Sentiment=Positive AND lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.109
#    - Confidence: 0.204
#    - Lift: 1.075
#
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.109
#    - Confidence: 0.204
#    - Lift: 1.075
#
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Post-COVID AND Rating=High
#    - Support: 0.114
#    - Confidence: 0.213
#    - Lift: 1.074
#
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Post-COVID
#    - Support: 0.114
#    - Confidence: 0.213
#    - Lift: 1.074
#
# -> IF season=Summer THEN lockdown_period=Post-COVID AND Rating=High
#    - Support: 0.114
#    - Confidence: 0.213
#    - Lift: 1.074
#
# -> IF season=Summer THEN Verified=Verified
#    - Support: 0.5
#    - Confidence: 0.936
#    - Lift: 1.001
#
# -> IF season=Summer THEN Verified=Verified AND Review_Length=Short
#    - Support: 0.481
#    - Confidence: 0.901
#    - Lift: 0.999
#
# -> IF season=Summer THEN Review_Length=Short
#    - Support: 0.508
#    - Confidence: 0.952
#    - Lift: 0.997
#
# -> IF season=Summer THEN Helpfulness=None AND Verified=Verified
#    - Support: 0.4
#    - Confidence: 0.749
#    - Lift: 0.997
#
# -> IF season=Summer THEN Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.392
#    - Confidence: 0.733
#    - Lift: 0.995
#
# -> IF season=Summer THEN Helpfulness=None
#    - Support: 0.427
#    - Confidence: 0.8
#    - Lift: 0.995
#
# -> IF season=Summer THEN Helpfulness=None AND Review_Length=Short
#    - Support: 0.415
#    - Confidence: 0.776
#    - Lift: 0.993
#
# -> IF season=Summer THEN Rating=High
#    - Support: 0.376
#    - Confidence: 0.704
#    - Lift: 0.988
#
# -> IF season=Summer THEN Sentiment=Positive
#    - Support: 0.376
#    - Confidence: 0.704
#    - Lift: 0.988
#
# -> IF season=Summer THEN Sentiment=Positive AND Rating=High
#    - Support: 0.376
#    - Confidence: 0.704
#    - Lift: 0.988
#
# -> IF season=Summer THEN Sentiment=Positive AND Verified=Verified AND Rating=High
#    - Support: 0.351
#    - Confidence: 0.658
#    - Lift: 0.988
#
# -> IF season=Summer THEN Verified=Verified AND Rating=High
#    - Support: 0.351
#    - Confidence: 0.658
#    - Lift: 0.988
#
# -> IF season=Summer THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.351
#    - Confidence: 0.658
#    - Lift: 0.988
#
# -> IF season=Summer THEN Rating=High AND Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.339
#    - Confidence: 0.635
#    - Lift: 0.986
#
# -> IF season=Summer THEN Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.339
#    - Confidence: 0.635
#    - Lift: 0.986
#
# -> IF season=Summer THEN Review_Length=Short AND Verified=Verified AND Rating=High
#    - Support: 0.339
#    - Confidence: 0.635
#    - Lift: 0.986
#
# -> IF season=Summer THEN Review_Length=Short AND Sentiment=Positive AND Rating=High
#    - Support: 0.358
#    - Confidence: 0.67
#    - Lift: 0.984
#
# -> IF season=Summer THEN Sentiment=Positive AND Review_Length=Short
#    - Support: 0.358
#    - Confidence: 0.67
#    - Lift: 0.984
#
# -> IF season=Summer THEN Review_Length=Short AND Rating=High
#    - Support: 0.358
#    - Confidence: 0.67
#    - Lift: 0.984
#
# -> IF season=Summer THEN Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.284
#    - Confidence: 0.531
#    - Lift: 0.982
#
# -> IF season=Summer THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.284
#    - Confidence: 0.531
#    - Lift: 0.982
#
# -> IF season=Summer THEN Sentiment=Positive AND Verified=Verified AND Helpfulness=None
#    - Support: 0.284
#    - Confidence: 0.531
#    - Lift: 0.982
#
# -> IF season=Summer THEN Sentiment=Positive AND Helpfulness=None
#    - Support: 0.303
#    - Confidence: 0.568
#    - Lift: 0.981
#
# -> IF season=Summer THEN Helpfulness=None AND Rating=High
#    - Support: 0.303
#    - Confidence: 0.568
#    - Lift: 0.981
#
# -> IF season=Summer THEN Sentiment=Positive AND Helpfulness=None AND Rating=High
#    - Support: 0.303
#    - Confidence: 0.568
#    - Lift: 0.981
#
# -> IF season=Summer THEN Rating=High AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.278
#    - Confidence: 0.522
#    - Lift: 0.981
#
# -> IF season=Summer THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND Rating=High
#    - Support: 0.278
#    - Confidence: 0.522
#    - Lift: 0.981
#
# -> IF season=Summer THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.278
#    - Confidence: 0.522
#    - Lift: 0.981
#
# -> IF season=Summer THEN Sentiment=Positive AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.295
#    - Confidence: 0.552
#    - Lift: 0.978
#
# -> IF season=Summer THEN Rating=High AND Sentiment=Positive AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.295
#    - Confidence: 0.552
#    - Lift: 0.978
#
# -> IF season=Summer THEN Review_Length=Short AND Helpfulness=None AND Rating=High
#    - Support: 0.295
#    - Confidence: 0.552
#    - Lift: 0.978
#
# -> IF season=Summer THEN lockdown_period=Pre-COVID
#    - Support: 0.364
#    - Confidence: 0.681
#    - Lift: 0.964
#
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Verified=Verified
#    - Support: 0.344
#    - Confidence: 0.644
#    - Lift: 0.963
#
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Verified=Verified AND Review_Length=Short
#    - Support: 0.33
#    - Confidence: 0.619
#    - Lift: 0.96
#
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Review_Length=Short
#    - Support: 0.345
#    - Confidence: 0.647
#    - Lift: 0.958
#
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Verified=Verified AND Helpfulness=None
#    - Support: 0.27
#    - Confidence: 0.505
#    - Lift: 0.955
#
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Helpfulness=None
#    - Support: 0.285
#    - Confidence: 0.533
#    - Lift: 0.955
#
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.262
#    - Confidence: 0.491
#    - Lift: 0.955
#
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Pre-COVID
#    - Support: 0.262
#    - Confidence: 0.491
#    - Lift: 0.955
#
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.262
#    - Confidence: 0.491
#    - Lift: 0.955
#
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.264
#    - Confidence: 0.495
#    - Lift: 0.954
#
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Verified=Verified
#    - Support: 0.247
#    - Confidence: 0.464
#    - Lift: 0.953
#
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Verified=Verified AND Rating=High
#    - Support: 0.247
#    - Confidence: 0.464
#    - Lift: 0.953
#
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Verified=Verified AND Rating=High
#    - Support: 0.247
#    - Confidence: 0.464
#    - Lift: 0.953
#
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.277
#    - Confidence: 0.518
#    - Lift: 0.952
#
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.238
#    - Confidence: 0.446
#    - Lift: 0.95
#
# -> IF season=Summer THEN Review_Length=Short AND Verified=Verified AND Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.238
#    - Confidence: 0.446
#    - Lift: 0.95
#
# -> IF season=Summer THEN Rating=High AND lockdown_period=Pre-COVID AND Verified=Verified AND Review_Length=Short
#    - Support: 0.238
#    - Confidence: 0.446
#    - Lift: 0.95
#
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Review_Length=Short
#    - Support: 0.249
#    - Confidence: 0.466
#    - Lift: 0.949
#
# -> IF season=Summer THEN Review_Length=Short AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.249
#    - Confidence: 0.466
#    - Lift: 0.949
#
# -> IF season=Summer THEN Rating=High AND lockdown_period=Pre-COVID AND Sentiment=Positive AND Review_Length=Short
#    - Support: 0.249
#    - Confidence: 0.466
#    - Lift: 0.949
#
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Rating=High
#    - Support: 0.207
#    - Confidence: 0.388
#    - Lift: 0.945
#
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Helpfulness=None
#    - Support: 0.207
#    - Confidence: 0.388
#    - Lift: 0.945
#
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Helpfulness=None AND Rating=High
#    - Support: 0.207
#    - Confidence: 0.388
#    - Lift: 0.945
#
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.196
#    - Confidence: 0.367
#    - Lift: 0.943
#
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Helpfulness=None AND Verified=Verified
#    - Support: 0.196
#    - Confidence: 0.367
#    - Lift: 0.943
#
# -> IF season=Summer THEN Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.196
#    - Confidence: 0.367
#    - Lift: 0.943
#
# -> IF season=Summer THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND lockdown_period=Pre-COVID
#    - Support: 0.192
#    - Confidence: 0.361
#    - Lift: 0.942
#
# -> IF season=Summer THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.192
#    - Confidence: 0.361
#    - Lift: 0.942
#
# -> IF season=Summer THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.192
#    - Confidence: 0.361
#    - Lift: 0.942
#
# -> IF season=Summer THEN Rating=High AND lockdown_period=Pre-COVID AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.201
#    - Confidence: 0.377
#    - Lift: 0.941
#
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.201
#    - Confidence: 0.377
#    - Lift: 0.941
#
# -> IF season=Summer THEN Review_Length=Short AND Helpfulness=None AND Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.201
#    - Confidence: 0.377
#    - Lift: 0.941

# %%
df_trans
# Out:
#          Helpfulness=Less Helpful  Helpfulness=More Helpful  Helpfulness=None  \
# 0                            True                     False             False
# 1                           False                     False              True
# 2                            True                     False             False
# 3                            True                     False             False
# 4                           False                     False              True
# ...                           ...                       ...               ...
# 1907673                     False                     False              True
# 1907674                     False                     False              True
# 1907675                     False                     False              True
# 1907676                     False                     False              True
# 1907677                      True                     False             False
#
#          Rating=High  Rating=Low  Rating=Medium  Review_Length=Long  \
# 0               True       False          False               False
# 1               True       False          False               False
# 2              False        True          False               False
# 3              False        True          False               False
# 4               True       False          False               False
# ...              ...         ...            ...                 ...
# 1907673         True       False          False               False
# 1907674         True       False          False               False
# 1907675        False        True          False               False
# 1907676        False       False           True               False
# 1907677         True       False          False               False
#
#          Review_Length=Medium  Review_Length=Short  Sentiment=Negative  \
# 0                       False                 True               False
# 1                       False                 True               False
# 2                       False                 True                True
# 3                       False                 True                True
# 4                       False                 True               False
# ...                       ...                  ...                 ...
# 1907673                 False                 True               False
# 1907674                 False                 True               False
# 1907675                 False                 True                True
# 1907676                 False                 True               False
# 1907677                 False                 True               False
#
#          Sentiment=Neutral  Sentiment=Positive  Verified=Not Verified  \
# 0                    False                True                  False
# 1                    False                True                  False
# 2                    False               False                  False
# 3                    False               False                  False
# 4                    False                True                  False
# ...                    ...                 ...                    ...
# 1907673              False                True                  False
# 1907674              False                True                  False
# 1907675              False               False                  False
# 1907676               True               False                  False
# 1907677              False                True                  False
#
#          Verified=Verified  lockdown_period=Post-COVID  \
# 0                     True                       False
# 1                     True                        True
# 2                     True                       False
# 3                     True                       False
# 4                     True                       False
# ...                    ...                         ...
# 1907673               True                       False
# 1907674               True                       False
# 1907675               True                       False
# 1907676               True                       False
# 1907677               True                       False
#
#          lockdown_period=Pre-COVID  season=Summer  season=Winter
# 0                             True          False           True
# 1                            False          False           True
# 2                             True           True          False
# 3                             True          False           True
# 4                             True           True          False
# ...                            ...            ...            ...
# 1907673                       True           True          False
# 1907674                       True           True          False
# 1907675                       True           True          False
# 1907676                       True          False           True
# 1907677                       True           True          False
#
# [1907678 rows x 18 columns]

# %%
# ---------------------------
# Helper function to calculate T and D weights
# ---------------------------
def calculate_weights_percentage(rules_df, season_column):
    def compute(row):
        in_antecedent = season_column in str(row['antecedents'])
        t_weight = row['support'] * 100 if in_antecedent else 0
        d_weight = row['lift'] * 100 if in_antecedent else 0
        return pd.Series([t_weight, d_weight])
    
    rules_df[['T Weight (%)', 'D Weight (%)']] = rules_df.apply(compute, axis=1)

    # Cap the D-Weight to not exceed 100% after computation
    rules_df['D Weight (%)'] = rules_df['D Weight (%)'].apply(lambda x: min(x, 100))

    return rules_df

# ---------------------------
# List of seasons (adapt based on your data)
# ---------------------------
seasons = ['Summer', 'Winter']

# ---------------------------
# Main loop to process each season
# ---------------------------
for season in seasons:
    season_tag = f"season={season}"

    if season_tag in df_trans.columns:
        # Filter rules where the season is the only antecedent
        season_rules = rules[rules['antecedents'].apply(
            lambda x: season_tag in str(x) and len(x) == 1
        )].sort_values(by='D weight', ascending=False)

        print(f"\n Rules for '{season_tag}':")
        if not season_rules.empty:
            # ✅ Add T/D Weights
            season_rules = calculate_weights_percentage(season_rules, season_tag)

            for _, row in season_rules.iterrows():
                antecedent = ' AND '.join(list(row['antecedents']))
                consequent = ' AND '.join(list(row['consequents']))
                print(f"-> IF {antecedent} THEN {consequent}")
                print(f"   - Support: {round(row['support'], 3)}")
                print(f"   - Confidence: {round(row['confidence'], 3)}")
                print(f"   - Lift: {round(row['lift'], 3)}")
                print(f"   - T Weight (Typicality): {row['T Weight (%)']:.2f}%")
                print(f"   - D Weight (Discriminability): {row['D Weight (%)']:.2f}%")

            # ✅ Save to CSV
            summary_df = season_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift',
                                       'T Weight (%)', 'D Weight (%)']].copy()
            summary_df['antecedents'] = summary_df['antecedents'].apply(lambda x: ' AND '.join(x))
            summary_df['consequents'] = summary_df['consequents'].apply(lambda x: ' AND '.join(x))
            summary_df.to_csv(f"season_rules/{season}_season_rules_summary.csv", index=False)
        else:
            print(f"❌ No rules generated for season '{season}'.")
    else:
        print(f"❌ Column '{season_tag}' not found in the DataFrame.")
# Out:
#  Rules for 'season=Summer':
# -> IF season=Summer THEN Verified=Verified AND lockdown_period=Post-COVID
#    - Support: 0.156
#    - Confidence: 0.292
#    - Lift: 1.095
#    - T Weight (Typicality): 15.60%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Summer THEN Verified=Verified AND lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.151
#    - Confidence: 0.282
#    - Lift: 1.095
#    - T Weight (Typicality): 15.07%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Summer THEN Helpfulness=None AND Verified=Verified AND lockdown_period=Post-COVID
#    - Support: 0.13
#    - Confidence: 0.244
#    - Lift: 1.094
#    - T Weight (Typicality): 13.00%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Summer THEN Helpfulness=None AND Verified=Verified AND lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.127
#    - Confidence: 0.238
#    - Lift: 1.094
#    - T Weight (Typicality): 12.72%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Summer THEN lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.163
#    - Confidence: 0.305
#    - Lift: 1.088
#    - T Weight (Typicality): 16.28%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Summer THEN lockdown_period=Post-COVID
#    - Support: 0.17
#    - Confidence: 0.319
#    - Lift: 1.088
#    - T Weight (Typicality): 17.01%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Summer THEN Helpfulness=None AND lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.138
#    - Confidence: 0.258
#    - Lift: 1.086
#    - T Weight (Typicality): 13.79%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Summer THEN Helpfulness=None AND lockdown_period=Post-COVID
#    - Support: 0.142
#    - Confidence: 0.266
#    - Lift: 1.085
#    - T Weight (Typicality): 14.22%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Summer THEN Review_Length=Short AND lockdown_period=Post-COVID AND Rating=High
#    - Support: 0.109
#    - Confidence: 0.204
#    - Lift: 1.075
#    - T Weight (Typicality): 10.88%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Summer THEN Rating=High AND Sentiment=Positive AND lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.109
#    - Confidence: 0.204
#    - Lift: 1.075
#    - T Weight (Typicality): 10.88%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.109
#    - Confidence: 0.204
#    - Lift: 1.075
#    - T Weight (Typicality): 10.88%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Post-COVID AND Rating=High
#    - Support: 0.114
#    - Confidence: 0.213
#    - Lift: 1.074
#    - T Weight (Typicality): 11.36%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Post-COVID
#    - Support: 0.114
#    - Confidence: 0.213
#    - Lift: 1.074
#    - T Weight (Typicality): 11.36%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Summer THEN lockdown_period=Post-COVID AND Rating=High
#    - Support: 0.114
#    - Confidence: 0.213
#    - Lift: 1.074
#    - T Weight (Typicality): 11.36%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Summer THEN Verified=Verified
#    - Support: 0.5
#    - Confidence: 0.936
#    - Lift: 1.001
#    - T Weight (Typicality): 49.98%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Summer THEN Verified=Verified AND Review_Length=Short
#    - Support: 0.481
#    - Confidence: 0.901
#    - Lift: 0.999
#    - T Weight (Typicality): 48.10%
#    - D Weight (Discriminability): 99.87%
# -> IF season=Summer THEN Review_Length=Short
#    - Support: 0.508
#    - Confidence: 0.952
#    - Lift: 0.997
#    - T Weight (Typicality): 50.82%
#    - D Weight (Discriminability): 99.66%
# -> IF season=Summer THEN Helpfulness=None AND Verified=Verified
#    - Support: 0.4
#    - Confidence: 0.749
#    - Lift: 0.997
#    - T Weight (Typicality): 39.96%
#    - D Weight (Discriminability): 99.65%
# -> IF season=Summer THEN Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.392
#    - Confidence: 0.733
#    - Lift: 0.995
#    - T Weight (Typicality): 39.15%
#    - D Weight (Discriminability): 99.54%
# -> IF season=Summer THEN Helpfulness=None
#    - Support: 0.427
#    - Confidence: 0.8
#    - Lift: 0.995
#    - T Weight (Typicality): 42.69%
#    - D Weight (Discriminability): 99.50%
# -> IF season=Summer THEN Helpfulness=None AND Review_Length=Short
#    - Support: 0.415
#    - Confidence: 0.776
#    - Lift: 0.993
#    - T Weight (Typicality): 41.45%
#    - D Weight (Discriminability): 99.30%
# -> IF season=Summer THEN Rating=High
#    - Support: 0.376
#    - Confidence: 0.704
#    - Lift: 0.988
#    - T Weight (Typicality): 37.59%
#    - D Weight (Discriminability): 98.84%
# -> IF season=Summer THEN Sentiment=Positive
#    - Support: 0.376
#    - Confidence: 0.704
#    - Lift: 0.988
#    - T Weight (Typicality): 37.59%
#    - D Weight (Discriminability): 98.84%
# -> IF season=Summer THEN Sentiment=Positive AND Rating=High
#    - Support: 0.376
#    - Confidence: 0.704
#    - Lift: 0.988
#    - T Weight (Typicality): 37.59%
#    - D Weight (Discriminability): 98.84%
# -> IF season=Summer THEN Sentiment=Positive AND Verified=Verified AND Rating=High
#    - Support: 0.351
#    - Confidence: 0.658
#    - Lift: 0.988
#    - T Weight (Typicality): 35.15%
#    - D Weight (Discriminability): 98.81%
# -> IF season=Summer THEN Verified=Verified AND Rating=High
#    - Support: 0.351
#    - Confidence: 0.658
#    - Lift: 0.988
#    - T Weight (Typicality): 35.15%
#    - D Weight (Discriminability): 98.81%
# -> IF season=Summer THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.351
#    - Confidence: 0.658
#    - Lift: 0.988
#    - T Weight (Typicality): 35.15%
#    - D Weight (Discriminability): 98.81%
# -> IF season=Summer THEN Rating=High AND Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.339
#    - Confidence: 0.635
#    - Lift: 0.986
#    - T Weight (Typicality): 33.87%
#    - D Weight (Discriminability): 98.56%
# -> IF season=Summer THEN Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.339
#    - Confidence: 0.635
#    - Lift: 0.986
#    - T Weight (Typicality): 33.87%
#    - D Weight (Discriminability): 98.56%
# -> IF season=Summer THEN Review_Length=Short AND Verified=Verified AND Rating=High
#    - Support: 0.339
#    - Confidence: 0.635
#    - Lift: 0.986
#    - T Weight (Typicality): 33.87%
#    - D Weight (Discriminability): 98.56%
# -> IF season=Summer THEN Review_Length=Short AND Sentiment=Positive AND Rating=High
#    - Support: 0.358
#    - Confidence: 0.67
#    - Lift: 0.984
#    - T Weight (Typicality): 35.77%
#    - D Weight (Discriminability): 98.39%
# -> IF season=Summer THEN Sentiment=Positive AND Review_Length=Short
#    - Support: 0.358
#    - Confidence: 0.67
#    - Lift: 0.984
#    - T Weight (Typicality): 35.77%
#    - D Weight (Discriminability): 98.39%
# -> IF season=Summer THEN Review_Length=Short AND Rating=High
#    - Support: 0.358
#    - Confidence: 0.67
#    - Lift: 0.984
#    - T Weight (Typicality): 35.77%
#    - D Weight (Discriminability): 98.39%
# -> IF season=Summer THEN Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.284
#    - Confidence: 0.531
#    - Lift: 0.982
#    - T Weight (Typicality): 28.36%
#    - D Weight (Discriminability): 98.18%
# -> IF season=Summer THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.284
#    - Confidence: 0.531
#    - Lift: 0.982
#    - T Weight (Typicality): 28.36%
#    - D Weight (Discriminability): 98.18%
# -> IF season=Summer THEN Sentiment=Positive AND Verified=Verified AND Helpfulness=None
#    - Support: 0.284
#    - Confidence: 0.531
#    - Lift: 0.982
#    - T Weight (Typicality): 28.36%
#    - D Weight (Discriminability): 98.18%
# -> IF season=Summer THEN Sentiment=Positive AND Helpfulness=None
#    - Support: 0.303
#    - Confidence: 0.568
#    - Lift: 0.981
#    - T Weight (Typicality): 30.31%
#    - D Weight (Discriminability): 98.11%
# -> IF season=Summer THEN Helpfulness=None AND Rating=High
#    - Support: 0.303
#    - Confidence: 0.568
#    - Lift: 0.981
#    - T Weight (Typicality): 30.31%
#    - D Weight (Discriminability): 98.11%
# -> IF season=Summer THEN Sentiment=Positive AND Helpfulness=None AND Rating=High
#    - Support: 0.303
#    - Confidence: 0.568
#    - Lift: 0.981
#    - T Weight (Typicality): 30.31%
#    - D Weight (Discriminability): 98.11%
# -> IF season=Summer THEN Rating=High AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.278
#    - Confidence: 0.522
#    - Lift: 0.981
#    - T Weight (Typicality): 27.85%
#    - D Weight (Discriminability): 98.06%
# -> IF season=Summer THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND Rating=High
#    - Support: 0.278
#    - Confidence: 0.522
#    - Lift: 0.981
#    - T Weight (Typicality): 27.85%
#    - D Weight (Discriminability): 98.06%
# -> IF season=Summer THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.278
#    - Confidence: 0.522
#    - Lift: 0.981
#    - T Weight (Typicality): 27.85%
#    - D Weight (Discriminability): 98.06%
# -> IF season=Summer THEN Sentiment=Positive AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.295
#    - Confidence: 0.552
#    - Lift: 0.978
#    - T Weight (Typicality): 29.45%
#    - D Weight (Discriminability): 97.85%
# -> IF season=Summer THEN Rating=High AND Sentiment=Positive AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.295
#    - Confidence: 0.552
#    - Lift: 0.978
#    - T Weight (Typicality): 29.45%
#    - D Weight (Discriminability): 97.85%
# -> IF season=Summer THEN Review_Length=Short AND Helpfulness=None AND Rating=High
#    - Support: 0.295
#    - Confidence: 0.552
#    - Lift: 0.978
#    - T Weight (Typicality): 29.45%
#    - D Weight (Discriminability): 97.85%
# -> IF season=Summer THEN lockdown_period=Pre-COVID
#    - Support: 0.364
#    - Confidence: 0.681
#    - Lift: 0.964
#    - T Weight (Typicality): 36.37%
#    - D Weight (Discriminability): 96.37%
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Verified=Verified
#    - Support: 0.344
#    - Confidence: 0.644
#    - Lift: 0.963
#    - T Weight (Typicality): 34.39%
#    - D Weight (Discriminability): 96.30%
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Verified=Verified AND Review_Length=Short
#    - Support: 0.33
#    - Confidence: 0.619
#    - Lift: 0.96
#    - T Weight (Typicality): 33.03%
#    - D Weight (Discriminability): 96.03%
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Review_Length=Short
#    - Support: 0.345
#    - Confidence: 0.647
#    - Lift: 0.958
#    - T Weight (Typicality): 34.53%
#    - D Weight (Discriminability): 95.85%
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Verified=Verified AND Helpfulness=None
#    - Support: 0.27
#    - Confidence: 0.505
#    - Lift: 0.955
#    - T Weight (Typicality): 26.96%
#    - D Weight (Discriminability): 95.54%
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Helpfulness=None
#    - Support: 0.285
#    - Confidence: 0.533
#    - Lift: 0.955
#    - T Weight (Typicality): 28.47%
#    - D Weight (Discriminability): 95.54%
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.262
#    - Confidence: 0.491
#    - Lift: 0.955
#    - T Weight (Typicality): 26.23%
#    - D Weight (Discriminability): 95.53%
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Pre-COVID
#    - Support: 0.262
#    - Confidence: 0.491
#    - Lift: 0.955
#    - T Weight (Typicality): 26.23%
#    - D Weight (Discriminability): 95.53%
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.262
#    - Confidence: 0.491
#    - Lift: 0.955
#    - T Weight (Typicality): 26.23%
#    - D Weight (Discriminability): 95.53%
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.264
#    - Confidence: 0.495
#    - Lift: 0.954
#    - T Weight (Typicality): 26.44%
#    - D Weight (Discriminability): 95.42%
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Verified=Verified
#    - Support: 0.247
#    - Confidence: 0.464
#    - Lift: 0.953
#    - T Weight (Typicality): 24.74%
#    - D Weight (Discriminability): 95.30%
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Verified=Verified AND Rating=High
#    - Support: 0.247
#    - Confidence: 0.464
#    - Lift: 0.953
#    - T Weight (Typicality): 24.74%
#    - D Weight (Discriminability): 95.30%
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Verified=Verified AND Rating=High
#    - Support: 0.247
#    - Confidence: 0.464
#    - Lift: 0.953
#    - T Weight (Typicality): 24.74%
#    - D Weight (Discriminability): 95.30%
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.277
#    - Confidence: 0.518
#    - Lift: 0.952
#    - T Weight (Typicality): 27.67%
#    - D Weight (Discriminability): 95.22%
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.238
#    - Confidence: 0.446
#    - Lift: 0.95
#    - T Weight (Typicality): 23.80%
#    - D Weight (Discriminability): 94.98%
# -> IF season=Summer THEN Review_Length=Short AND Verified=Verified AND Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.238
#    - Confidence: 0.446
#    - Lift: 0.95
#    - T Weight (Typicality): 23.80%
#    - D Weight (Discriminability): 94.98%
# -> IF season=Summer THEN Rating=High AND lockdown_period=Pre-COVID AND Verified=Verified AND Review_Length=Short
#    - Support: 0.238
#    - Confidence: 0.446
#    - Lift: 0.95
#    - T Weight (Typicality): 23.80%
#    - D Weight (Discriminability): 94.98%
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Review_Length=Short
#    - Support: 0.249
#    - Confidence: 0.466
#    - Lift: 0.949
#    - T Weight (Typicality): 24.89%
#    - D Weight (Discriminability): 94.87%
# -> IF season=Summer THEN Review_Length=Short AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.249
#    - Confidence: 0.466
#    - Lift: 0.949
#    - T Weight (Typicality): 24.89%
#    - D Weight (Discriminability): 94.87%
# -> IF season=Summer THEN Rating=High AND lockdown_period=Pre-COVID AND Sentiment=Positive AND Review_Length=Short
#    - Support: 0.249
#    - Confidence: 0.466
#    - Lift: 0.949
#    - T Weight (Typicality): 24.89%
#    - D Weight (Discriminability): 94.87%
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Rating=High
#    - Support: 0.207
#    - Confidence: 0.388
#    - Lift: 0.945
#    - T Weight (Typicality): 20.72%
#    - D Weight (Discriminability): 94.47%
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Helpfulness=None
#    - Support: 0.207
#    - Confidence: 0.388
#    - Lift: 0.945
#    - T Weight (Typicality): 20.72%
#    - D Weight (Discriminability): 94.47%
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Helpfulness=None AND Rating=High
#    - Support: 0.207
#    - Confidence: 0.388
#    - Lift: 0.945
#    - T Weight (Typicality): 20.72%
#    - D Weight (Discriminability): 94.47%
# -> IF season=Summer THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.196
#    - Confidence: 0.367
#    - Lift: 0.943
#    - T Weight (Typicality): 19.59%
#    - D Weight (Discriminability): 94.34%
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Helpfulness=None AND Verified=Verified
#    - Support: 0.196
#    - Confidence: 0.367
#    - Lift: 0.943
#    - T Weight (Typicality): 19.59%
#    - D Weight (Discriminability): 94.34%
# -> IF season=Summer THEN Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.196
#    - Confidence: 0.367
#    - Lift: 0.943
#    - T Weight (Typicality): 19.59%
#    - D Weight (Discriminability): 94.34%
# -> IF season=Summer THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND lockdown_period=Pre-COVID
#    - Support: 0.192
#    - Confidence: 0.361
#    - Lift: 0.942
#    - T Weight (Typicality): 19.25%
#    - D Weight (Discriminability): 94.21%
# -> IF season=Summer THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.192
#    - Confidence: 0.361
#    - Lift: 0.942
#    - T Weight (Typicality): 19.25%
#    - D Weight (Discriminability): 94.21%
# -> IF season=Summer THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.192
#    - Confidence: 0.361
#    - Lift: 0.942
#    - T Weight (Typicality): 19.25%
#    - D Weight (Discriminability): 94.21%
# -> IF season=Summer THEN Rating=High AND lockdown_period=Pre-COVID AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.201
#    - Confidence: 0.377
#    - Lift: 0.941
#    - T Weight (Typicality): 20.14%
#    - D Weight (Discriminability): 94.08%
# -> IF season=Summer THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.201
#    - Confidence: 0.377
#    - Lift: 0.941
#    - T Weight (Typicality): 20.14%
#    - D Weight (Discriminability): 94.08%
# -> IF season=Summer THEN Review_Length=Short AND Helpfulness=None AND Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.201
#    - Confidence: 0.377
#    - Lift: 0.941
#    - T Weight (Typicality): 20.14%
#    - D Weight (Discriminability): 94.08%
#
#  Rules for 'season=Winter':
# -> IF season=Winter THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.2
#    - Confidence: 0.428
#    - Lift: 1.068
#    - T Weight (Typicality): 19.96%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Review_Length=Short AND Helpfulness=None AND Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.2
#    - Confidence: 0.428
#    - Lift: 1.068
#    - T Weight (Typicality): 19.96%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Rating=High AND lockdown_period=Pre-COVID AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.2
#    - Confidence: 0.428
#    - Lift: 1.068
#    - T Weight (Typicality): 19.96%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.19
#    - Confidence: 0.408
#    - Lift: 1.066
#    - T Weight (Typicality): 19.02%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND lockdown_period=Pre-COVID
#    - Support: 0.19
#    - Confidence: 0.408
#    - Lift: 1.066
#    - T Weight (Typicality): 19.02%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.19
#    - Confidence: 0.408
#    - Lift: 1.066
#    - T Weight (Typicality): 19.02%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.193
#    - Confidence: 0.414
#    - Lift: 1.065
#    - T Weight (Typicality): 19.31%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.193
#    - Confidence: 0.414
#    - Lift: 1.065
#    - T Weight (Typicality): 19.31%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Helpfulness=None AND Verified=Verified
#    - Support: 0.193
#    - Confidence: 0.414
#    - Lift: 1.065
#    - T Weight (Typicality): 19.31%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Sentiment=Positive AND lockdown_period=Pre-COVID AND Helpfulness=None AND Rating=High
#    - Support: 0.204
#    - Confidence: 0.437
#    - Lift: 1.063
#    - T Weight (Typicality): 20.37%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Helpfulness=None
#    - Support: 0.204
#    - Confidence: 0.437
#    - Lift: 1.063
#    - T Weight (Typicality): 20.37%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Rating=High
#    - Support: 0.204
#    - Confidence: 0.437
#    - Lift: 1.063
#    - T Weight (Typicality): 20.37%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Review_Length=Short AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.242
#    - Confidence: 0.52
#    - Lift: 1.059
#    - T Weight (Typicality): 24.25%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Review_Length=Short
#    - Support: 0.242
#    - Confidence: 0.52
#    - Lift: 1.059
#    - T Weight (Typicality): 24.25%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Rating=High AND lockdown_period=Pre-COVID AND Sentiment=Positive AND Review_Length=Short
#    - Support: 0.242
#    - Confidence: 0.52
#    - Lift: 1.059
#    - T Weight (Typicality): 24.25%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Rating=High AND lockdown_period=Pre-COVID AND Verified=Verified AND Review_Length=Short
#    - Support: 0.231
#    - Confidence: 0.496
#    - Lift: 1.057
#    - T Weight (Typicality): 23.14%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Review_Length=Short AND Verified=Verified AND Sentiment=Positive AND lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.231
#    - Confidence: 0.496
#    - Lift: 1.057
#    - T Weight (Typicality): 23.14%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.231
#    - Confidence: 0.496
#    - Lift: 1.057
#    - T Weight (Typicality): 23.14%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.268
#    - Confidence: 0.574
#    - Lift: 1.055
#    - T Weight (Typicality): 26.76%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Verified=Verified AND Rating=High
#    - Support: 0.239
#    - Confidence: 0.512
#    - Lift: 1.054
#    - T Weight (Typicality): 23.89%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Verified=Verified
#    - Support: 0.239
#    - Confidence: 0.512
#    - Lift: 1.054
#    - T Weight (Typicality): 23.89%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Verified=Verified AND Rating=High
#    - Support: 0.239
#    - Confidence: 0.512
#    - Lift: 1.054
#    - T Weight (Typicality): 23.89%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.255
#    - Confidence: 0.546
#    - Lift: 1.052
#    - T Weight (Typicality): 25.46%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Sentiment=Positive
#    - Support: 0.252
#    - Confidence: 0.541
#    - Lift: 1.051
#    - T Weight (Typicality): 25.20%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Rating=High
#    - Support: 0.252
#    - Confidence: 0.541
#    - Lift: 1.051
#    - T Weight (Typicality): 25.20%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Sentiment=Positive AND Rating=High
#    - Support: 0.252
#    - Confidence: 0.541
#    - Lift: 1.051
#    - T Weight (Typicality): 25.20%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Helpfulness=None
#    - Support: 0.273
#    - Confidence: 0.587
#    - Lift: 1.051
#    - T Weight (Typicality): 27.35%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Helpfulness=None AND Verified=Verified
#    - Support: 0.259
#    - Confidence: 0.555
#    - Lift: 1.051
#    - T Weight (Typicality): 25.89%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Review_Length=Short
#    - Support: 0.33
#    - Confidence: 0.707
#    - Lift: 1.048
#    - T Weight (Typicality): 32.96%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Verified=Verified AND Review_Length=Short
#    - Support: 0.314
#    - Confidence: 0.674
#    - Lift: 1.046
#    - T Weight (Typicality): 31.40%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID AND Verified=Verified
#    - Support: 0.325
#    - Confidence: 0.697
#    - Lift: 1.042
#    - T Weight (Typicality): 32.50%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN lockdown_period=Pre-COVID
#    - Support: 0.343
#    - Confidence: 0.736
#    - Lift: 1.042
#    - T Weight (Typicality): 34.32%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Sentiment=Positive AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.269
#    - Confidence: 0.578
#    - Lift: 1.025
#    - T Weight (Typicality): 26.93%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Rating=High AND Sentiment=Positive AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.269
#    - Confidence: 0.578
#    - Lift: 1.025
#    - T Weight (Typicality): 26.93%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Review_Length=Short AND Helpfulness=None AND Rating=High
#    - Support: 0.269
#    - Confidence: 0.578
#    - Lift: 1.025
#    - T Weight (Typicality): 26.93%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND Rating=High
#    - Support: 0.253
#    - Confidence: 0.544
#    - Lift: 1.022
#    - T Weight (Typicality): 25.35%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Rating=High AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.253
#    - Confidence: 0.544
#    - Lift: 1.022
#    - T Weight (Typicality): 25.35%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.253
#    - Confidence: 0.544
#    - Lift: 1.022
#    - T Weight (Typicality): 25.35%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Sentiment=Positive AND Helpfulness=None AND Rating=High
#    - Support: 0.276
#    - Confidence: 0.591
#    - Lift: 1.022
#    - T Weight (Typicality): 27.56%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Helpfulness=None AND Rating=High
#    - Support: 0.276
#    - Confidence: 0.591
#    - Lift: 1.022
#    - T Weight (Typicality): 27.56%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Sentiment=Positive AND Helpfulness=None
#    - Support: 0.276
#    - Confidence: 0.591
#    - Lift: 1.022
#    - T Weight (Typicality): 27.56%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.258
#    - Confidence: 0.552
#    - Lift: 1.021
#    - T Weight (Typicality): 25.75%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Sentiment=Positive AND Verified=Verified AND Helpfulness=None
#    - Support: 0.258
#    - Confidence: 0.552
#    - Lift: 1.021
#    - T Weight (Typicality): 25.75%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.258
#    - Confidence: 0.552
#    - Lift: 1.021
#    - T Weight (Typicality): 25.75%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Review_Length=Short AND Sentiment=Positive AND Rating=High
#    - Support: 0.323
#    - Confidence: 0.694
#    - Lift: 1.018
#    - T Weight (Typicality): 32.33%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Review_Length=Short AND Rating=High
#    - Support: 0.323
#    - Confidence: 0.694
#    - Lift: 1.018
#    - T Weight (Typicality): 32.33%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Sentiment=Positive AND Review_Length=Short
#    - Support: 0.323
#    - Confidence: 0.694
#    - Lift: 1.018
#    - T Weight (Typicality): 32.33%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.305
#    - Confidence: 0.654
#    - Lift: 1.016
#    - T Weight (Typicality): 30.50%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Review_Length=Short AND Verified=Verified AND Rating=High
#    - Support: 0.305
#    - Confidence: 0.654
#    - Lift: 1.016
#    - T Weight (Typicality): 30.50%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Rating=High AND Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.305
#    - Confidence: 0.654
#    - Lift: 1.016
#    - T Weight (Typicality): 30.50%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Sentiment=Positive AND Verified=Verified AND Rating=High
#    - Support: 0.315
#    - Confidence: 0.675
#    - Lift: 1.014
#    - T Weight (Typicality): 31.48%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Verified=Verified AND Rating=High
#    - Support: 0.315
#    - Confidence: 0.675
#    - Lift: 1.014
#    - T Weight (Typicality): 31.48%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.315
#    - Confidence: 0.675
#    - Lift: 1.014
#    - T Weight (Typicality): 31.48%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Rating=High
#    - Support: 0.336
#    - Confidence: 0.722
#    - Lift: 1.013
#    - T Weight (Typicality): 33.65%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Sentiment=Positive AND Rating=High
#    - Support: 0.336
#    - Confidence: 0.722
#    - Lift: 1.013
#    - T Weight (Typicality): 33.65%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Sentiment=Positive
#    - Support: 0.336
#    - Confidence: 0.722
#    - Lift: 1.013
#    - T Weight (Typicality): 33.65%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Helpfulness=None AND Review_Length=Short
#    - Support: 0.367
#    - Confidence: 0.788
#    - Lift: 1.008
#    - T Weight (Typicality): 36.74%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Helpfulness=None
#    - Support: 0.377
#    - Confidence: 0.808
#    - Lift: 1.006
#    - T Weight (Typicality): 37.67%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.345
#    - Confidence: 0.741
#    - Lift: 1.005
#    - T Weight (Typicality): 34.53%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Helpfulness=None AND Verified=Verified
#    - Support: 0.352
#    - Confidence: 0.754
#    - Lift: 1.004
#    - T Weight (Typicality): 35.15%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Review_Length=Short
#    - Support: 0.447
#    - Confidence: 0.959
#    - Lift: 1.004
#    - T Weight (Typicality): 44.70%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Verified=Verified AND Review_Length=Short
#    - Support: 0.421
#    - Confidence: 0.903
#    - Lift: 1.001
#    - T Weight (Typicality): 42.11%
#    - D Weight (Discriminability): 100.00%
# -> IF season=Winter THEN Verified=Verified
#    - Support: 0.436
#    - Confidence: 0.935
#    - Lift: 0.999
#    - T Weight (Typicality): 43.57%
#    - D Weight (Discriminability): 99.92%
# -> IF season=Winter THEN Helpfulness=None AND lockdown_period=Post-COVID
#    - Support: 0.103
#    - Confidence: 0.221
#    - Lift: 0.902
#    - T Weight (Typicality): 10.32%
#    - D Weight (Discriminability): 90.24%
# -> IF season=Winter THEN Helpfulness=None AND lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.1
#    - Confidence: 0.214
#    - Lift: 0.901
#    - T Weight (Typicality): 9.98%
#    - D Weight (Discriminability): 90.12%
# -> IF season=Winter THEN lockdown_period=Post-COVID
#    - Support: 0.123
#    - Confidence: 0.264
#    - Lift: 0.9
#    - T Weight (Typicality): 12.29%
#    - D Weight (Discriminability): 89.98%
# -> IF season=Winter THEN lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.117
#    - Confidence: 0.252
#    - Lift: 0.899
#    - T Weight (Typicality): 11.74%
#    - D Weight (Discriminability): 89.88%
# -> IF season=Winter THEN Verified=Verified AND lockdown_period=Post-COVID AND Review_Length=Short
#    - Support: 0.107
#    - Confidence: 0.23
#    - Lift: 0.891
#    - T Weight (Typicality): 10.71%
#    - D Weight (Discriminability): 89.14%
# -> IF season=Winter THEN Verified=Verified AND lockdown_period=Post-COVID
#    - Support: 0.111
#    - Confidence: 0.238
#    - Lift: 0.891
#    - T Weight (Typicality): 11.07%
#    - D Weight (Discriminability): 89.07%

# %%
def calculate_weights_percentage(rules_df, lockdown_period_column):
    def compute(row):
        in_antecedent = lockdown_period_column in str(row['antecedents'])
        t_weight = row['support'] * 100 if in_antecedent else 0
        d_weight = row['lift'] * 100 if in_antecedent else 0
        return pd.Series([t_weight, d_weight])
    
    rules_df[['T Weight (%)', 'D Weight (%)']] = rules_df.apply(compute, axis=1)

    # Cap the D-Weight to not exceed 100% after computation
    rules_df['D Weight (%)'] = rules_df['D Weight (%)'].apply(lambda x: min(x, 100))

    return rules_df


# ---------------------------
# List of lockdown periods
# ---------------------------
lockdown_periods = ['Pre-COVID', 'Post-COVID']

# ---------------------------
# Main loop to process each lockdown period
# ---------------------------
for period in lockdown_periods:
    period_tag = f"lockdown_period={period}"

    if period_tag in df_trans.columns:
        # Filter rules where the lockdown period is the only antecedent
        period_rules = rules[rules['antecedents'].apply(
            lambda x: period_tag in str(x) and len(x) == 1
        )].sort_values(by='lift', ascending=False)

        print(f"\n Rules for '{period_tag}':")
        if not period_rules.empty:
            # ✅ Add T/D Weights
            period_rules = calculate_weights_percentage(period_rules, period_tag)

            for _, row in period_rules.iterrows():
                antecedent = ' AND '.join(list(row['antecedents']))
                consequent = ' AND '.join(list(row['consequents']))
                print(f"-> IF {antecedent} THEN {consequent}")
                print(f"   - Support: {round(row['support'], 3)}")
                print(f"   - Confidence: {round(row['confidence'], 3)}")
                print(f"   - Lift: {round(row['lift'], 3)}")
                print(f"   - T Weight (Typicality): {row['T Weight (%)']:.2f}%")
                print(f"   - D Weight (Discriminability): {row['D Weight (%)']:.2f}%")

            # ✅ Save to CSV
            summary_df = period_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift',
                                       'T Weight (%)', 'D Weight (%)']].copy()
            summary_df['antecedents'] = summary_df['antecedents'].apply(lambda x: ' AND '.join(x))
            summary_df['consequents'] = summary_df['consequents'].apply(lambda x: ' AND '.join(x))
            summary_df.to_csv(f"lockdown_period_rules/{period}_lockdown_period_rules_summary.csv", index=False)
        else:
            print(f"❌ No rules generated for lockdown period '{period}'.")
    else:
        print(f"❌ Column '{period_tag}' not found in the DataFrame.")
        print(f"❌ Column '{season_tag}' not found in the DataFrame.")
# Out:
#  Rules for 'lockdown_period=Pre-COVID':
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Sentiment=Positive AND Verified=Verified AND Rating=High
#    - Support: 0.239
#    - Confidence: 0.338
#    - Lift: 1.073
#    - T Weight (Typicality): 23.89%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Verified=Verified AND Rating=High
#    - Support: 0.239
#    - Confidence: 0.338
#    - Lift: 1.073
#    - T Weight (Typicality): 23.89%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Sentiment=Positive AND Verified=Verified
#    - Support: 0.239
#    - Confidence: 0.338
#    - Lift: 1.073
#    - T Weight (Typicality): 23.89%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND season=Winter AND Verified=Verified AND Review_Length=Short
#    - Support: 0.231
#    - Confidence: 0.327
#    - Lift: 1.073
#    - T Weight (Typicality): 23.14%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Verified=Verified AND season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.231
#    - Confidence: 0.327
#    - Lift: 1.073
#    - T Weight (Typicality): 23.14%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.231
#    - Confidence: 0.327
#    - Lift: 1.073
#    - T Weight (Typicality): 23.14%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND season=Winter AND Sentiment=Positive
#    - Support: 0.19
#    - Confidence: 0.269
#    - Lift: 1.062
#    - T Weight (Typicality): 19.02%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND season=Winter AND Rating=High
#    - Support: 0.19
#    - Confidence: 0.269
#    - Lift: 1.062
#    - T Weight (Typicality): 19.02%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.19
#    - Confidence: 0.269
#    - Lift: 1.062
#    - T Weight (Typicality): 19.02%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND season=Winter AND Sentiment=Positive AND Review_Length=Short
#    - Support: 0.242
#    - Confidence: 0.343
#    - Lift: 1.061
#    - T Weight (Typicality): 24.25%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND season=Winter AND Rating=High
#    - Support: 0.242
#    - Confidence: 0.343
#    - Lift: 1.061
#    - T Weight (Typicality): 24.25%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Sentiment=Positive AND Review_Length=Short
#    - Support: 0.242
#    - Confidence: 0.343
#    - Lift: 1.061
#    - T Weight (Typicality): 24.25%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.193
#    - Confidence: 0.273
#    - Lift: 1.061
#    - T Weight (Typicality): 19.31%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND season=Winter AND Helpfulness=None AND Verified=Verified
#    - Support: 0.193
#    - Confidence: 0.273
#    - Lift: 1.061
#    - T Weight (Typicality): 19.31%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Verified=Verified AND season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.193
#    - Confidence: 0.273
#    - Lift: 1.061
#    - T Weight (Typicality): 19.31%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.252
#    - Confidence: 0.356
#    - Lift: 1.059
#    - T Weight (Typicality): 25.20%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Rating=High
#    - Support: 0.252
#    - Confidence: 0.356
#    - Lift: 1.059
#    - T Weight (Typicality): 25.20%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Sentiment=Positive
#    - Support: 0.252
#    - Confidence: 0.356
#    - Lift: 1.059
#    - T Weight (Typicality): 25.20%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Verified=Verified
#    - Support: 0.325
#    - Confidence: 0.46
#    - Lift: 1.055
#    - T Weight (Typicality): 32.50%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Verified=Verified AND Review_Length=Short
#    - Support: 0.314
#    - Confidence: 0.444
#    - Lift: 1.055
#    - T Weight (Typicality): 31.40%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND season=Winter AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.2
#    - Confidence: 0.282
#    - Lift: 1.048
#    - T Weight (Typicality): 19.96%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.2
#    - Confidence: 0.282
#    - Lift: 1.048
#    - T Weight (Typicality): 19.96%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND season=Winter AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.2
#    - Confidence: 0.282
#    - Lift: 1.048
#    - T Weight (Typicality): 19.96%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Helpfulness=None AND Rating=High
#    - Support: 0.204
#    - Confidence: 0.288
#    - Lift: 1.045
#    - T Weight (Typicality): 20.37%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND season=Winter AND Helpfulness=None AND Rating=High
#    - Support: 0.204
#    - Confidence: 0.288
#    - Lift: 1.045
#    - T Weight (Typicality): 20.37%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Sentiment=Positive AND Helpfulness=None
#    - Support: 0.204
#    - Confidence: 0.288
#    - Lift: 1.045
#    - T Weight (Typicality): 20.37%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.255
#    - Confidence: 0.36
#    - Lift: 1.043
#    - T Weight (Typicality): 25.46%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Review_Length=Short
#    - Support: 0.33
#    - Confidence: 0.466
#    - Lift: 1.043
#    - T Weight (Typicality): 32.96%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Helpfulness=None AND Verified=Verified
#    - Support: 0.259
#    - Confidence: 0.366
#    - Lift: 1.042
#    - T Weight (Typicality): 25.89%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter
#    - Support: 0.343
#    - Confidence: 0.486
#    - Lift: 1.042
#    - T Weight (Typicality): 34.32%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Verified=Verified AND Rating=High
#    - Support: 0.486
#    - Confidence: 0.688
#    - Lift: 1.033
#    - T Weight (Typicality): 48.63%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.486
#    - Confidence: 0.688
#    - Lift: 1.033
#    - T Weight (Typicality): 48.63%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Verified=Verified AND Rating=High
#    - Support: 0.486
#    - Confidence: 0.688
#    - Lift: 1.033
#    - T Weight (Typicality): 48.63%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.469
#    - Confidence: 0.664
#    - Lift: 1.031
#    - T Weight (Typicality): 46.94%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.469
#    - Confidence: 0.664
#    - Lift: 1.031
#    - T Weight (Typicality): 46.94%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Verified=Verified AND Rating=High
#    - Support: 0.469
#    - Confidence: 0.664
#    - Lift: 1.031
#    - T Weight (Typicality): 46.94%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.268
#    - Confidence: 0.378
#    - Lift: 1.03
#    - T Weight (Typicality): 26.76%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN season=Winter AND Helpfulness=None
#    - Support: 0.273
#    - Confidence: 0.387
#    - Lift: 1.027
#    - T Weight (Typicality): 27.35%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Rating=High
#    - Support: 0.514
#    - Confidence: 0.728
#    - Lift: 1.021
#    - T Weight (Typicality): 51.44%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive
#    - Support: 0.514
#    - Confidence: 0.728
#    - Lift: 1.021
#    - T Weight (Typicality): 51.44%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Rating=High
#    - Support: 0.514
#    - Confidence: 0.728
#    - Lift: 1.021
#    - T Weight (Typicality): 51.44%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Review_Length=Short
#    - Support: 0.491
#    - Confidence: 0.695
#    - Lift: 1.021
#    - T Weight (Typicality): 49.13%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Rating=High
#    - Support: 0.491
#    - Confidence: 0.695
#    - Lift: 1.021
#    - T Weight (Typicality): 49.13%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Sentiment=Positive AND Rating=High
#    - Support: 0.491
#    - Confidence: 0.695
#    - Lift: 1.021
#    - T Weight (Typicality): 49.13%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.383
#    - Confidence: 0.541
#    - Lift: 1.018
#    - T Weight (Typicality): 38.27%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND Rating=High
#    - Support: 0.383
#    - Confidence: 0.541
#    - Lift: 1.018
#    - T Weight (Typicality): 38.27%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.383
#    - Confidence: 0.541
#    - Lift: 1.018
#    - T Weight (Typicality): 38.27%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Verified=Verified AND Helpfulness=None
#    - Support: 0.389
#    - Confidence: 0.55
#    - Lift: 1.017
#    - T Weight (Typicality): 38.90%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.389
#    - Confidence: 0.55
#    - Lift: 1.017
#    - T Weight (Typicality): 38.90%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.389
#    - Confidence: 0.55
#    - Lift: 1.017
#    - T Weight (Typicality): 38.90%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Verified=Verified
#    - Support: 0.669
#    - Confidence: 0.946
#    - Lift: 1.011
#    - T Weight (Typicality): 66.88%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Verified=Verified AND Review_Length=Short
#    - Support: 0.644
#    - Confidence: 0.911
#    - Lift: 1.01
#    - T Weight (Typicality): 64.43%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND Sentiment=Positive AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.401
#    - Confidence: 0.567
#    - Lift: 1.006
#    - T Weight (Typicality): 40.10%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Rating=High
#    - Support: 0.401
#    - Confidence: 0.567
#    - Lift: 1.006
#    - T Weight (Typicality): 40.10%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.401
#    - Confidence: 0.567
#    - Lift: 1.006
#    - T Weight (Typicality): 40.10%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Helpfulness=None
#    - Support: 0.411
#    - Confidence: 0.581
#    - Lift: 1.004
#    - T Weight (Typicality): 41.09%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Helpfulness=None AND Rating=High
#    - Support: 0.411
#    - Confidence: 0.581
#    - Lift: 1.004
#    - T Weight (Typicality): 41.09%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Rating=High
#    - Support: 0.411
#    - Confidence: 0.581
#    - Lift: 1.004
#    - T Weight (Typicality): 41.09%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short
#    - Support: 0.675
#    - Confidence: 0.955
#    - Lift: 0.999
#    - T Weight (Typicality): 67.49%
#    - D Weight (Discriminability): 99.95%
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.519
#    - Confidence: 0.734
#    - Lift: 0.996
#    - T Weight (Typicality): 51.90%
#    - D Weight (Discriminability): 99.64%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Verified=Verified AND season=Summer
#    - Support: 0.247
#    - Confidence: 0.35
#    - Lift: 0.996
#    - T Weight (Typicality): 24.74%
#    - D Weight (Discriminability): 99.59%
# -> IF lockdown_period=Pre-COVID THEN Verified=Verified AND season=Summer AND Rating=High
#    - Support: 0.247
#    - Confidence: 0.35
#    - Lift: 0.996
#    - T Weight (Typicality): 24.74%
#    - D Weight (Discriminability): 99.59%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Verified=Verified AND season=Summer AND Rating=High
#    - Support: 0.247
#    - Confidence: 0.35
#    - Lift: 0.996
#    - T Weight (Typicality): 24.74%
#    - D Weight (Discriminability): 99.59%
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Verified=Verified
#    - Support: 0.528
#    - Confidence: 0.748
#    - Lift: 0.995
#    - T Weight (Typicality): 52.85%
#    - D Weight (Discriminability): 99.53%
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND Verified=Verified AND season=Summer AND Review_Length=Short
#    - Support: 0.238
#    - Confidence: 0.337
#    - Lift: 0.994
#    - T Weight (Typicality): 23.80%
#    - D Weight (Discriminability): 99.39%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Verified=Verified AND season=Summer AND Review_Length=Short
#    - Support: 0.238
#    - Confidence: 0.337
#    - Lift: 0.994
#    - T Weight (Typicality): 23.80%
#    - D Weight (Discriminability): 99.39%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Verified=Verified AND Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.238
#    - Confidence: 0.337
#    - Lift: 0.994
#    - T Weight (Typicality): 23.80%
#    - D Weight (Discriminability): 99.39%
# -> IF lockdown_period=Pre-COVID THEN season=Summer AND Rating=High
#    - Support: 0.262
#    - Confidence: 0.371
#    - Lift: 0.987
#    - T Weight (Typicality): 26.23%
#    - D Weight (Discriminability): 98.71%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.262
#    - Confidence: 0.371
#    - Lift: 0.987
#    - T Weight (Typicality): 26.23%
#    - D Weight (Discriminability): 98.71%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND season=Summer
#    - Support: 0.262
#    - Confidence: 0.371
#    - Lift: 0.987
#    - T Weight (Typicality): 26.23%
#    - D Weight (Discriminability): 98.71%
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Review_Length=Short
#    - Support: 0.544
#    - Confidence: 0.77
#    - Lift: 0.985
#    - T Weight (Typicality): 54.43%
#    - D Weight (Discriminability): 98.45%
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND Sentiment=Positive AND season=Summer AND Review_Length=Short
#    - Support: 0.249
#    - Confidence: 0.352
#    - Lift: 0.984
#    - T Weight (Typicality): 24.89%
#    - D Weight (Discriminability): 98.42%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND season=Summer AND Review_Length=Short
#    - Support: 0.249
#    - Confidence: 0.352
#    - Lift: 0.984
#    - T Weight (Typicality): 24.89%
#    - D Weight (Discriminability): 98.42%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND season=Summer AND Rating=High
#    - Support: 0.249
#    - Confidence: 0.352
#    - Lift: 0.984
#    - T Weight (Typicality): 24.89%
#    - D Weight (Discriminability): 98.42%
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None
#    - Support: 0.558
#    - Confidence: 0.79
#    - Lift: 0.983
#    - T Weight (Typicality): 55.82%
#    - D Weight (Discriminability): 98.25%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.192
#    - Confidence: 0.272
#    - Lift: 0.978
#    - T Weight (Typicality): 19.25%
#    - D Weight (Discriminability): 97.77%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND season=Summer
#    - Support: 0.192
#    - Confidence: 0.272
#    - Lift: 0.978
#    - T Weight (Typicality): 19.25%
#    - D Weight (Discriminability): 97.77%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND season=Summer AND Rating=High
#    - Support: 0.192
#    - Confidence: 0.272
#    - Lift: 0.978
#    - T Weight (Typicality): 19.25%
#    - D Weight (Discriminability): 97.77%
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.196
#    - Confidence: 0.277
#    - Lift: 0.977
#    - T Weight (Typicality): 19.59%
#    - D Weight (Discriminability): 97.70%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND season=Summer
#    - Support: 0.196
#    - Confidence: 0.277
#    - Lift: 0.977
#    - T Weight (Typicality): 19.59%
#    - D Weight (Discriminability): 97.70%
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Verified=Verified AND season=Summer AND Rating=High
#    - Support: 0.196
#    - Confidence: 0.277
#    - Lift: 0.977
#    - T Weight (Typicality): 19.59%
#    - D Weight (Discriminability): 97.70%
# -> IF lockdown_period=Pre-COVID THEN Verified=Verified AND season=Summer
#    - Support: 0.344
#    - Confidence: 0.486
#    - Lift: 0.973
#    - T Weight (Typicality): 34.39%
#    - D Weight (Discriminability): 97.31%
# -> IF lockdown_period=Pre-COVID THEN Verified=Verified AND season=Summer AND Review_Length=Short
#    - Support: 0.33
#    - Confidence: 0.467
#    - Lift: 0.971
#    - T Weight (Typicality): 33.03%
#    - D Weight (Discriminability): 97.14%
# -> IF lockdown_period=Pre-COVID THEN Rating=High AND Helpfulness=None AND season=Summer AND Review_Length=Short
#    - Support: 0.201
#    - Confidence: 0.285
#    - Lift: 0.967
#    - T Weight (Typicality): 20.14%
#    - D Weight (Discriminability): 96.72%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Helpfulness=None AND season=Summer AND Review_Length=Short
#    - Support: 0.201
#    - Confidence: 0.285
#    - Lift: 0.967
#    - T Weight (Typicality): 20.14%
#    - D Weight (Discriminability): 96.72%
# -> IF lockdown_period=Pre-COVID THEN Review_Length=Short AND Helpfulness=None AND Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.201
#    - Confidence: 0.285
#    - Lift: 0.967
#    - T Weight (Typicality): 20.14%
#    - D Weight (Discriminability): 96.72%
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND season=Summer AND Rating=High
#    - Support: 0.207
#    - Confidence: 0.293
#    - Lift: 0.967
#    - T Weight (Typicality): 20.72%
#    - D Weight (Discriminability): 96.70%
# -> IF lockdown_period=Pre-COVID THEN Sentiment=Positive AND Helpfulness=None AND season=Summer AND Rating=High
#    - Support: 0.207
#    - Confidence: 0.293
#    - Lift: 0.967
#    - T Weight (Typicality): 20.72%
#    - D Weight (Discriminability): 96.70%
# -> IF lockdown_period=Pre-COVID THEN season=Summer AND Sentiment=Positive AND Helpfulness=None
#    - Support: 0.207
#    - Confidence: 0.293
#    - Lift: 0.967
#    - T Weight (Typicality): 20.72%
#    - D Weight (Discriminability): 96.70%
# -> IF lockdown_period=Pre-COVID THEN season=Summer
#    - Support: 0.364
#    - Confidence: 0.514
#    - Lift: 0.964
#    - T Weight (Typicality): 36.37%
#    - D Weight (Discriminability): 96.37%
# -> IF lockdown_period=Pre-COVID THEN season=Summer AND Review_Length=Short
#    - Support: 0.345
#    - Confidence: 0.488
#    - Lift: 0.961
#    - T Weight (Typicality): 34.53%
#    - D Weight (Discriminability): 96.12%
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Verified=Verified AND season=Summer AND Review_Length=Short
#    - Support: 0.264
#    - Confidence: 0.374
#    - Lift: 0.955
#    - T Weight (Typicality): 26.44%
#    - D Weight (Discriminability): 95.52%
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND Verified=Verified AND season=Summer
#    - Support: 0.27
#    - Confidence: 0.381
#    - Lift: 0.954
#    - T Weight (Typicality): 26.96%
#    - D Weight (Discriminability): 95.42%
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND season=Summer AND Review_Length=Short
#    - Support: 0.277
#    - Confidence: 0.391
#    - Lift: 0.944
#    - T Weight (Typicality): 27.67%
#    - D Weight (Discriminability): 94.41%
# -> IF lockdown_period=Pre-COVID THEN Helpfulness=None AND season=Summer
#    - Support: 0.285
#    - Confidence: 0.403
#    - Lift: 0.943
#    - T Weight (Typicality): 28.47%
#    - D Weight (Discriminability): 94.34%
#
#  Rules for 'lockdown_period=Post-COVID':
# -> IF lockdown_period=Post-COVID THEN Sentiment=Negative AND Review_Length=Short
#    - Support: 0.064
#    - Confidence: 0.218
#    - Lift: 1.196
#    - T Weight (Typicality): 6.38%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Rating=Low
#    - Support: 0.064
#    - Confidence: 0.218
#    - Lift: 1.196
#    - T Weight (Typicality): 6.38%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Sentiment=Negative AND Rating=Low
#    - Support: 0.064
#    - Confidence: 0.218
#    - Lift: 1.196
#    - T Weight (Typicality): 6.38%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Negative
#    - Support: 0.066
#    - Confidence: 0.227
#    - Lift: 1.194
#    - T Weight (Typicality): 6.64%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Negative AND Rating=Low
#    - Support: 0.066
#    - Confidence: 0.227
#    - Lift: 1.194
#    - T Weight (Typicality): 6.64%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Rating=Low
#    - Support: 0.066
#    - Confidence: 0.227
#    - Lift: 1.194
#    - T Weight (Typicality): 6.64%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Verified=Verified AND Rating=Low
#    - Support: 0.059
#    - Confidence: 0.201
#    - Lift: 1.174
#    - T Weight (Typicality): 5.90%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Rating=Low AND Sentiment=Negative AND Verified=Verified AND Review_Length=Short
#    - Support: 0.059
#    - Confidence: 0.201
#    - Lift: 1.174
#    - T Weight (Typicality): 5.90%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Negative AND Verified=Verified AND Review_Length=Short
#    - Support: 0.059
#    - Confidence: 0.201
#    - Lift: 1.174
#    - T Weight (Typicality): 5.90%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Verified=Verified AND Rating=Low
#    - Support: 0.061
#    - Confidence: 0.209
#    - Lift: 1.172
#    - T Weight (Typicality): 6.11%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Negative AND Verified=Verified
#    - Support: 0.061
#    - Confidence: 0.209
#    - Lift: 1.172
#    - T Weight (Typicality): 6.11%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Negative AND Verified=Verified AND Rating=Low
#    - Support: 0.061
#    - Confidence: 0.209
#    - Lift: 1.172
#    - T Weight (Typicality): 6.11%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND season=Summer
#    - Support: 0.142
#    - Confidence: 0.485
#    - Lift: 1.137
#    - T Weight (Typicality): 14.22%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND season=Summer AND Review_Length=Short
#    - Support: 0.138
#    - Confidence: 0.47
#    - Lift: 1.135
#    - T Weight (Typicality): 13.79%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Verified=Verified AND season=Summer
#    - Support: 0.13
#    - Confidence: 0.444
#    - Lift: 1.111
#    - T Weight (Typicality): 13.00%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Verified=Verified AND season=Summer AND Review_Length=Short
#    - Support: 0.127
#    - Confidence: 0.434
#    - Lift: 1.108
#    - T Weight (Typicality): 12.72%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN season=Summer AND Review_Length=Short
#    - Support: 0.163
#    - Confidence: 0.556
#    - Lift: 1.093
#    - T Weight (Typicality): 16.28%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN season=Summer
#    - Support: 0.17
#    - Confidence: 0.581
#    - Lift: 1.088
#    - T Weight (Typicality): 17.01%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND season=Summer AND Rating=High
#    - Support: 0.096
#    - Confidence: 0.327
#    - Lift: 1.08
#    - T Weight (Typicality): 9.59%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Helpfulness=None AND season=Summer AND Rating=High
#    - Support: 0.096
#    - Confidence: 0.327
#    - Lift: 1.08
#    - T Weight (Typicality): 9.59%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN season=Summer AND Sentiment=Positive AND Helpfulness=None
#    - Support: 0.096
#    - Confidence: 0.327
#    - Lift: 1.08
#    - T Weight (Typicality): 9.59%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.093
#    - Confidence: 0.318
#    - Lift: 1.079
#    - T Weight (Typicality): 9.32%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Helpfulness=None AND season=Summer AND Review_Length=Short
#    - Support: 0.093
#    - Confidence: 0.318
#    - Lift: 1.079
#    - T Weight (Typicality): 9.32%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Rating=High AND Helpfulness=None AND season=Summer AND Review_Length=Short
#    - Support: 0.093
#    - Confidence: 0.318
#    - Lift: 1.079
#    - T Weight (Typicality): 9.32%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Verified=Verified AND season=Summer AND Review_Length=Short
#    - Support: 0.151
#    - Confidence: 0.514
#    - Lift: 1.069
#    - T Weight (Typicality): 15.07%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Verified=Verified AND season=Summer
#    - Support: 0.156
#    - Confidence: 0.532
#    - Lift: 1.065
#    - T Weight (Typicality): 15.60%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Verified=Verified AND season=Summer AND Rating=High
#    - Support: 0.088
#    - Confidence: 0.299
#    - Lift: 1.055
#    - T Weight (Typicality): 8.77%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND season=Summer
#    - Support: 0.088
#    - Confidence: 0.299
#    - Lift: 1.055
#    - T Weight (Typicality): 8.77%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.088
#    - Confidence: 0.299
#    - Lift: 1.055
#    - T Weight (Typicality): 8.77%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.086
#    - Confidence: 0.293
#    - Lift: 1.054
#    - T Weight (Typicality): 8.60%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND season=Summer AND Rating=High
#    - Support: 0.086
#    - Confidence: 0.293
#    - Lift: 1.054
#    - T Weight (Typicality): 8.60%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND season=Summer
#    - Support: 0.086
#    - Confidence: 0.293
#    - Lift: 1.054
#    - T Weight (Typicality): 8.60%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None
#    - Support: 0.245
#    - Confidence: 0.837
#    - Lift: 1.042
#    - T Weight (Typicality): 24.54%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND season=Summer AND Rating=High
#    - Support: 0.109
#    - Confidence: 0.371
#    - Lift: 1.038
#    - T Weight (Typicality): 10.88%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND season=Summer AND Review_Length=Short
#    - Support: 0.109
#    - Confidence: 0.371
#    - Lift: 1.038
#    - T Weight (Typicality): 10.88%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Rating=High AND Sentiment=Positive AND season=Summer AND Review_Length=Short
#    - Support: 0.109
#    - Confidence: 0.371
#    - Lift: 1.038
#    - T Weight (Typicality): 10.88%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Review_Length=Short
#    - Support: 0.238
#    - Confidence: 0.811
#    - Lift: 1.037
#    - T Weight (Typicality): 23.77%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN season=Summer AND Rating=High
#    - Support: 0.114
#    - Confidence: 0.388
#    - Lift: 1.031
#    - T Weight (Typicality): 11.36%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.114
#    - Confidence: 0.388
#    - Lift: 1.031
#    - T Weight (Typicality): 11.36%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND season=Summer
#    - Support: 0.114
#    - Confidence: 0.388
#    - Lift: 1.031
#    - T Weight (Typicality): 11.36%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Verified=Verified AND Sentiment=Positive AND season=Summer AND Rating=High
#    - Support: 0.101
#    - Confidence: 0.344
#    - Lift: 1.015
#    - T Weight (Typicality): 10.07%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Verified=Verified AND season=Summer AND Review_Length=Short
#    - Support: 0.101
#    - Confidence: 0.344
#    - Lift: 1.015
#    - T Weight (Typicality): 10.07%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Rating=High AND Verified=Verified AND season=Summer AND Review_Length=Short
#    - Support: 0.101
#    - Confidence: 0.344
#    - Lift: 1.015
#    - T Weight (Typicality): 10.07%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Verified=Verified
#    - Support: 0.223
#    - Confidence: 0.76
#    - Lift: 1.011
#    - T Weight (Typicality): 22.26%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Verified=Verified AND season=Summer
#    - Support: 0.104
#    - Confidence: 0.355
#    - Lift: 1.01
#    - T Weight (Typicality): 10.40%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Verified=Verified AND season=Summer AND Rating=High
#    - Support: 0.104
#    - Confidence: 0.355
#    - Lift: 1.01
#    - T Weight (Typicality): 10.40%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Verified=Verified AND season=Summer AND Rating=High
#    - Support: 0.104
#    - Confidence: 0.355
#    - Lift: 1.01
#    - T Weight (Typicality): 10.40%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.218
#    - Confidence: 0.743
#    - Lift: 1.009
#    - T Weight (Typicality): 21.78%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short
#    - Support: 0.28
#    - Confidence: 0.956
#    - Lift: 1.001
#    - T Weight (Typicality): 28.03%
#    - D Weight (Discriminability): 100.00%
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Rating=High
#    - Support: 0.168
#    - Confidence: 0.573
#    - Lift: 0.99
#    - T Weight (Typicality): 16.79%
#    - D Weight (Discriminability): 98.98%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Helpfulness=None
#    - Support: 0.168
#    - Confidence: 0.573
#    - Lift: 0.99
#    - T Weight (Typicality): 16.79%
#    - D Weight (Discriminability): 98.98%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Helpfulness=None AND Rating=High
#    - Support: 0.168
#    - Confidence: 0.573
#    - Lift: 0.99
#    - T Weight (Typicality): 16.79%
#    - D Weight (Discriminability): 98.98%
# -> IF lockdown_period=Post-COVID THEN Rating=High AND Sentiment=Positive AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.163
#    - Confidence: 0.556
#    - Lift: 0.986
#    - T Weight (Typicality): 16.29%
#    - D Weight (Discriminability): 98.58%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Rating=High
#    - Support: 0.163
#    - Confidence: 0.556
#    - Lift: 0.986
#    - T Weight (Typicality): 16.29%
#    - D Weight (Discriminability): 98.58%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.163
#    - Confidence: 0.556
#    - Lift: 0.986
#    - T Weight (Typicality): 16.29%
#    - D Weight (Discriminability): 98.58%
# -> IF lockdown_period=Post-COVID THEN Verified=Verified AND Review_Length=Short
#    - Support: 0.258
#    - Confidence: 0.88
#    - Lift: 0.975
#    - T Weight (Typicality): 25.78%
#    - D Weight (Discriminability): 97.52%
# -> IF lockdown_period=Post-COVID THEN Verified=Verified
#    - Support: 0.267
#    - Confidence: 0.91
#    - Lift: 0.973
#    - T Weight (Typicality): 26.67%
#    - D Weight (Discriminability): 97.28%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.152
#    - Confidence: 0.519
#    - Lift: 0.96
#    - T Weight (Typicality): 15.22%
#    - D Weight (Discriminability): 95.96%
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.152
#    - Confidence: 0.519
#    - Lift: 0.96
#    - T Weight (Typicality): 15.22%
#    - D Weight (Discriminability): 95.96%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Verified=Verified AND Helpfulness=None
#    - Support: 0.152
#    - Confidence: 0.519
#    - Lift: 0.96
#    - T Weight (Typicality): 15.22%
#    - D Weight (Discriminability): 95.96%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND Sentiment=Positive AND Rating=High
#    - Support: 0.149
#    - Confidence: 0.509
#    - Lift: 0.957
#    - T Weight (Typicality): 14.92%
#    - D Weight (Discriminability): 95.74%
# -> IF lockdown_period=Post-COVID THEN Rating=High AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.149
#    - Confidence: 0.509
#    - Lift: 0.957
#    - T Weight (Typicality): 14.92%
#    - D Weight (Discriminability): 95.74%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.149
#    - Confidence: 0.509
#    - Lift: 0.957
#    - T Weight (Typicality): 14.92%
#    - D Weight (Discriminability): 95.74%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Rating=High
#    - Support: 0.19
#    - Confidence: 0.647
#    - Lift: 0.95
#    - T Weight (Typicality): 18.96%
#    - D Weight (Discriminability): 95.03%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Review_Length=Short
#    - Support: 0.19
#    - Confidence: 0.647
#    - Lift: 0.95
#    - T Weight (Typicality): 18.96%
#    - D Weight (Discriminability): 95.03%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Sentiment=Positive AND Rating=High
#    - Support: 0.19
#    - Confidence: 0.647
#    - Lift: 0.95
#    - T Weight (Typicality): 18.96%
#    - D Weight (Discriminability): 95.03%
# -> IF lockdown_period=Post-COVID THEN Rating=High
#    - Support: 0.198
#    - Confidence: 0.676
#    - Lift: 0.949
#    - T Weight (Typicality): 19.80%
#    - D Weight (Discriminability): 94.86%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive
#    - Support: 0.198
#    - Confidence: 0.676
#    - Lift: 0.949
#    - T Weight (Typicality): 19.80%
#    - D Weight (Discriminability): 94.86%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Rating=High
#    - Support: 0.198
#    - Confidence: 0.676
#    - Lift: 0.949
#    - T Weight (Typicality): 19.80%
#    - D Weight (Discriminability): 94.86%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Helpfulness=None
#    - Support: 0.103
#    - Confidence: 0.352
#    - Lift: 0.935
#    - T Weight (Typicality): 10.32%
#    - D Weight (Discriminability): 93.51%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.1
#    - Confidence: 0.341
#    - Lift: 0.927
#    - T Weight (Typicality): 9.98%
#    - D Weight (Discriminability): 92.73%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.174
#    - Confidence: 0.595
#    - Lift: 0.924
#    - T Weight (Typicality): 17.44%
#    - D Weight (Discriminability): 92.43%
# -> IF lockdown_period=Post-COVID THEN Rating=High AND Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.174
#    - Confidence: 0.595
#    - Lift: 0.924
#    - T Weight (Typicality): 17.44%
#    - D Weight (Discriminability): 92.43%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Verified=Verified AND Rating=High
#    - Support: 0.174
#    - Confidence: 0.595
#    - Lift: 0.924
#    - T Weight (Typicality): 17.44%
#    - D Weight (Discriminability): 92.43%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Verified=Verified
#    - Support: 0.18
#    - Confidence: 0.614
#    - Lift: 0.922
#    - T Weight (Typicality): 17.99%
#    - D Weight (Discriminability): 92.16%
# -> IF lockdown_period=Post-COVID THEN Verified=Verified AND Rating=High
#    - Support: 0.18
#    - Confidence: 0.614
#    - Lift: 0.922
#    - T Weight (Typicality): 17.99%
#    - D Weight (Discriminability): 92.16%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND Verified=Verified AND Rating=High
#    - Support: 0.18
#    - Confidence: 0.614
#    - Lift: 0.922
#    - T Weight (Typicality): 17.99%
#    - D Weight (Discriminability): 92.16%
# -> IF lockdown_period=Post-COVID THEN season=Winter
#    - Support: 0.123
#    - Confidence: 0.419
#    - Lift: 0.9
#    - T Weight (Typicality): 12.29%
#    - D Weight (Discriminability): 89.98%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Helpfulness=None AND Verified=Verified
#    - Support: 0.093
#    - Confidence: 0.316
#    - Lift: 0.899
#    - T Weight (Typicality): 9.26%
#    - D Weight (Discriminability): 89.88%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Review_Length=Short
#    - Support: 0.117
#    - Confidence: 0.401
#    - Lift: 0.896
#    - T Weight (Typicality): 11.74%
#    - D Weight (Discriminability): 89.64%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Helpfulness=None AND Verified=Verified AND Review_Length=Short
#    - Support: 0.091
#    - Confidence: 0.309
#    - Lift: 0.896
#    - T Weight (Typicality): 9.06%
#    - D Weight (Discriminability): 89.58%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Sentiment=Positive AND Helpfulness=None
#    - Support: 0.072
#    - Confidence: 0.246
#    - Lift: 0.891
#    - T Weight (Typicality): 7.20%
#    - D Weight (Discriminability): 89.11%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Helpfulness=None AND Rating=High
#    - Support: 0.072
#    - Confidence: 0.246
#    - Lift: 0.891
#    - T Weight (Typicality): 7.20%
#    - D Weight (Discriminability): 89.11%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND season=Winter AND Helpfulness=None AND Rating=High
#    - Support: 0.072
#    - Confidence: 0.246
#    - Lift: 0.891
#    - T Weight (Typicality): 7.20%
#    - D Weight (Discriminability): 89.11%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND season=Winter AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.07
#    - Confidence: 0.238
#    - Lift: 0.883
#    - T Weight (Typicality): 6.97%
#    - D Weight (Discriminability): 88.35%
# -> IF lockdown_period=Post-COVID THEN Rating=High AND season=Winter AND Helpfulness=None AND Review_Length=Short
#    - Support: 0.07
#    - Confidence: 0.238
#    - Lift: 0.883
#    - T Weight (Typicality): 6.97%
#    - D Weight (Discriminability): 88.35%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.07
#    - Confidence: 0.238
#    - Lift: 0.883
#    - T Weight (Typicality): 6.97%
#    - D Weight (Discriminability): 88.35%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Verified=Verified AND Review_Length=Short
#    - Support: 0.107
#    - Confidence: 0.366
#    - Lift: 0.868
#    - T Weight (Typicality): 10.71%
#    - D Weight (Discriminability): 86.80%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Verified=Verified
#    - Support: 0.111
#    - Confidence: 0.378
#    - Lift: 0.867
#    - T Weight (Typicality): 11.07%
#    - D Weight (Discriminability): 86.72%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Sentiment=Positive
#    - Support: 0.084
#    - Confidence: 0.288
#    - Lift: 0.857
#    - T Weight (Typicality): 8.45%
#    - D Weight (Discriminability): 85.65%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Rating=High
#    - Support: 0.084
#    - Confidence: 0.288
#    - Lift: 0.857
#    - T Weight (Typicality): 8.45%
#    - D Weight (Discriminability): 85.65%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.084
#    - Confidence: 0.288
#    - Lift: 0.857
#    - T Weight (Typicality): 8.45%
#    - D Weight (Discriminability): 85.65%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Helpfulness=None AND Verified=Verified AND Rating=High
#    - Support: 0.064
#    - Confidence: 0.22
#    - Lift: 0.854
#    - T Weight (Typicality): 6.44%
#    - D Weight (Discriminability): 85.40%
# -> IF lockdown_period=Post-COVID THEN Helpfulness=None AND Verified=Verified AND season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.064
#    - Confidence: 0.22
#    - Lift: 0.854
#    - T Weight (Typicality): 6.44%
#    - D Weight (Discriminability): 85.40%
# -> IF lockdown_period=Post-COVID THEN Sentiment=Positive AND season=Winter AND Helpfulness=None AND Verified=Verified
#    - Support: 0.064
#    - Confidence: 0.22
#    - Lift: 0.854
#    - T Weight (Typicality): 6.44%
#    - D Weight (Discriminability): 85.40%
# -> IF lockdown_period=Post-COVID THEN Rating=High AND season=Winter AND Sentiment=Positive AND Review_Length=Short
#    - Support: 0.081
#    - Confidence: 0.276
#    - Lift: 0.853
#    - T Weight (Typicality): 8.08%
#    - D Weight (Discriminability): 85.30%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Sentiment=Positive AND Review_Length=Short
#    - Support: 0.081
#    - Confidence: 0.276
#    - Lift: 0.853
#    - T Weight (Typicality): 8.08%
#    - D Weight (Discriminability): 85.30%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND season=Winter AND Rating=High
#    - Support: 0.081
#    - Confidence: 0.276
#    - Lift: 0.853
#    - T Weight (Typicality): 8.08%
#    - D Weight (Discriminability): 85.30%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND season=Winter AND Sentiment=Positive
#    - Support: 0.063
#    - Confidence: 0.216
#    - Lift: 0.851
#    - T Weight (Typicality): 6.32%
#    - D Weight (Discriminability): 85.15%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.063
#    - Confidence: 0.216
#    - Lift: 0.851
#    - T Weight (Typicality): 6.32%
#    - D Weight (Discriminability): 85.15%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Helpfulness=None AND Verified=Verified AND season=Winter AND Rating=High
#    - Support: 0.063
#    - Confidence: 0.216
#    - Lift: 0.851
#    - T Weight (Typicality): 6.32%
#    - D Weight (Discriminability): 85.15%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Sentiment=Positive AND Verified=Verified AND Review_Length=Short
#    - Support: 0.074
#    - Confidence: 0.251
#    - Lift: 0.824
#    - T Weight (Typicality): 7.36%
#    - D Weight (Discriminability): 82.39%
# -> IF lockdown_period=Post-COVID THEN Rating=High AND season=Winter AND Verified=Verified AND Review_Length=Short
#    - Support: 0.074
#    - Confidence: 0.251
#    - Lift: 0.824
#    - T Weight (Typicality): 7.36%
#    - D Weight (Discriminability): 82.39%
# -> IF lockdown_period=Post-COVID THEN Review_Length=Short AND Verified=Verified AND season=Winter AND Sentiment=Positive AND Rating=High
#    - Support: 0.074
#    - Confidence: 0.251
#    - Lift: 0.824
#    - T Weight (Typicality): 7.36%
#    - D Weight (Discriminability): 82.39%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Verified=Verified AND Rating=High
#    - Support: 0.076
#    - Confidence: 0.259
#    - Lift: 0.823
#    - T Weight (Typicality): 7.59%
#    - D Weight (Discriminability): 82.30%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Sentiment=Positive AND Verified=Verified
#    - Support: 0.076
#    - Confidence: 0.259
#    - Lift: 0.823
#    - T Weight (Typicality): 7.59%
#    - D Weight (Discriminability): 82.30%
# -> IF lockdown_period=Post-COVID THEN season=Winter AND Sentiment=Positive AND Verified=Verified AND Rating=High
#    - Support: 0.076
#    - Confidence: 0.259
#    - Lift: 0.823
#    - T Weight (Typicality): 7.59%
#    - D Weight (Discriminability): 82.30%
